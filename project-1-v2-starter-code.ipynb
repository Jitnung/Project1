# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
player_id = 1              #unique id of player
player_name = "Jitnung"
time_played = 45.0
player_pokemon = {}        #captured pokemon with features
gyms_visited = []          #ids of gyms visited

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'sporcle.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
gym_locations = ['reddit.com', 'amazon.com', 'twitter.com', 'linkedin.com', 'ebay.com', 'netflix.com', 'sporcle.com', 'stackoverflow.com', 'github.com', 'quora.com']
                 
for i in range(2):
    gyms_visited.append(gym_locations[i])

print(gyms_visited)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
my_pokedex = {}

my_pokedex[1] = {'name': 'charmander','type':'fire','hp': 1000, 'attack':250, 'defense':200,
                   'special_attack':480, 'special_defense':450, 'speed':300}
my_pokedex[2] = {'name': 'squirtle','type':'water','hp': 1000, 'attack':230, 'defense':240,
                   'special_attack':450, 'special_defense':480, 'speed':290}
my_pokedex[3] = {'name': 'bulbasaur','type':'grass','hp': 1000, 'attack':200, 'defense':220,
                   'special_attack':500, 'special_defense':490, 'speed':300}
pprint(my_pokedex)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
players = {}

players[1] = {"player_name": "Jitnung", "time_played": 45.0, "player_pokemon":{}, "gyms_visited":['reddit.com', 'amazon.com']}

pprint(players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'amazon.com'],
#      'player_name': 'Jitnung',
#      'player_pokemon': {},
#      'time_played': 45.0}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
players[2] = {"player_name": "Ash", "time_played": 105.0, "player_pokemon":{}, "gyms_visited":['alcatraz','pacific_beach']}

pprint(players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'amazon.com'],
#      'player_name': 'Jitnung',
#      'player_pokemon': {},
#      'time_played': 45.0},
#  2: {'gyms_visited': ['alcatraz', 'pacific_beach'],
#      'player_name': 'Ash',
#      'player_pokemon': {},
#      'time_played': 105.0}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
players[1]["player_pokemon"][2] = my_pokedex[2]       #giving player 1 squirtle

players[2]["player_pokemon"][1] = my_pokedex[1]          #giving player 2 char
players[2]["player_pokemon"][3] = my_pokedex[3]       #giving player 2 bulb

pprint(players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'amazon.com'],
#      'player_name': 'Jitnung',
#      'player_pokemon': {2: {'attack': 230,
#                             'defense': 240,
#                             'hp': 1000,
#                             'name': 'squirtle',
#                             'special_attack': 450,
#                             'special_defense': 480,
#                             'speed': 290,
#                             'type': 'water'}},
#      'time_played': 45.0},
#  2: {'gyms_visited': ['alcatraz', 'pacific_beach'],
#      'player_name': 'Ash',
#      'player_pokemon': {1: {'attack': 250,
#                             'defense': 200,
#                             'hp': 1000,
#                             'name': 'charmander',
#                             'special_attack': 480,
#                             'special_defense': 450,
#                             'speed': 300,
#                             'type': 'fire'},
#                         3: {'attack': 200,
#                             'defense': 220,
#                             'hp': 1000,
#                             'name': 'bulbasaur',
#                             'special_attack': 500,
#                             'special_defense': 490,
#                             'speed': 300,
#                             'type': 'grass'}},
#      'time_played': 105.0}}

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `gym_locations` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
for gym in gym_locations:
    for location in players[1]['gyms_visited']:
        if location == gym:
            print("player", 1, "has visited", gym)  
            
    for location in players[2]['gyms_visited']:
        if location == gym:
            print("player", 2, "has visited", gym)
# Out:
# player 1 has visited reddit.com
# player 1 has visited amazon.com

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %% [markdown]
# Yes, using list comprehension with less 'for' loop, it would save on the loading time

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
def player_power(player_dict,pokedex_dict,player_id):
    
    caught_pokemon = players[player_id]['player_pokemon']  #variable draws out caught pokemon(s) of selected player
    total_power = 0
    for keys in caught_pokemon:   #caught_pokemon is a dict. In this case, keys are already same as pokemon id in pokedex
        for poke_id in my_pokedex:
            if keys == poke_id:
                total_power += (my_pokedex[poke_id]['attack'] + pokedex[poke_id]['defense'])

    return total_power

print("Pokemon power for player 1 is: ", player_power(players,pokedex,1))
print("Pokemon power for player 2 is: ", player_power(players,pokedex,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-74e198a11e19> in <module>
#      10     return total_power
#      11
# ---> 12 print("Pokemon power for player 1 is: ", player_power(players,pokedex,1))
#      13 print("Pokemon power for player 2 is: ", player_power(players,pokedex,2))
#
# NameError: name 'pokedex' is not defined

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.readlines()
# raw_pd

raw_data = []
for row in raw_pd:
    raw_data.append(row.replace('"',''))             #removing quotes ("")

split_data = []    
for row in raw_data:
    split_data.append(row.split(','))               #spliting each element in row into individual strings

split_data[:3]
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed\n'],
#  ['001',
#   'Bulbasaur',
#   'GrassPoison',
#   '318',
#   '45',
#   '49',
#   '49',
#   '65',
#   '65',
#   '45\n'],
#  ['002',
#   'Ivysaur',
#   'GrassPoison',
#   '405',
#   '60',
#   '62',
#   '63',
#   '80',
#   '80',
#   '60\n']]

# %%
# split_data[1:]
floated_data = []

for row in split_data[1:]:
    new_row = [float(row[0])]
    new_row.append(row[1])
    new_row.append(row[2])    
#     print(new_row)              #getting first 3 elements of every row

    for num in row[3:]:
        new_row.append(float(num))
        
    floated_data.append(new_row)

floated_data
# Out:
# [[1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0],
#  [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0],
#  [3.0,
#   'VenusaurMega Venusaur',
#   'GrassPoison',
#   625.0,
#   80.0,
#   100.0,
#   123.0,
#   122.0,
#   120.0,
#   80.0],
#  [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0],
#  [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0],
#  [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0],
#  [6.0,
#   'CharizardMega Charizard X',
#   'FireDragon',
#   634.0,
#   78.0,
#   130.0,
#   111.0,
#   130.0,
#   85.0,
#   100.0],
#  [6.0,
#   'CharizardMega Charizard Y',
#   'FireFlying',
#   634.0,
#   78.0,
#   104.0,
#   78.0,
#   159.0,
#   115.0,
#   100.0],
#  [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0],
#  [8.0, 'Wartortle', 'Water', 405.0, 59.0, 63.0, 80.0, 65.0, 80.0, 58.0],
#  [9.0, 'Blastoise', 'Water', 530.0, 79.0, 83.0, 100.0, 85.0, 105.0, 78.0],
#  [9.0,
#   'BlastoiseMega Blastoise',
#   'Water',
#   630.0,
#   79.0,
#   103.0,
#   120.0,
#   135.0,
#   115.0,
#   78.0],
#  [10.0, 'Caterpie', 'Bug', 195.0, 45.0, 30.0, 35.0, 20.0, 20.0, 45.0],
#  [11.0, 'Metapod', 'Bug', 205.0, 50.0, 20.0, 55.0, 25.0, 25.0, 30.0],
#  [12.0, 'Butterfree', 'BugFlying', 395.0, 60.0, 45.0, 50.0, 90.0, 80.0, 70.0],
#  [13.0, 'Weedle', 'BugPoison', 195.0, 40.0, 35.0, 30.0, 20.0, 20.0, 50.0],
#  [14.0, 'Kakuna', 'BugPoison', 205.0, 45.0, 25.0, 50.0, 25.0, 25.0, 35.0],
#  [15.0, 'Beedrill', 'BugPoison', 395.0, 65.0, 90.0, 40.0, 45.0, 80.0, 75.0],
#  [15.0,
#   'BeedrillMega Beedrill',
#   'BugPoison',
#   495.0,
#   65.0,
#   150.0,
#   40.0,
#   15.0,
#   80.0,
#   145.0],
#  [16.0, 'Pidgey', 'NormalFlying', 251.0, 40.0, 45.0, 40.0, 35.0, 35.0, 56.0],
#  [17.0,
#   'Pidgeotto',
#   'NormalFlying',
#   349.0,
#   63.0,
#   60.0,
#   55.0,
#   50.0,
#   50.0,
#   71.0],
#  [18.0, 'Pidgeot', 'NormalFlying', 479.0, 83.0, 80.0, 75.0, 70.0, 70.0, 101.0],
#  [18.0,
#   'PidgeotMega Pidgeot',
#   'NormalFlying',
#   579.0,
#   83.0,
#   80.0,
#   80.0,
#   135.0,
#   80.0,
#   121.0],
#  [19.0, 'Rattata', 'Normal', 253.0, 30.0, 56.0, 35.0, 25.0, 35.0, 72.0],
#  [20.0, 'Raticate', 'Normal', 413.0, 55.0, 81.0, 60.0, 50.0, 70.0, 97.0],
#  [21.0, 'Spearow', 'NormalFlying', 262.0, 40.0, 60.0, 30.0, 31.0, 31.0, 70.0],
#  [22.0, 'Fearow', 'NormalFlying', 442.0, 65.0, 90.0, 65.0, 61.0, 61.0, 100.0],
#  [23.0, 'Ekans', 'Poison', 288.0, 35.0, 60.0, 44.0, 40.0, 54.0, 55.0],
#  [24.0, 'Arbok', 'Poison', 438.0, 60.0, 85.0, 69.0, 65.0, 79.0, 80.0],
#  [25.0, 'Pikachu', 'Electric', 320.0, 35.0, 55.0, 40.0, 50.0, 50.0, 90.0],
#  [26.0, 'Raichu', 'Electric', 485.0, 60.0, 90.0, 55.0, 90.0, 80.0, 110.0],
#  [27.0, 'Sandshrew', 'Ground', 300.0, 50.0, 75.0, 85.0, 20.0, 30.0, 40.0],
#  [28.0, 'Sandslash', 'Ground', 450.0, 75.0, 100.0, 110.0, 45.0, 55.0, 65.0],
#  [29.0, 'NidoranF', 'Poison', 275.0, 55.0, 47.0, 52.0, 40.0, 40.0, 41.0],
#  [30.0, 'Nidorina', 'Poison', 365.0, 70.0, 62.0, 67.0, 55.0, 55.0, 56.0],
#  [31.0,
#   'Nidoqueen',
#   'PoisonGround',
#   505.0,
#   90.0,
#   92.0,
#   87.0,
#   75.0,
#   85.0,
#   76.0],
#  [32.0, 'NidoranM', 'Poison', 273.0, 46.0, 57.0, 40.0, 40.0, 40.0, 50.0],
#  [33.0, 'Nidorino', 'Poison', 365.0, 61.0, 72.0, 57.0, 55.0, 55.0, 65.0],
#  [34.0,
#   'Nidoking',
#   'PoisonGround',
#   505.0,
#   81.0,
#   102.0,
#   77.0,
#   85.0,
#   75.0,
#   85.0],
#  [35.0, 'Clefairy', 'Fairy', 323.0, 70.0, 45.0, 48.0, 60.0, 65.0, 35.0],
#  [36.0, 'Clefable', 'Fairy', 483.0, 95.0, 70.0, 73.0, 95.0, 90.0, 60.0],
#  [37.0, 'Vulpix', 'Fire', 299.0, 38.0, 41.0, 40.0, 50.0, 65.0, 65.0],
#  [38.0, 'Ninetales', 'Fire', 505.0, 73.0, 76.0, 75.0, 81.0, 100.0, 100.0],
#  [39.0,
#   'Jigglypuff',
#   'NormalFairy',
#   270.0,
#   115.0,
#   45.0,
#   20.0,
#   45.0,
#   25.0,
#   20.0],
#  [40.0,
#   'Wigglytuff',
#   'NormalFairy',
#   435.0,
#   140.0,
#   70.0,
#   45.0,
#   85.0,
#   50.0,
#   45.0],
#  [41.0, 'Zubat', 'PoisonFlying', 245.0, 40.0, 45.0, 35.0, 30.0, 40.0, 55.0],
#  [42.0, 'Golbat', 'PoisonFlying', 455.0, 75.0, 80.0, 70.0, 65.0, 75.0, 90.0],
#  [43.0, 'Oddish', 'GrassPoison', 320.0, 45.0, 50.0, 55.0, 75.0, 65.0, 30.0],
#  [44.0, 'Gloom', 'GrassPoison', 395.0, 60.0, 65.0, 70.0, 85.0, 75.0, 40.0],
#  [45.0,
#   'Vileplume',
#   'GrassPoison',
#   490.0,
#   75.0,
#   80.0,
#   85.0,
#   110.0,
#   90.0,
#   50.0],
#  [46.0, 'Paras', 'BugGrass', 285.0, 35.0, 70.0, 55.0, 45.0, 55.0, 25.0],
#  [47.0, 'Parasect', 'BugGrass', 405.0, 60.0, 95.0, 80.0, 60.0, 80.0, 30.0],
#  [48.0, 'Venonat', 'BugPoison', 305.0, 60.0, 55.0, 50.0, 40.0, 55.0, 45.0],
#  [49.0, 'Venomoth', 'BugPoison', 450.0, 70.0, 65.0, 60.0, 90.0, 75.0, 90.0],
#  [50.0, 'Diglett', 'Ground', 265.0, 10.0, 55.0, 25.0, 35.0, 45.0, 95.0],
#  [51.0, 'Dugtrio', 'Ground', 405.0, 35.0, 80.0, 50.0, 50.0, 70.0, 120.0],
#  [52.0, 'Meowth', 'Normal', 290.0, 40.0, 45.0, 35.0, 40.0, 40.0, 90.0],
#  [53.0, 'Persian', 'Normal', 440.0, 65.0, 70.0, 60.0, 65.0, 65.0, 115.0],
#  [54.0, 'Psyduck', 'Water', 320.0, 50.0, 52.0, 48.0, 65.0, 50.0, 55.0],
#  [55.0, 'Golduck', 'Water', 500.0, 80.0, 82.0, 78.0, 95.0, 80.0, 85.0],
#  [56.0, 'Mankey', 'Fighting', 305.0, 40.0, 80.0, 35.0, 35.0, 45.0, 70.0],
#  [57.0, 'Primeape', 'Fighting', 455.0, 65.0, 105.0, 60.0, 60.0, 70.0, 95.0],
#  [58.0, 'Growlithe', 'Fire', 350.0, 55.0, 70.0, 45.0, 70.0, 50.0, 60.0],
#  [59.0, 'Arcanine', 'Fire', 555.0, 90.0, 110.0, 80.0, 100.0, 80.0, 95.0],
#  [60.0, 'Poliwag', 'Water', 300.0, 40.0, 50.0, 40.0, 40.0, 40.0, 90.0],
#  [61.0, 'Poliwhirl', 'Water', 385.0, 65.0, 65.0, 65.0, 50.0, 50.0, 90.0],
#  [62.0,
#   'Poliwrath',
#   'WaterFighting',
#   510.0,
#   90.0,
#   95.0,
#   95.0,
#   70.0,
#   90.0,
#   70.0],
#  [63.0, 'Abra', 'Psychic', 310.0, 25.0, 20.0, 15.0, 105.0, 55.0, 90.0],
#  [64.0, 'Kadabra', 'Psychic', 400.0, 40.0, 35.0, 30.0, 120.0, 70.0, 105.0],
#  [65.0, 'Alakazam', 'Psychic', 500.0, 55.0, 50.0, 45.0, 135.0, 95.0, 120.0],
#  [65.0,
#   'AlakazamMega Alakazam',
#   'Psychic',
#   590.0,
#   55.0,
#   50.0,
#   65.0,
#   175.0,
#   95.0,
#   150.0],
#  [66.0, 'Machop', 'Fighting', 305.0, 70.0, 80.0, 50.0, 35.0, 35.0, 35.0],
#  [67.0, 'Machoke', 'Fighting', 405.0, 80.0, 100.0, 70.0, 50.0, 60.0, 45.0],
#  [68.0, 'Machamp', 'Fighting', 505.0, 90.0, 130.0, 80.0, 65.0, 85.0, 55.0],
#  [69.0,
#   'Bellsprout',
#   'GrassPoison',
#   300.0,
#   50.0,
#   75.0,
#   35.0,
#   70.0,
#   30.0,
#   40.0],
#  [70.0,
#   'Weepinbell',
#   'GrassPoison',
#   390.0,
#   65.0,
#   90.0,
#   50.0,
#   85.0,
#   45.0,
#   55.0],
#  [71.0,
#   'Victreebel',
#   'GrassPoison',
#   490.0,
#   80.0,
#   105.0,
#   65.0,
#   100.0,
#   70.0,
#   70.0],
#  [72.0,
#   'Tentacool',
#   'WaterPoison',
#   335.0,
#   40.0,
#   40.0,
#   35.0,
#   50.0,
#   100.0,
#   70.0],
#  [73.0,
#   'Tentacruel',
#   'WaterPoison',
#   515.0,
#   80.0,
#   70.0,
#   65.0,
#   80.0,
#   120.0,
#   100.0],
#  [74.0, 'Geodude', 'RockGround', 300.0, 40.0, 80.0, 100.0, 30.0, 30.0, 20.0],
#  [75.0, 'Graveler', 'RockGround', 390.0, 55.0, 95.0, 115.0, 45.0, 45.0, 35.0],
#  [76.0, 'Golem', 'RockGround', 495.0, 80.0, 120.0, 130.0, 55.0, 65.0, 45.0],
#  [77.0, 'Ponyta', 'Fire', 410.0, 50.0, 85.0, 55.0, 65.0, 65.0, 90.0],
#  [78.0, 'Rapidash', 'Fire', 500.0, 65.0, 100.0, 70.0, 80.0, 80.0, 105.0],
#  [79.0, 'Slowpoke', 'WaterPsychic', 315.0, 90.0, 65.0, 65.0, 40.0, 40.0, 15.0],
#  [80.0,
#   'Slowbro',
#   'WaterPsychic',
#   490.0,
#   95.0,
#   75.0,
#   110.0,
#   100.0,
#   80.0,
#   30.0],
#  [80.0,
#   'SlowbroMega Slowbro',
#   'WaterPsychic',
#   590.0,
#   95.0,
#   75.0,
#   180.0,
#   130.0,
#   80.0,
#   30.0],
#  [81.0,
#   'Magnemite',
#   'ElectricSteel',
#   325.0,
#   25.0,
#   35.0,
#   70.0,
#   95.0,
#   55.0,
#   45.0],
#  [82.0,
#   'Magneton',
#   'ElectricSteel',
#   465.0,
#   50.0,
#   60.0,
#   95.0,
#   120.0,
#   70.0,
#   70.0],
#  [83.0,
#   "Farfetch'd",
#   'NormalFlying',
#   352.0,
#   52.0,
#   65.0,
#   55.0,
#   58.0,
#   62.0,
#   60.0],
#  [84.0, 'Doduo', 'NormalFlying', 310.0, 35.0, 85.0, 45.0, 35.0, 35.0, 75.0],
#  [85.0, 'Dodrio', 'NormalFlying', 460.0, 60.0, 110.0, 70.0, 60.0, 60.0, 100.0],
#  [86.0, 'Seel', 'Water', 325.0, 65.0, 45.0, 55.0, 45.0, 70.0, 45.0],
#  [87.0, 'Dewgong', 'WaterIce', 475.0, 90.0, 70.0, 80.0, 70.0, 95.0, 70.0],
#  [88.0, 'Grimer', 'Poison', 325.0, 80.0, 80.0, 50.0, 40.0, 50.0, 25.0],
#  [89.0, 'Muk', 'Poison', 500.0, 105.0, 105.0, 75.0, 65.0, 100.0, 50.0],
#  [90.0, 'Shellder', 'Water', 305.0, 30.0, 65.0, 100.0, 45.0, 25.0, 40.0],
#  [91.0, 'Cloyster', 'WaterIce', 525.0, 50.0, 95.0, 180.0, 85.0, 45.0, 70.0],
#  [92.0, 'Gastly', 'GhostPoison', 310.0, 30.0, 35.0, 30.0, 100.0, 35.0, 80.0],
#  [93.0, 'Haunter', 'GhostPoison', 405.0, 45.0, 50.0, 45.0, 115.0, 55.0, 95.0],
#  [94.0, 'Gengar', 'GhostPoison', 500.0, 60.0, 65.0, 60.0, 130.0, 75.0, 110.0],
#  [94.0,
#   'GengarMega Gengar',
#   'GhostPoison',
#   600.0,
#   60.0,
#   65.0,
#   80.0,
#   170.0,
#   95.0,
#   130.0],
#  [95.0, 'Onix', 'RockGround', 385.0, 35.0, 45.0, 160.0, 30.0, 45.0, 70.0],
#  [96.0, 'Drowzee', 'Psychic', 328.0, 60.0, 48.0, 45.0, 43.0, 90.0, 42.0],
#  [97.0, 'Hypno', 'Psychic', 483.0, 85.0, 73.0, 70.0, 73.0, 115.0, 67.0],
#  [98.0, 'Krabby', 'Water', 325.0, 30.0, 105.0, 90.0, 25.0, 25.0, 50.0],
#  [99.0, 'Kingler', 'Water', 475.0, 55.0, 130.0, 115.0, 50.0, 50.0, 75.0],
#  [100.0, 'Voltorb', 'Electric', 330.0, 40.0, 30.0, 50.0, 55.0, 55.0, 100.0],
#  [101.0, 'Electrode', 'Electric', 480.0, 60.0, 50.0, 70.0, 80.0, 80.0, 140.0],
#  [102.0,
#   'Exeggcute',
#   'GrassPsychic',
#   325.0,
#   60.0,
#   40.0,
#   80.0,
#   60.0,
#   45.0,
#   40.0],
#  [103.0,
#   'Exeggutor',
#   'GrassPsychic',
#   520.0,
#   95.0,
#   95.0,
#   85.0,
#   125.0,
#   65.0,
#   55.0],
#  [104.0, 'Cubone', 'Ground', 320.0, 50.0, 50.0, 95.0, 40.0, 50.0, 35.0],
#  [105.0, 'Marowak', 'Ground', 425.0, 60.0, 80.0, 110.0, 50.0, 80.0, 45.0],
#  [106.0, 'Hitmonlee', 'Fighting', 455.0, 50.0, 120.0, 53.0, 35.0, 110.0, 87.0],
#  [107.0,
#   'Hitmonchan',
#   'Fighting',
#   455.0,
#   50.0,
#   105.0,
#   79.0,
#   35.0,
#   110.0,
#   76.0],
#  [108.0, 'Lickitung', 'Normal', 385.0, 90.0, 55.0, 75.0, 60.0, 75.0, 30.0],
#  [109.0, 'Koffing', 'Poison', 340.0, 40.0, 65.0, 95.0, 60.0, 45.0, 35.0],
#  [110.0, 'Weezing', 'Poison', 490.0, 65.0, 90.0, 120.0, 85.0, 70.0, 60.0],
#  [111.0, 'Rhyhorn', 'GroundRock', 345.0, 80.0, 85.0, 95.0, 30.0, 30.0, 25.0],
#  [112.0, 'Rhydon', 'GroundRock', 485.0, 105.0, 130.0, 120.0, 45.0, 45.0, 40.0],
#  [113.0, 'Chansey', 'Normal', 450.0, 250.0, 5.0, 5.0, 35.0, 105.0, 50.0],
#  [114.0, 'Tangela', 'Grass', 435.0, 65.0, 55.0, 115.0, 100.0, 40.0, 60.0],
#  [115.0, 'Kangaskhan', 'Normal', 490.0, 105.0, 95.0, 80.0, 40.0, 80.0, 90.0],
#  [115.0,
#   'KangaskhanMega Kangaskhan',
#   'Normal',
#   590.0,
#   105.0,
#   125.0,
#   100.0,
#   60.0,
#   100.0,
#   100.0],
#  [116.0, 'Horsea', 'Water', 295.0, 30.0, 40.0, 70.0, 70.0, 25.0, 60.0],
#  [117.0, 'Seadra', 'Water', 440.0, 55.0, 65.0, 95.0, 95.0, 45.0, 85.0],
#  [118.0, 'Goldeen', 'Water', 320.0, 45.0, 67.0, 60.0, 35.0, 50.0, 63.0],
#  [119.0, 'Seaking', 'Water', 450.0, 80.0, 92.0, 65.0, 65.0, 80.0, 68.0],
#  [120.0, 'Staryu', 'Water', 340.0, 30.0, 45.0, 55.0, 70.0, 55.0, 85.0],
#  [121.0,
#   'Starmie',
#   'WaterPsychic',
#   520.0,
#   60.0,
#   75.0,
#   85.0,
#   100.0,
#   85.0,
#   115.0],
#  [122.0,
#   'Mr. Mime',
#   'PsychicFairy',
#   460.0,
#   40.0,
#   45.0,
#   65.0,
#   100.0,
#   120.0,
#   90.0],
#  [123.0, 'Scyther', 'BugFlying', 500.0, 70.0, 110.0, 80.0, 55.0, 80.0, 105.0],
#  [124.0, 'Jynx', 'IcePsychic', 455.0, 65.0, 50.0, 35.0, 115.0, 95.0, 95.0],
#  [125.0, 'Electabuzz', 'Electric', 490.0, 65.0, 83.0, 57.0, 95.0, 85.0, 105.0],
#  [126.0, 'Magmar', 'Fire', 495.0, 65.0, 95.0, 57.0, 100.0, 85.0, 93.0],
#  [127.0, 'Pinsir', 'Bug', 500.0, 65.0, 125.0, 100.0, 55.0, 70.0, 85.0],
#  [127.0,
#   'PinsirMega Pinsir',
#   'BugFlying',
#   600.0,
#   65.0,
#   155.0,
#   120.0,
#   65.0,
#   90.0,
#   105.0],
#  [128.0, 'Tauros', 'Normal', 490.0, 75.0, 100.0, 95.0, 40.0, 70.0, 110.0],
#  [129.0, 'Magikarp', 'Water', 200.0, 20.0, 10.0, 55.0, 15.0, 20.0, 80.0],
#  [130.0,
#   'Gyarados',
#   'WaterFlying',
#   540.0,
#   95.0,
#   125.0,
#   79.0,
#   60.0,
#   100.0,
#   81.0],
#  [130.0,
#   'GyaradosMega Gyarados',
#   'WaterDark',
#   640.0,
#   95.0,
#   155.0,
#   109.0,
#   70.0,
#   130.0,
#   81.0],
#  [131.0, 'Lapras', 'WaterIce', 535.0, 130.0, 85.0, 80.0, 85.0, 95.0, 60.0],
#  [132.0, 'Ditto', 'Normal', 288.0, 48.0, 48.0, 48.0, 48.0, 48.0, 48.0],
#  [133.0, 'Eevee', 'Normal', 325.0, 55.0, 55.0, 50.0, 45.0, 65.0, 55.0],
#  [134.0, 'Vaporeon', 'Water', 525.0, 130.0, 65.0, 60.0, 110.0, 95.0, 65.0],
#  [135.0, 'Jolteon', 'Electric', 525.0, 65.0, 65.0, 60.0, 110.0, 95.0, 130.0],
#  [136.0, 'Flareon', 'Fire', 525.0, 65.0, 130.0, 60.0, 95.0, 110.0, 65.0],
#  [137.0, 'Porygon', 'Normal', 395.0, 65.0, 60.0, 70.0, 85.0, 75.0, 40.0],
#  [138.0, 'Omanyte', 'RockWater', 355.0, 35.0, 40.0, 100.0, 90.0, 55.0, 35.0],
#  [139.0, 'Omastar', 'RockWater', 495.0, 70.0, 60.0, 125.0, 115.0, 70.0, 55.0],
#  [140.0, 'Kabuto', 'RockWater', 355.0, 30.0, 80.0, 90.0, 55.0, 45.0, 55.0],
#  [141.0, 'Kabutops', 'RockWater', 495.0, 60.0, 115.0, 105.0, 65.0, 70.0, 80.0],
#  [142.0,
#   'Aerodactyl',
#   'RockFlying',
#   515.0,
#   80.0,
#   105.0,
#   65.0,
#   60.0,
#   75.0,
#   130.0],
#  [142.0,
#   'AerodactylMega Aerodactyl',
#   'RockFlying',
#   615.0,
#   80.0,
#   135.0,
#   85.0,
#   70.0,
#   95.0,
#   150.0],
#  [143.0, 'Snorlax', 'Normal', 540.0, 160.0, 110.0, 65.0, 65.0, 110.0, 30.0],
#  [144.0, 'Articuno', 'IceFlying', 580.0, 90.0, 85.0, 100.0, 95.0, 125.0, 85.0],
#  [145.0,
#   'Zapdos',
#   'ElectricFlying',
#   580.0,
#   90.0,
#   90.0,
#   85.0,
#   125.0,
#   90.0,
#   100.0],
#  [146.0, 'Moltres', 'FireFlying', 580.0, 90.0, 100.0, 90.0, 125.0, 85.0, 90.0],
#  [147.0, 'Dratini', 'Dragon', 300.0, 41.0, 64.0, 45.0, 50.0, 50.0, 50.0],
#  [148.0, 'Dragonair', 'Dragon', 420.0, 61.0, 84.0, 65.0, 70.0, 70.0, 70.0],
#  [149.0,
#   'Dragonite',
#   'DragonFlying',
#   600.0,
#   91.0,
#   134.0,
#   95.0,
#   100.0,
#   100.0,
#   80.0],
#  [150.0, 'Mewtwo', 'Psychic', 680.0, 106.0, 110.0, 90.0, 154.0, 90.0, 130.0],
#  [150.0,
#   'MewtwoMega Mewtwo X',
#   'PsychicFighting',
#   800.0,
#   126.0,
#   190.0,
#   100.0,
#   154.0,
#   100.0,
#   130.0],
#  [150.0,
#   'MewtwoMega Mewtwo Y',
#   'Psychic',
#   780.0,
#   106.0,
#   150.0,
#   70.0,
#   194.0,
#   120.0,
#   140.0],
#  [151.0, 'Mew', 'Psychic', 600.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0],
#  [152.0, 'Chikorita', 'Grass', 318.0, 45.0, 49.0, 65.0, 49.0, 65.0, 45.0],
#  [153.0, 'Bayleef', 'Grass', 405.0, 60.0, 62.0, 80.0, 63.0, 80.0, 60.0],
#  [154.0, 'Meganium', 'Grass', 525.0, 80.0, 82.0, 100.0, 83.0, 100.0, 80.0],
#  [155.0, 'Cyndaquil', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0],
#  [156.0, 'Quilava', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0],
#  [157.0, 'Typhlosion', 'Fire', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0],
#  [158.0, 'Totodile', 'Water', 314.0, 50.0, 65.0, 64.0, 44.0, 48.0, 43.0],
#  [159.0, 'Croconaw', 'Water', 405.0, 65.0, 80.0, 80.0, 59.0, 63.0, 58.0],
#  [160.0, 'Feraligatr', 'Water', 530.0, 85.0, 105.0, 100.0, 79.0, 83.0, 78.0],
#  [161.0, 'Sentret', 'Normal', 215.0, 35.0, 46.0, 34.0, 35.0, 45.0, 20.0],
#  [162.0, 'Furret', 'Normal', 415.0, 85.0, 76.0, 64.0, 45.0, 55.0, 90.0],
#  [163.0,
#   'Hoothoot',
#   'NormalFlying',
#   262.0,
#   60.0,
#   30.0,
#   30.0,
#   36.0,
#   56.0,
#   50.0],
#  [164.0,
#   'Noctowl',
#   'NormalFlying',
#   442.0,
#   100.0,
#   50.0,
#   50.0,
#   76.0,
#   96.0,
#   70.0],
#  [165.0, 'Ledyba', 'BugFlying', 265.0, 40.0, 20.0, 30.0, 40.0, 80.0, 55.0],
#  [166.0, 'Ledian', 'BugFlying', 390.0, 55.0, 35.0, 50.0, 55.0, 110.0, 85.0],
#  [167.0, 'Spinarak', 'BugPoison', 250.0, 40.0, 60.0, 40.0, 40.0, 40.0, 30.0],
#  [168.0, 'Ariados', 'BugPoison', 390.0, 70.0, 90.0, 70.0, 60.0, 60.0, 40.0],
#  [169.0, 'Crobat', 'PoisonFlying', 535.0, 85.0, 90.0, 80.0, 70.0, 80.0, 130.0],
#  [170.0,
#   'Chinchou',
#   'WaterElectric',
#   330.0,
#   75.0,
#   38.0,
#   38.0,
#   56.0,
#   56.0,
#   67.0],
#  [171.0,
#   'Lanturn',
#   'WaterElectric',
#   460.0,
#   125.0,
#   58.0,
#   58.0,
#   76.0,
#   76.0,
#   67.0],
#  [172.0, 'Pichu', 'Electric', 205.0, 20.0, 40.0, 15.0, 35.0, 35.0, 60.0],
#  [173.0, 'Cleffa', 'Fairy', 218.0, 50.0, 25.0, 28.0, 45.0, 55.0, 15.0],
#  [174.0,
#   'Igglybuff',
#   'NormalFairy',
#   210.0,
#   90.0,
#   30.0,
#   15.0,
#   40.0,
#   20.0,
#   15.0],
#  [175.0, 'Togepi', 'Fairy', 245.0, 35.0, 20.0, 65.0, 40.0, 65.0, 20.0],
#  [176.0, 'Togetic', 'FairyFlying', 405.0, 55.0, 40.0, 85.0, 80.0, 105.0, 40.0],
#  [177.0, 'Natu', 'PsychicFlying', 320.0, 40.0, 50.0, 45.0, 70.0, 45.0, 70.0],
#  [178.0, 'Xatu', 'PsychicFlying', 470.0, 65.0, 75.0, 70.0, 95.0, 70.0, 95.0],
#  [179.0, 'Mareep', 'Electric', 280.0, 55.0, 40.0, 40.0, 65.0, 45.0, 35.0],
#  [180.0, 'Flaaffy', 'Electric', 365.0, 70.0, 55.0, 55.0, 80.0, 60.0, 45.0],
#  [181.0, 'Ampharos', 'Electric', 510.0, 90.0, 75.0, 85.0, 115.0, 90.0, 55.0],
#  [181.0,
#   'AmpharosMega Ampharos',
#   'ElectricDragon',
#   610.0,
#   90.0,
#   95.0,
#   105.0,
#   165.0,
#   110.0,
#   45.0],
#  [182.0, 'Bellossom', 'Grass', 490.0, 75.0, 80.0, 95.0, 90.0, 100.0, 50.0],
#  [183.0, 'Marill', 'WaterFairy', 250.0, 70.0, 20.0, 50.0, 20.0, 50.0, 40.0],
#  [184.0,
#   'Azumarill',
#   'WaterFairy',
#   420.0,
#   100.0,
#   50.0,
#   80.0,
#   60.0,
#   80.0,
#   50.0],
#  [185.0, 'Sudowoodo', 'Rock', 410.0, 70.0, 100.0, 115.0, 30.0, 65.0, 30.0],
#  [186.0, 'Politoed', 'Water', 500.0, 90.0, 75.0, 75.0, 90.0, 100.0, 70.0],
#  [187.0, 'Hoppip', 'GrassFlying', 250.0, 35.0, 35.0, 40.0, 35.0, 55.0, 50.0],
#  [188.0, 'Skiploom', 'GrassFlying', 340.0, 55.0, 45.0, 50.0, 45.0, 65.0, 80.0],
#  [189.0,
#   'Jumpluff',
#   'GrassFlying',
#   460.0,
#   75.0,
#   55.0,
#   70.0,
#   55.0,
#   95.0,
#   110.0],
#  [190.0, 'Aipom', 'Normal', 360.0, 55.0, 70.0, 55.0, 40.0, 55.0, 85.0],
#  [191.0, 'Sunkern', 'Grass', 180.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0],
#  [192.0, 'Sunflora', 'Grass', 425.0, 75.0, 75.0, 55.0, 105.0, 85.0, 30.0],
#  [193.0, 'Yanma', 'BugFlying', 390.0, 65.0, 65.0, 45.0, 75.0, 45.0, 95.0],
#  [194.0, 'Wooper', 'WaterGround', 210.0, 55.0, 45.0, 45.0, 25.0, 25.0, 15.0],
#  [195.0, 'Quagsire', 'WaterGround', 430.0, 95.0, 85.0, 85.0, 65.0, 65.0, 35.0],
#  [196.0, 'Espeon', 'Psychic', 525.0, 65.0, 65.0, 60.0, 130.0, 95.0, 110.0],
#  [197.0, 'Umbreon', 'Dark', 525.0, 95.0, 65.0, 110.0, 60.0, 130.0, 65.0],
#  [198.0, 'Murkrow', 'DarkFlying', 405.0, 60.0, 85.0, 42.0, 85.0, 42.0, 91.0],
#  [199.0,
#   'Slowking',
#   'WaterPsychic',
#   490.0,
#   95.0,
#   75.0,
#   80.0,
#   100.0,
#   110.0,
#   30.0],
#  [200.0, 'Misdreavus', 'Ghost', 435.0, 60.0, 60.0, 60.0, 85.0, 85.0, 85.0],
#  [201.0, 'Unown', 'Psychic', 336.0, 48.0, 72.0, 48.0, 72.0, 48.0, 48.0],
#  [202.0, 'Wobbuffet', 'Psychic', 405.0, 190.0, 33.0, 58.0, 33.0, 58.0, 33.0],
#  [203.0,
#   'Girafarig',
#   'NormalPsychic',
#   455.0,
#   70.0,
#   80.0,
#   65.0,
#   90.0,
#   65.0,
#   85.0],
#  [204.0, 'Pineco', 'Bug', 290.0, 50.0, 65.0, 90.0, 35.0, 35.0, 15.0],
#  [205.0, 'Forretress', 'BugSteel', 465.0, 75.0, 90.0, 140.0, 60.0, 60.0, 40.0],
#  [206.0, 'Dunsparce', 'Normal', 415.0, 100.0, 70.0, 70.0, 65.0, 65.0, 45.0],
#  [207.0, 'Gligar', 'GroundFlying', 430.0, 65.0, 75.0, 105.0, 35.0, 65.0, 85.0],
#  [208.0, 'Steelix', 'SteelGround', 510.0, 75.0, 85.0, 200.0, 55.0, 65.0, 30.0],
#  [208.0,
#   'SteelixMega Steelix',
#   'SteelGround',
#   610.0,
#   75.0,
#   125.0,
#   230.0,
#   55.0,
#   95.0,
#   30.0],
#  [209.0, 'Snubbull', 'Fairy', 300.0, 60.0, 80.0, 50.0, 40.0, 40.0, 30.0],
#  [210.0, 'Granbull', 'Fairy', 450.0, 90.0, 120.0, 75.0, 60.0, 60.0, 45.0],
#  [211.0, 'Qwilfish', 'WaterPoison', 430.0, 65.0, 95.0, 75.0, 55.0, 55.0, 85.0],
#  [212.0, 'Scizor', 'BugSteel', 500.0, 70.0, 130.0, 100.0, 55.0, 80.0, 65.0],
#  [212.0,
#   'ScizorMega Scizor',
#   'BugSteel',
#   600.0,
#   70.0,
#   150.0,
#   140.0,
#   65.0,
#   100.0,
#   75.0],
#  [213.0, 'Shuckle', 'BugRock', 505.0, 20.0, 10.0, 230.0, 10.0, 230.0, 5.0],
#  [214.0,
#   'Heracross',
#   'BugFighting',
#   500.0,
#   80.0,
#   125.0,
#   75.0,
#   40.0,
#   95.0,
#   85.0],
#  [214.0,
#   'HeracrossMega Heracross',
#   'BugFighting',
#   600.0,
#   80.0,
#   185.0,
#   115.0,
#   40.0,
#   105.0,
#   75.0],
#  [215.0, 'Sneasel', 'DarkIce', 430.0, 55.0, 95.0, 55.0, 35.0, 75.0, 115.0],
#  [216.0, 'Teddiursa', 'Normal', 330.0, 60.0, 80.0, 50.0, 50.0, 50.0, 40.0],
#  [217.0, 'Ursaring', 'Normal', 500.0, 90.0, 130.0, 75.0, 75.0, 75.0, 55.0],
#  [218.0, 'Slugma', 'Fire', 250.0, 40.0, 40.0, 40.0, 70.0, 40.0, 20.0],
#  [219.0, 'Magcargo', 'FireRock', 410.0, 50.0, 50.0, 120.0, 80.0, 80.0, 30.0],
#  [220.0, 'Swinub', 'IceGround', 250.0, 50.0, 50.0, 40.0, 30.0, 30.0, 50.0],
#  [221.0,
#   'Piloswine',
#   'IceGround',
#   450.0,
#   100.0,
#   100.0,
#   80.0,
#   60.0,
#   60.0,
#   50.0],
#  [222.0, 'Corsola', 'WaterRock', 380.0, 55.0, 55.0, 85.0, 65.0, 85.0, 35.0],
#  [223.0, 'Remoraid', 'Water', 300.0, 35.0, 65.0, 35.0, 65.0, 35.0, 65.0],
#  [224.0, 'Octillery', 'Water', 480.0, 75.0, 105.0, 75.0, 105.0, 75.0, 45.0],
#  [225.0, 'Delibird', 'IceFlying', 330.0, 45.0, 55.0, 45.0, 65.0, 45.0, 75.0],
#  [226.0, 'Mantine', 'WaterFlying', 465.0, 65.0, 40.0, 70.0, 80.0, 140.0, 70.0],
#  [227.0,
#   'Skarmory',
#   'SteelFlying',
#   465.0,
#   65.0,
#   80.0,
#   140.0,
#   40.0,
#   70.0,
#   70.0],
#  [228.0, 'Houndour', 'DarkFire', 330.0, 45.0, 60.0, 30.0, 80.0, 50.0, 65.0],
#  [229.0, 'Houndoom', 'DarkFire', 500.0, 75.0, 90.0, 50.0, 110.0, 80.0, 95.0],
#  [229.0,
#   'HoundoomMega Houndoom',
#   'DarkFire',
#   600.0,
#   75.0,
#   90.0,
#   90.0,
#   140.0,
#   90.0,
#   115.0],
#  [230.0, 'Kingdra', 'WaterDragon', 540.0, 75.0, 95.0, 95.0, 95.0, 95.0, 85.0],
#  [231.0, 'Phanpy', 'Ground', 330.0, 90.0, 60.0, 60.0, 40.0, 40.0, 40.0],
#  [232.0, 'Donphan', 'Ground', 500.0, 90.0, 120.0, 120.0, 60.0, 60.0, 50.0],
#  [233.0, 'Porygon2', 'Normal', 515.0, 85.0, 80.0, 90.0, 105.0, 95.0, 60.0],
#  [234.0, 'Stantler', 'Normal', 465.0, 73.0, 95.0, 62.0, 85.0, 65.0, 85.0],
#  [235.0, 'Smeargle', 'Normal', 250.0, 55.0, 20.0, 35.0, 20.0, 45.0, 75.0],
#  [236.0, 'Tyrogue', 'Fighting', 210.0, 35.0, 35.0, 35.0, 35.0, 35.0, 35.0],
#  [237.0, 'Hitmontop', 'Fighting', 455.0, 50.0, 95.0, 95.0, 35.0, 110.0, 70.0],
#  [238.0, 'Smoochum', 'IcePsychic', 305.0, 45.0, 30.0, 15.0, 85.0, 65.0, 65.0],
#  [239.0, 'Elekid', 'Electric', 360.0, 45.0, 63.0, 37.0, 65.0, 55.0, 95.0],
#  [240.0, 'Magby', 'Fire', 365.0, 45.0, 75.0, 37.0, 70.0, 55.0, 83.0],
#  [241.0, 'Miltank', 'Normal', 490.0, 95.0, 80.0, 105.0, 40.0, 70.0, 100.0],
#  [242.0, 'Blissey', 'Normal', 540.0, 255.0, 10.0, 10.0, 75.0, 135.0, 55.0],
#  [243.0, 'Raikou', 'Electric', 580.0, 90.0, 85.0, 75.0, 115.0, 100.0, 115.0],
#  [244.0, 'Entei', 'Fire', 580.0, 115.0, 115.0, 85.0, 90.0, 75.0, 100.0],
#  [245.0, 'Suicune', 'Water', 580.0, 100.0, 75.0, 115.0, 90.0, 115.0, 85.0],
#  [246.0, 'Larvitar', 'RockGround', 300.0, 50.0, 64.0, 50.0, 45.0, 50.0, 41.0],
#  [247.0, 'Pupitar', 'RockGround', 410.0, 70.0, 84.0, 70.0, 65.0, 70.0, 51.0],
#  [248.0,
#   'Tyranitar',
#   'RockDark',
#   600.0,
#   100.0,
#   134.0,
#   110.0,
#   95.0,
#   100.0,
#   61.0],
#  [248.0,
#   'TyranitarMega Tyranitar',
#   'RockDark',
#   700.0,
#   100.0,
#   164.0,
#   150.0,
#   95.0,
#   120.0,
#   71.0],
#  [249.0,
#   'Lugia',
#   'PsychicFlying',
#   680.0,
#   106.0,
#   90.0,
#   130.0,
#   90.0,
#   154.0,
#   110.0],
#  [250.0, 'Ho-oh', 'FireFlying', 680.0, 106.0, 130.0, 90.0, 110.0, 154.0, 90.0],
#  [251.0,
#   'Celebi',
#   'PsychicGrass',
#   600.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0],
#  [252.0, 'Treecko', 'Grass', 310.0, 40.0, 45.0, 35.0, 65.0, 55.0, 70.0],
#  [253.0, 'Grovyle', 'Grass', 405.0, 50.0, 65.0, 45.0, 85.0, 65.0, 95.0],
#  [254.0, 'Sceptile', 'Grass', 530.0, 70.0, 85.0, 65.0, 105.0, 85.0, 120.0],
#  [254.0,
#   'SceptileMega Sceptile',
#   'GrassDragon',
#   630.0,
#   70.0,
#   110.0,
#   75.0,
#   145.0,
#   85.0,
#   145.0],
#  [255.0, 'Torchic', 'Fire', 310.0, 45.0, 60.0, 40.0, 70.0, 50.0, 45.0],
#  [256.0,
#   'Combusken',
#   'FireFighting',
#   405.0,
#   60.0,
#   85.0,
#   60.0,
#   85.0,
#   60.0,
#   55.0],
#  [257.0,
#   'Blaziken',
#   'FireFighting',
#   530.0,
#   80.0,
#   120.0,
#   70.0,
#   110.0,
#   70.0,
#   80.0],
#  [257.0,
#   'BlazikenMega Blaziken',
#   'FireFighting',
#   630.0,
#   80.0,
#   160.0,
#   80.0,
#   130.0,
#   80.0,
#   100.0],
#  [258.0, 'Mudkip', 'Water', 310.0, 50.0, 70.0, 50.0, 50.0, 50.0, 40.0],
#  [259.0,
#   'Marshtomp',
#   'WaterGround',
#   405.0,
#   70.0,
#   85.0,
#   70.0,
#   60.0,
#   70.0,
#   50.0],
#  [260.0,
#   'Swampert',
#   'WaterGround',
#   535.0,
#   100.0,
#   110.0,
#   90.0,
#   85.0,
#   90.0,
#   60.0],
#  [260.0,
#   'SwampertMega Swampert',
#   'WaterGround',
#   635.0,
#   100.0,
#   150.0,
#   110.0,
#   95.0,
#   110.0,
#   70.0],
#  [261.0, 'Poochyena', 'Dark', 220.0, 35.0, 55.0, 35.0, 30.0, 30.0, 35.0],
#  [262.0, 'Mightyena', 'Dark', 420.0, 70.0, 90.0, 70.0, 60.0, 60.0, 70.0],
#  [263.0, 'Zigzagoon', 'Normal', 240.0, 38.0, 30.0, 41.0, 30.0, 41.0, 60.0],
#  [264.0, 'Linoone', 'Normal', 420.0, 78.0, 70.0, 61.0, 50.0, 61.0, 100.0],
#  [265.0, 'Wurmple', 'Bug', 195.0, 45.0, 45.0, 35.0, 20.0, 30.0, 20.0],
#  [266.0, 'Silcoon', 'Bug', 205.0, 50.0, 35.0, 55.0, 25.0, 25.0, 15.0],
#  [267.0, 'Beautifly', 'BugFlying', 395.0, 60.0, 70.0, 50.0, 100.0, 50.0, 65.0],
#  [268.0, 'Cascoon', 'Bug', 205.0, 50.0, 35.0, 55.0, 25.0, 25.0, 15.0],
#  [269.0, 'Dustox', 'BugPoison', 385.0, 60.0, 50.0, 70.0, 50.0, 90.0, 65.0],
#  [270.0, 'Lotad', 'WaterGrass', 220.0, 40.0, 30.0, 30.0, 40.0, 50.0, 30.0],
#  [271.0, 'Lombre', 'WaterGrass', 340.0, 60.0, 50.0, 50.0, 60.0, 70.0, 50.0],
#  [272.0, 'Ludicolo', 'WaterGrass', 480.0, 80.0, 70.0, 70.0, 90.0, 100.0, 70.0],
#  [273.0, 'Seedot', 'Grass', 220.0, 40.0, 40.0, 50.0, 30.0, 30.0, 30.0],
#  [274.0, 'Nuzleaf', 'GrassDark', 340.0, 70.0, 70.0, 40.0, 60.0, 40.0, 60.0],
#  [275.0, 'Shiftry', 'GrassDark', 480.0, 90.0, 100.0, 60.0, 90.0, 60.0, 80.0],
#  [276.0, 'Taillow', 'NormalFlying', 270.0, 40.0, 55.0, 30.0, 30.0, 30.0, 85.0],
#  [277.0,
#   'Swellow',
#   'NormalFlying',
#   430.0,
#   60.0,
#   85.0,
#   60.0,
#   50.0,
#   50.0,
#   125.0],
#  [278.0, 'Wingull', 'WaterFlying', 270.0, 40.0, 30.0, 30.0, 55.0, 30.0, 85.0],
#  [279.0,
#   'Pelipper',
#   'WaterFlying',
#   430.0,
#   60.0,
#   50.0,
#   100.0,
#   85.0,
#   70.0,
#   65.0],
#  [280.0, 'Ralts', 'PsychicFairy', 198.0, 28.0, 25.0, 25.0, 45.0, 35.0, 40.0],
#  [281.0, 'Kirlia', 'PsychicFairy', 278.0, 38.0, 35.0, 35.0, 65.0, 55.0, 50.0],
#  [282.0,
#   'Gardevoir',
#   'PsychicFairy',
#   518.0,
#   68.0,
#   65.0,
#   65.0,
#   125.0,
#   115.0,
#   80.0],
#  [282.0,
#   'GardevoirMega Gardevoir',
#   'PsychicFairy',
#   618.0,
#   68.0,
#   85.0,
#   65.0,
#   165.0,
#   135.0,
#   100.0],
#  [283.0, 'Surskit', 'BugWater', 269.0, 40.0, 30.0, 32.0, 50.0, 52.0, 65.0],
#  [284.0, 'Masquerain', 'BugFlying', 414.0, 70.0, 60.0, 62.0, 80.0, 82.0, 60.0],
#  [285.0, 'Shroomish', 'Grass', 295.0, 60.0, 40.0, 60.0, 40.0, 60.0, 35.0],
#  [286.0,
#   'Breloom',
#   'GrassFighting',
#   460.0,
#   60.0,
#   130.0,
#   80.0,
#   60.0,
#   60.0,
#   70.0],
#  [287.0, 'Slakoth', 'Normal', 280.0, 60.0, 60.0, 60.0, 35.0, 35.0, 30.0],
#  [288.0, 'Vigoroth', 'Normal', 440.0, 80.0, 80.0, 80.0, 55.0, 55.0, 90.0],
#  [289.0, 'Slaking', 'Normal', 670.0, 150.0, 160.0, 100.0, 95.0, 65.0, 100.0],
#  [290.0, 'Nincada', 'BugGround', 266.0, 31.0, 45.0, 90.0, 30.0, 30.0, 40.0],
#  [291.0, 'Ninjask', 'BugFlying', 456.0, 61.0, 90.0, 45.0, 50.0, 50.0, 160.0],
#  [292.0, 'Shedinja', 'BugGhost', 236.0, 1.0, 90.0, 45.0, 30.0, 30.0, 40.0],
#  [293.0, 'Whismur', 'Normal', 240.0, 64.0, 51.0, 23.0, 51.0, 23.0, 28.0],
#  [294.0, 'Loudred', 'Normal', 360.0, 84.0, 71.0, 43.0, 71.0, 43.0, 48.0],
#  [295.0, 'Exploud', 'Normal', 490.0, 104.0, 91.0, 63.0, 91.0, 73.0, 68.0],
#  [296.0, 'Makuhita', 'Fighting', 237.0, 72.0, 60.0, 30.0, 20.0, 30.0, 25.0],
#  [297.0, 'Hariyama', 'Fighting', 474.0, 144.0, 120.0, 60.0, 40.0, 60.0, 50.0],
#  [298.0, 'Azurill', 'NormalFairy', 190.0, 50.0, 20.0, 40.0, 20.0, 40.0, 20.0],
#  [299.0, 'Nosepass', 'Rock', 375.0, 30.0, 45.0, 135.0, 45.0, 90.0, 30.0],
#  [300.0, 'Skitty', 'Normal', 260.0, 50.0, 45.0, 45.0, 35.0, 35.0, 50.0],
#  [301.0, 'Delcatty', 'Normal', 380.0, 70.0, 65.0, 65.0, 55.0, 55.0, 70.0],
#  [302.0, 'Sableye', 'DarkGhost', 380.0, 50.0, 75.0, 75.0, 65.0, 65.0, 50.0],
#  [302.0,
#   'SableyeMega Sableye',
#   'DarkGhost',
#   480.0,
#   50.0,
#   85.0,
#   125.0,
#   85.0,
#   115.0,
#   20.0],
#  [303.0, 'Mawile', 'SteelFairy', 380.0, 50.0, 85.0, 85.0, 55.0, 55.0, 50.0],
#  [303.0,
#   'MawileMega Mawile',
#   'SteelFairy',
#   480.0,
#   50.0,
#   105.0,
#   125.0,
#   55.0,
#   95.0,
#   50.0],
#  [304.0, 'Aron', 'SteelRock', 330.0, 50.0, 70.0, 100.0, 40.0, 40.0, 30.0],
#  [305.0, 'Lairon', 'SteelRock', 430.0, 60.0, 90.0, 140.0, 50.0, 50.0, 40.0],
#  [306.0, 'Aggron', 'SteelRock', 530.0, 70.0, 110.0, 180.0, 60.0, 60.0, 50.0],
#  [306.0,
#   'AggronMega Aggron',
#   'Steel',
#   630.0,
#   70.0,
#   140.0,
#   230.0,
#   60.0,
#   80.0,
#   50.0],
#  [307.0,
#   'Meditite',
#   'FightingPsychic',
#   280.0,
#   30.0,
#   40.0,
#   55.0,
#   40.0,
#   55.0,
#   60.0],
#  [308.0,
#   'Medicham',
#   'FightingPsychic',
#   410.0,
#   60.0,
#   60.0,
#   75.0,
#   60.0,
#   75.0,
#   80.0],
#  [308.0,
#   'MedichamMega Medicham',
#   'FightingPsychic',
#   510.0,
#   60.0,
#   100.0,
#   85.0,
#   80.0,
#   85.0,
#   100.0],
#  [309.0, 'Electrike', 'Electric', 295.0, 40.0, 45.0, 40.0, 65.0, 40.0, 65.0],
#  [310.0, 'Manectric', 'Electric', 475.0, 70.0, 75.0, 60.0, 105.0, 60.0, 105.0],
#  [310.0,
#   'ManectricMega Manectric',
#   'Electric',
#   575.0,
#   70.0,
#   75.0,
#   80.0,
#   135.0,
#   80.0,
#   135.0],
#  [311.0, 'Plusle', 'Electric', 405.0, 60.0, 50.0, 40.0, 85.0, 75.0, 95.0],
#  [312.0, 'Minun', 'Electric', 405.0, 60.0, 40.0, 50.0, 75.0, 85.0, 95.0],
#  [313.0, 'Volbeat', 'Bug', 400.0, 65.0, 73.0, 55.0, 47.0, 75.0, 85.0],
#  [314.0, 'Illumise', 'Bug', 400.0, 65.0, 47.0, 55.0, 73.0, 75.0, 85.0],
#  [315.0, 'Roselia', 'GrassPoison', 400.0, 50.0, 60.0, 45.0, 100.0, 80.0, 65.0],
#  [316.0, 'Gulpin', 'Poison', 302.0, 70.0, 43.0, 53.0, 43.0, 53.0, 40.0],
#  [317.0, 'Swalot', 'Poison', 467.0, 100.0, 73.0, 83.0, 73.0, 83.0, 55.0],
#  [318.0, 'Carvanha', 'WaterDark', 305.0, 45.0, 90.0, 20.0, 65.0, 20.0, 65.0],
#  [319.0, 'Sharpedo', 'WaterDark', 460.0, 70.0, 120.0, 40.0, 95.0, 40.0, 95.0],
#  [319.0,
#   'SharpedoMega Sharpedo',
#   'WaterDark',
#   560.0,
#   70.0,
#   140.0,
#   70.0,
#   110.0,
#   65.0,
#   105.0],
#  [320.0, 'Wailmer', 'Water', 400.0, 130.0, 70.0, 35.0, 70.0, 35.0, 60.0],
#  [321.0, 'Wailord', 'Water', 500.0, 170.0, 90.0, 45.0, 90.0, 45.0, 60.0],
#  [322.0, 'Numel', 'FireGround', 305.0, 60.0, 60.0, 40.0, 65.0, 45.0, 35.0],
#  [323.0,
#   'Camerupt',
#   'FireGround',
#   460.0,
#   70.0,
#   100.0,
#   70.0,
#   105.0,
#   75.0,
#   40.0],
#  [323.0,
#   'CameruptMega Camerupt',
#   'FireGround',
#   560.0,
#   70.0,
#   120.0,
#   100.0,
#   145.0,
#   105.0,
#   20.0],
#  [324.0, 'Torkoal', 'Fire', 470.0, 70.0, 85.0, 140.0, 85.0, 70.0, 20.0],
#  [325.0, 'Spoink', 'Psychic', 330.0, 60.0, 25.0, 35.0, 70.0, 80.0, 60.0],
#  [326.0, 'Grumpig', 'Psychic', 470.0, 80.0, 45.0, 65.0, 90.0, 110.0, 80.0],
#  [327.0, 'Spinda', 'Normal', 360.0, 60.0, 60.0, 60.0, 60.0, 60.0, 60.0],
#  [328.0, 'Trapinch', 'Ground', 290.0, 45.0, 100.0, 45.0, 45.0, 45.0, 10.0],
#  [329.0, 'Vibrava', 'GroundDragon', 340.0, 50.0, 70.0, 50.0, 50.0, 50.0, 70.0],
#  [330.0,
#   'Flygon',
#   'GroundDragon',
#   520.0,
#   80.0,
#   100.0,
#   80.0,
#   80.0,
#   80.0,
#   100.0],
#  [331.0, 'Cacnea', 'Grass', 335.0, 50.0, 85.0, 40.0, 85.0, 40.0, 35.0],
#  [332.0, 'Cacturne', 'GrassDark', 475.0, 70.0, 115.0, 60.0, 115.0, 60.0, 55.0],
#  [333.0, 'Swablu', 'NormalFlying', 310.0, 45.0, 40.0, 60.0, 40.0, 75.0, 50.0],
#  [334.0,
#   'Altaria',
#   'DragonFlying',
#   490.0,
#   75.0,
#   70.0,
#   90.0,
#   70.0,
#   105.0,
#   80.0],
#  [334.0,
#   'AltariaMega Altaria',
#   'DragonFairy',
#   590.0,
#   75.0,
#   110.0,
#   110.0,
#   110.0,
#   105.0,
#   80.0],
#  [335.0, 'Zangoose', 'Normal', 458.0, 73.0, 115.0, 60.0, 60.0, 60.0, 90.0],
#  [336.0, 'Seviper', 'Poison', 458.0, 73.0, 100.0, 60.0, 100.0, 60.0, 65.0],
#  [337.0, 'Lunatone', 'RockPsychic', 440.0, 70.0, 55.0, 65.0, 95.0, 85.0, 70.0],
#  [338.0, 'Solrock', 'RockPsychic', 440.0, 70.0, 95.0, 85.0, 55.0, 65.0, 70.0],
#  [339.0, 'Barboach', 'WaterGround', 288.0, 50.0, 48.0, 43.0, 46.0, 41.0, 60.0],
#  [340.0,
#   'Whiscash',
#   'WaterGround',
#   468.0,
#   110.0,
#   78.0,
#   73.0,
#   76.0,
#   71.0,
#   60.0],
#  [341.0, 'Corphish', 'Water', 308.0, 43.0, 80.0, 65.0, 50.0, 35.0, 35.0],
#  [342.0, 'Crawdaunt', 'WaterDark', 468.0, 63.0, 120.0, 85.0, 90.0, 55.0, 55.0],
#  [343.0, 'Baltoy', 'GroundPsychic', 300.0, 40.0, 40.0, 55.0, 40.0, 70.0, 55.0],
#  [344.0,
#   'Claydol',
#   'GroundPsychic',
#   500.0,
#   60.0,
#   70.0,
#   105.0,
#   70.0,
#   120.0,
#   75.0],
#  [345.0, 'Lileep', 'RockGrass', 355.0, 66.0, 41.0, 77.0, 61.0, 87.0, 23.0],
#  [346.0, 'Cradily', 'RockGrass', 495.0, 86.0, 81.0, 97.0, 81.0, 107.0, 43.0],
#  [347.0, 'Anorith', 'RockBug', 355.0, 45.0, 95.0, 50.0, 40.0, 50.0, 75.0],
#  [348.0, 'Armaldo', 'RockBug', 495.0, 75.0, 125.0, 100.0, 70.0, 80.0, 45.0],
#  [349.0, 'Feebas', 'Water', 200.0, 20.0, 15.0, 20.0, 10.0, 55.0, 80.0],
#  [350.0, 'Milotic', 'Water', 540.0, 95.0, 60.0, 79.0, 100.0, 125.0, 81.0],
#  [351.0, 'Castform', 'Normal', 420.0, 70.0, 70.0, 70.0, 70.0, 70.0, 70.0],
#  [352.0, 'Kecleon', 'Normal', 440.0, 60.0, 90.0, 70.0, 60.0, 120.0, 40.0],
#  [353.0, 'Shuppet', 'Ghost', 295.0, 44.0, 75.0, 35.0, 63.0, 33.0, 45.0],
#  [354.0, 'Banette', 'Ghost', 455.0, 64.0, 115.0, 65.0, 83.0, 63.0, 65.0],
#  [354.0,
#   'BanetteMega Banette',
#   'Ghost',
#   555.0,
#   64.0,
#   165.0,
#   75.0,
#   93.0,
#   83.0,
#   75.0],
#  [355.0, 'Duskull', 'Ghost', 295.0, 20.0, 40.0, 90.0, 30.0, 90.0, 25.0],
#  [356.0, 'Dusclops', 'Ghost', 455.0, 40.0, 70.0, 130.0, 60.0, 130.0, 25.0],
#  [357.0, 'Tropius', 'GrassFlying', 460.0, 99.0, 68.0, 83.0, 72.0, 87.0, 51.0],
#  [358.0, 'Chimecho', 'Psychic', 425.0, 65.0, 50.0, 70.0, 95.0, 80.0, 65.0],
#  [359.0, 'Absol', 'Dark', 465.0, 65.0, 130.0, 60.0, 75.0, 60.0, 75.0],
#  [359.0,
#   'AbsolMega Absol',
#   'Dark',
#   565.0,
#   65.0,
#   150.0,
#   60.0,
#   115.0,
#   60.0,
#   115.0],
#  [360.0, 'Wynaut', 'Psychic', 260.0, 95.0, 23.0, 48.0, 23.0, 48.0, 23.0],
#  [361.0, 'Snorunt', 'Ice', 300.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0],
#  [362.0, 'Glalie', 'Ice', 480.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0],
#  [362.0,
#   'GlalieMega Glalie',
#   'Ice',
#   580.0,
#   80.0,
#   120.0,
#   80.0,
#   120.0,
#   80.0,
#   100.0],
#  [363.0, 'Spheal', 'IceWater', 290.0, 70.0, 40.0, 50.0, 55.0, 50.0, 25.0],
#  [364.0, 'Sealeo', 'IceWater', 410.0, 90.0, 60.0, 70.0, 75.0, 70.0, 45.0],
#  [365.0, 'Walrein', 'IceWater', 530.0, 110.0, 80.0, 90.0, 95.0, 90.0, 65.0],
#  [366.0, 'Clamperl', 'Water', 345.0, 35.0, 64.0, 85.0, 74.0, 55.0, 32.0],
#  [367.0, 'Huntail', 'Water', 485.0, 55.0, 104.0, 105.0, 94.0, 75.0, 52.0],
#  [368.0, 'Gorebyss', 'Water', 485.0, 55.0, 84.0, 105.0, 114.0, 75.0, 52.0],
#  [369.0,
#   'Relicanth',
#   'WaterRock',
#   485.0,
#   100.0,
#   90.0,
#   130.0,
#   45.0,
#   65.0,
#   55.0],
#  [370.0, 'Luvdisc', 'Water', 330.0, 43.0, 30.0, 55.0, 40.0, 65.0, 97.0],
#  [371.0, 'Bagon', 'Dragon', 300.0, 45.0, 75.0, 60.0, 40.0, 30.0, 50.0],
#  [372.0, 'Shelgon', 'Dragon', 420.0, 65.0, 95.0, 100.0, 60.0, 50.0, 50.0],
#  [373.0,
#   'Salamence',
#   'DragonFlying',
#   600.0,
#   95.0,
#   135.0,
#   80.0,
#   110.0,
#   80.0,
#   100.0],
#  [373.0,
#   'SalamenceMega Salamence',
#   'DragonFlying',
#   700.0,
#   95.0,
#   145.0,
#   130.0,
#   120.0,
#   90.0,
#   120.0],
#  [374.0, 'Beldum', 'SteelPsychic', 300.0, 40.0, 55.0, 80.0, 35.0, 60.0, 30.0],
#  [375.0, 'Metang', 'SteelPsychic', 420.0, 60.0, 75.0, 100.0, 55.0, 80.0, 50.0],
#  [376.0,
#   'Metagross',
#   'SteelPsychic',
#   600.0,
#   80.0,
#   135.0,
#   130.0,
#   95.0,
#   90.0,
#   70.0],
#  [376.0,
#   'MetagrossMega Metagross',
#   'SteelPsychic',
#   700.0,
#   80.0,
#   145.0,
#   150.0,
#   105.0,
#   110.0,
#   110.0],
#  [377.0, 'Regirock', 'Rock', 580.0, 80.0, 100.0, 200.0, 50.0, 100.0, 50.0],
#  [378.0, 'Regice', 'Ice', 580.0, 80.0, 50.0, 100.0, 100.0, 200.0, 50.0],
#  [379.0, 'Registeel', 'Steel', 580.0, 80.0, 75.0, 150.0, 75.0, 150.0, 50.0],
#  [380.0,
#   'Latias',
#   'DragonPsychic',
#   600.0,
#   80.0,
#   80.0,
#   90.0,
#   110.0,
#   130.0,
#   110.0],
#  [380.0,
#   'LatiasMega Latias',
#   'DragonPsychic',
#   700.0,
#   80.0,
#   100.0,
#   120.0,
#   140.0,
#   150.0,
#   110.0],
#  [381.0,
#   'Latios',
#   'DragonPsychic',
#   600.0,
#   80.0,
#   90.0,
#   80.0,
#   130.0,
#   110.0,
#   110.0],
#  [381.0,
#   'LatiosMega Latios',
#   'DragonPsychic',
#   700.0,
#   80.0,
#   130.0,
#   100.0,
#   160.0,
#   120.0,
#   110.0],
#  [382.0, 'Kyogre', 'Water', 670.0, 100.0, 100.0, 90.0, 150.0, 140.0, 90.0],
#  [382.0,
#   'KyogrePrimal Kyogre',
#   'Water',
#   770.0,
#   100.0,
#   150.0,
#   90.0,
#   180.0,
#   160.0,
#   90.0],
#  [383.0, 'Groudon', 'Ground', 670.0, 100.0, 150.0, 140.0, 100.0, 90.0, 90.0],
#  [383.0,
#   'GroudonPrimal Groudon',
#   'GroundFire',
#   770.0,
#   100.0,
#   180.0,
#   160.0,
#   150.0,
#   90.0,
#   90.0],
#  [384.0,
#   'Rayquaza',
#   'DragonFlying',
#   680.0,
#   105.0,
#   150.0,
#   90.0,
#   150.0,
#   90.0,
#   95.0],
#  [384.0,
#   'RayquazaMega Rayquaza',
#   'DragonFlying',
#   780.0,
#   105.0,
#   180.0,
#   100.0,
#   180.0,
#   100.0,
#   115.0],
#  [385.0,
#   'Jirachi',
#   'SteelPsychic',
#   600.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0],
#  [386.0,
#   'DeoxysNormal Forme',
#   'Psychic',
#   600.0,
#   50.0,
#   150.0,
#   50.0,
#   150.0,
#   50.0,
#   150.0],
#  [386.0,
#   'DeoxysAttack Forme',
#   'Psychic',
#   600.0,
#   50.0,
#   180.0,
#   20.0,
#   180.0,
#   20.0,
#   150.0],
#  [386.0,
#   'DeoxysDefense Forme',
#   'Psychic',
#   600.0,
#   50.0,
#   70.0,
#   160.0,
#   70.0,
#   160.0,
#   90.0],
#  [386.0,
#   'DeoxysSpeed Forme',
#   'Psychic',
#   600.0,
#   50.0,
#   95.0,
#   90.0,
#   95.0,
#   90.0,
#   180.0],
#  [387.0, 'Turtwig', 'Grass', 318.0, 55.0, 68.0, 64.0, 45.0, 55.0, 31.0],
#  [388.0, 'Grotle', 'Grass', 405.0, 75.0, 89.0, 85.0, 55.0, 65.0, 36.0],
#  [389.0,
#   'Torterra',
#   'GrassGround',
#   525.0,
#   95.0,
#   109.0,
#   105.0,
#   75.0,
#   85.0,
#   56.0],
#  [390.0, 'Chimchar', 'Fire', 309.0, 44.0, 58.0, 44.0, 58.0, 44.0, 61.0],
#  [391.0,
#   'Monferno',
#   'FireFighting',
#   405.0,
#   64.0,
#   78.0,
#   52.0,
#   78.0,
#   52.0,
#   81.0],
#  [392.0,
#   'Infernape',
#   'FireFighting',
#   534.0,
#   76.0,
#   104.0,
#   71.0,
#   104.0,
#   71.0,
#   108.0],
#  [393.0, 'Piplup', 'Water', 314.0, 53.0, 51.0, 53.0, 61.0, 56.0, 40.0],
#  [394.0, 'Prinplup', 'Water', 405.0, 64.0, 66.0, 68.0, 81.0, 76.0, 50.0],
#  [395.0,
#   'Empoleon',
#   'WaterSteel',
#   530.0,
#   84.0,
#   86.0,
#   88.0,
#   111.0,
#   101.0,
#   60.0],
#  [396.0, 'Starly', 'NormalFlying', 245.0, 40.0, 55.0, 30.0, 30.0, 30.0, 60.0],
#  [397.0,
#   'Staravia',
#   'NormalFlying',
#   340.0,
#   55.0,
#   75.0,
#   50.0,
#   40.0,
#   40.0,
#   80.0],
#  [398.0,
#   'Staraptor',
#   'NormalFlying',
#   485.0,
#   85.0,
#   120.0,
#   70.0,
#   50.0,
#   60.0,
#   100.0],
#  [399.0, 'Bidoof', 'Normal', 250.0, 59.0, 45.0, 40.0, 35.0, 40.0, 31.0],
#  [400.0, 'Bibarel', 'NormalWater', 410.0, 79.0, 85.0, 60.0, 55.0, 60.0, 71.0],
#  [401.0, 'Kricketot', 'Bug', 194.0, 37.0, 25.0, 41.0, 25.0, 41.0, 25.0],
#  [402.0, 'Kricketune', 'Bug', 384.0, 77.0, 85.0, 51.0, 55.0, 51.0, 65.0],
#  [403.0, 'Shinx', 'Electric', 263.0, 45.0, 65.0, 34.0, 40.0, 34.0, 45.0],
#  [404.0, 'Luxio', 'Electric', 363.0, 60.0, 85.0, 49.0, 60.0, 49.0, 60.0],
#  [405.0, 'Luxray', 'Electric', 523.0, 80.0, 120.0, 79.0, 95.0, 79.0, 70.0],
#  [406.0, 'Budew', 'GrassPoison', 280.0, 40.0, 30.0, 35.0, 50.0, 70.0, 55.0],
#  [407.0,
#   'Roserade',
#   'GrassPoison',
#   515.0,
#   60.0,
#   70.0,
#   65.0,
#   125.0,
#   105.0,
#   90.0],
#  [408.0, 'Cranidos', 'Rock', 350.0, 67.0, 125.0, 40.0, 30.0, 30.0, 58.0],
#  [409.0, 'Rampardos', 'Rock', 495.0, 97.0, 165.0, 60.0, 65.0, 50.0, 58.0],
#  [410.0, 'Shieldon', 'RockSteel', 350.0, 30.0, 42.0, 118.0, 42.0, 88.0, 30.0],
#  [411.0,
#   'Bastiodon',
#   'RockSteel',
#   495.0,
#   60.0,
#   52.0,
#   168.0,
#   47.0,
#   138.0,
#   30.0],
#  [412.0, 'Burmy', 'Bug', 224.0, 40.0, 29.0, 45.0, 29.0, 45.0, 36.0],
#  [413.0,
#   'WormadamPlant Cloak',
#   'BugGrass',
#   424.0,
#   60.0,
#   59.0,
#   85.0,
#   79.0,
#   105.0,
#   36.0],
#  [413.0,
#   'WormadamSandy Cloak',
#   'BugGround',
#   424.0,
#   60.0,
#   79.0,
#   105.0,
#   59.0,
#   85.0,
#   36.0],
#  [413.0,
#   'WormadamTrash Cloak',
#   'BugSteel',
#   424.0,
#   60.0,
#   69.0,
#   95.0,
#   69.0,
#   95.0,
#   36.0],
#  [414.0, 'Mothim', 'BugFlying', 424.0, 70.0, 94.0, 50.0, 94.0, 50.0, 66.0],
#  [415.0, 'Combee', 'BugFlying', 244.0, 30.0, 30.0, 42.0, 30.0, 42.0, 70.0],
#  [416.0,
#   'Vespiquen',
#   'BugFlying',
#   474.0,
#   70.0,
#   80.0,
#   102.0,
#   80.0,
#   102.0,
#   40.0],
#  [417.0, 'Pachirisu', 'Electric', 405.0, 60.0, 45.0, 70.0, 45.0, 90.0, 95.0],
#  [418.0, 'Buizel', 'Water', 330.0, 55.0, 65.0, 35.0, 60.0, 30.0, 85.0],
#  [419.0, 'Floatzel', 'Water', 495.0, 85.0, 105.0, 55.0, 85.0, 50.0, 115.0],
#  [420.0, 'Cherubi', 'Grass', 275.0, 45.0, 35.0, 45.0, 62.0, 53.0, 35.0],
#  [421.0, 'Cherrim', 'Grass', 450.0, 70.0, 60.0, 70.0, 87.0, 78.0, 85.0],
#  [422.0, 'Shellos', 'Water', 325.0, 76.0, 48.0, 48.0, 57.0, 62.0, 34.0],
#  [423.0,
#   'Gastrodon',
#   'WaterGround',
#   475.0,
#   111.0,
#   83.0,
#   68.0,
#   92.0,
#   82.0,
#   39.0],
#  [424.0, 'Ambipom', 'Normal', 482.0, 75.0, 100.0, 66.0, 60.0, 66.0, 115.0],
#  [425.0, 'Drifloon', 'GhostFlying', 348.0, 90.0, 50.0, 34.0, 60.0, 44.0, 70.0],
#  [426.0,
#   'Drifblim',
#   'GhostFlying',
#   498.0,
#   150.0,
#   80.0,
#   44.0,
#   90.0,
#   54.0,
#   80.0],
#  [427.0, 'Buneary', 'Normal', 350.0, 55.0, 66.0, 44.0, 44.0, 56.0, 85.0],
#  [428.0, 'Lopunny', 'Normal', 480.0, 65.0, 76.0, 84.0, 54.0, 96.0, 105.0],
#  [428.0,
#   'LopunnyMega Lopunny',
#   'NormalFighting',
#   580.0,
#   65.0,
#   136.0,
#   94.0,
#   54.0,
#   96.0,
#   135.0],
#  [429.0, 'Mismagius', 'Ghost', 495.0, 60.0, 60.0, 60.0, 105.0, 105.0, 105.0],
#  [430.0,
#   'Honchkrow',
#   'DarkFlying',
#   505.0,
#   100.0,
#   125.0,
#   52.0,
#   105.0,
#   52.0,
#   71.0],
#  [431.0, 'Glameow', 'Normal', 310.0, 49.0, 55.0, 42.0, 42.0, 37.0, 85.0],
#  [432.0, 'Purugly', 'Normal', 452.0, 71.0, 82.0, 64.0, 64.0, 59.0, 112.0],
#  [433.0, 'Chingling', 'Psychic', 285.0, 45.0, 30.0, 50.0, 65.0, 50.0, 45.0],
#  [434.0, 'Stunky', 'PoisonDark', 329.0, 63.0, 63.0, 47.0, 41.0, 41.0, 74.0],
#  [435.0, 'Skuntank', 'PoisonDark', 479.0, 103.0, 93.0, 67.0, 71.0, 61.0, 84.0],
#  [436.0, 'Bronzor', 'SteelPsychic', 300.0, 57.0, 24.0, 86.0, 24.0, 86.0, 23.0],
#  [437.0,
#   'Bronzong',
#   'SteelPsychic',
#   500.0,
#   67.0,
#   89.0,
#   116.0,
#   79.0,
#   116.0,
#   33.0],
#  [438.0, 'Bonsly', 'Rock', 290.0, 50.0, 80.0, 95.0, 10.0, 45.0, 10.0],
#  [439.0,
#   'Mime Jr.',
#   'PsychicFairy',
#   310.0,
#   20.0,
#   25.0,
#   45.0,
#   70.0,
#   90.0,
#   60.0],
#  [440.0, 'Happiny', 'Normal', 220.0, 100.0, 5.0, 5.0, 15.0, 65.0, 30.0],
#  [441.0, 'Chatot', 'NormalFlying', 411.0, 76.0, 65.0, 45.0, 92.0, 42.0, 91.0],
#  [442.0,
#   'Spiritomb',
#   'GhostDark',
#   485.0,
#   50.0,
#   92.0,
#   108.0,
#   92.0,
#   108.0,
#   35.0],
#  [443.0, 'Gible', 'DragonGround', 300.0, 58.0, 70.0, 45.0, 40.0, 45.0, 42.0],
#  [444.0, 'Gabite', 'DragonGround', 410.0, 68.0, 90.0, 65.0, 50.0, 55.0, 82.0],
#  [445.0,
#   'Garchomp',
#   'DragonGround',
#   600.0,
#   108.0,
#   130.0,
#   95.0,
#   80.0,
#   85.0,
#   102.0],
#  [445.0,
#   'GarchompMega Garchomp',
#   'DragonGround',
#   700.0,
#   108.0,
#   170.0,
#   115.0,
#   120.0,
#   95.0,
#   92.0],
#  [446.0, 'Munchlax', 'Normal', 390.0, 135.0, 85.0, 40.0, 40.0, 85.0, 5.0],
#  [447.0, 'Riolu', 'Fighting', 285.0, 40.0, 70.0, 40.0, 35.0, 40.0, 60.0],
#  [448.0,
#   'Lucario',
#   'FightingSteel',
#   525.0,
#   70.0,
#   110.0,
#   70.0,
#   115.0,
#   70.0,
#   90.0],
#  [448.0,
#   'LucarioMega Lucario',
#   'FightingSteel',
#   625.0,
#   70.0,
#   145.0,
#   88.0,
#   140.0,
#   70.0,
#   112.0],
#  [449.0, 'Hippopotas', 'Ground', 330.0, 68.0, 72.0, 78.0, 38.0, 42.0, 32.0],
#  [450.0, 'Hippowdon', 'Ground', 525.0, 108.0, 112.0, 118.0, 68.0, 72.0, 47.0],
#  [451.0, 'Skorupi', 'PoisonBug', 330.0, 40.0, 50.0, 90.0, 30.0, 55.0, 65.0],
#  [452.0, 'Drapion', 'PoisonDark', 500.0, 70.0, 90.0, 110.0, 60.0, 75.0, 95.0],
#  [453.0,
#   'Croagunk',
#   'PoisonFighting',
#   300.0,
#   48.0,
#   61.0,
#   40.0,
#   61.0,
#   40.0,
#   50.0],
#  [454.0,
#   'Toxicroak',
#   'PoisonFighting',
#   490.0,
#   83.0,
#   106.0,
#   65.0,
#   86.0,
#   65.0,
#   85.0],
#  [455.0, 'Carnivine', 'Grass', 454.0, 74.0, 100.0, 72.0, 90.0, 72.0, 46.0],
#  [456.0, 'Finneon', 'Water', 330.0, 49.0, 49.0, 56.0, 49.0, 61.0, 66.0],
#  [457.0, 'Lumineon', 'Water', 460.0, 69.0, 69.0, 76.0, 69.0, 86.0, 91.0],
#  [458.0, 'Mantyke', 'WaterFlying', 345.0, 45.0, 20.0, 50.0, 60.0, 120.0, 50.0],
#  [459.0, 'Snover', 'GrassIce', 334.0, 60.0, 62.0, 50.0, 62.0, 60.0, 40.0],
#  [460.0, 'Abomasnow', 'GrassIce', 494.0, 90.0, 92.0, 75.0, 92.0, 85.0, 60.0],
#  [460.0,
#   'AbomasnowMega Abomasnow',
#   'GrassIce',
#   594.0,
#   90.0,
#   132.0,
#   105.0,
#   132.0,
#   105.0,
#   30.0],
#  [461.0, 'Weavile', 'DarkIce', 510.0, 70.0, 120.0, 65.0, 45.0, 85.0, 125.0],
#  [462.0,
#   'Magnezone',
#   'ElectricSteel',
#   535.0,
#   70.0,
#   70.0,
#   115.0,
#   130.0,
#   90.0,
#   60.0],
#  [463.0, 'Lickilicky', 'Normal', 515.0, 110.0, 85.0, 95.0, 80.0, 95.0, 50.0],
#  [464.0,
#   'Rhyperior',
#   'GroundRock',
#   535.0,
#   115.0,
#   140.0,
#   130.0,
#   55.0,
#   55.0,
#   40.0],
#  [465.0, 'Tangrowth', 'Grass', 535.0, 100.0, 100.0, 125.0, 110.0, 50.0, 50.0],
#  [466.0, 'Electivire', 'Electric', 540.0, 75.0, 123.0, 67.0, 95.0, 85.0, 95.0],
#  [467.0, 'Magmortar', 'Fire', 540.0, 75.0, 95.0, 67.0, 125.0, 95.0, 83.0],
#  [468.0,
#   'Togekiss',
#   'FairyFlying',
#   545.0,
#   85.0,
#   50.0,
#   95.0,
#   120.0,
#   115.0,
#   80.0],
#  [469.0, 'Yanmega', 'BugFlying', 515.0, 86.0, 76.0, 86.0, 116.0, 56.0, 95.0],
#  [470.0, 'Leafeon', 'Grass', 525.0, 65.0, 110.0, 130.0, 60.0, 65.0, 95.0],
#  [471.0, 'Glaceon', 'Ice', 525.0, 65.0, 60.0, 110.0, 130.0, 95.0, 65.0],
#  [472.0,
#   'Gliscor',
#   'GroundFlying',
#   510.0,
#   75.0,
#   95.0,
#   125.0,
#   45.0,
#   75.0,
#   95.0],
#  [473.0,
#   'Mamoswine',
#   'IceGround',
#   530.0,
#   110.0,
#   130.0,
#   80.0,
#   70.0,
#   60.0,
#   80.0],
#  [474.0, 'Porygon-Z', 'Normal', 535.0, 85.0, 80.0, 70.0, 135.0, 75.0, 90.0],
#  [475.0,
#   'Gallade',
#   'PsychicFighting',
#   518.0,
#   68.0,
#   125.0,
#   65.0,
#   65.0,
#   115.0,
#   80.0],
#  [475.0,
#   'GalladeMega Gallade',
#   'PsychicFighting',
#   618.0,
#   68.0,
#   165.0,
#   95.0,
#   65.0,
#   115.0,
#   110.0],
#  [476.0,
#   'Probopass',
#   'RockSteel',
#   525.0,
#   60.0,
#   55.0,
#   145.0,
#   75.0,
#   150.0,
#   40.0],
#  [477.0, 'Dusknoir', 'Ghost', 525.0, 45.0, 100.0, 135.0, 65.0, 135.0, 45.0],
#  [478.0, 'Froslass', 'IceGhost', 480.0, 70.0, 80.0, 70.0, 80.0, 70.0, 110.0],
#  [479.0, 'Rotom', 'ElectricGhost', 440.0, 50.0, 50.0, 77.0, 95.0, 77.0, 91.0],
#  [479.0,
#   'RotomHeat Rotom',
#   'ElectricFire',
#   520.0,
#   50.0,
#   65.0,
#   107.0,
#   105.0,
#   107.0,
#   86.0],
#  [479.0,
#   'RotomWash Rotom',
#   'ElectricWater',
#   520.0,
#   50.0,
#   65.0,
#   107.0,
#   105.0,
#   107.0,
#   86.0],
#  [479.0,
#   'RotomFrost Rotom',
#   'ElectricIce',
#   520.0,
#   50.0,
#   65.0,
#   107.0,
#   105.0,
#   107.0,
#   86.0],
#  [479.0,
#   'RotomFan Rotom',
#   'ElectricFlying',
#   520.0,
#   50.0,
#   65.0,
#   107.0,
#   105.0,
#   107.0,
#   86.0],
#  [479.0,
#   'RotomMow Rotom',
#   'ElectricGrass',
#   520.0,
#   50.0,
#   65.0,
#   107.0,
#   105.0,
#   107.0,
#   86.0],
#  [480.0, 'Uxie', 'Psychic', 580.0, 75.0, 75.0, 130.0, 75.0, 130.0, 95.0],
#  [481.0, 'Mesprit', 'Psychic', 580.0, 80.0, 105.0, 105.0, 105.0, 105.0, 80.0],
#  [482.0, 'Azelf', 'Psychic', 580.0, 75.0, 125.0, 70.0, 125.0, 70.0, 115.0],
#  [483.0,
#   'Dialga',
#   'SteelDragon',
#   680.0,
#   100.0,
#   120.0,
#   120.0,
#   150.0,
#   100.0,
#   90.0],
#  [484.0,
#   'Palkia',
#   'WaterDragon',
#   680.0,
#   90.0,
#   120.0,
#   100.0,
#   150.0,
#   120.0,
#   100.0],
#  [485.0, 'Heatran', 'FireSteel', 600.0, 91.0, 90.0, 106.0, 130.0, 106.0, 77.0],
#  [486.0,
#   'Regigigas',
#   'Normal',
#   670.0,
#   110.0,
#   160.0,
#   110.0,
#   80.0,
#   110.0,
#   100.0],
#  [487.0,
#   'GiratinaAltered Forme',
#   'GhostDragon',
#   680.0,
#   150.0,
#   100.0,
#   120.0,
#   100.0,
#   120.0,
#   90.0],
#  [487.0,
#   'GiratinaOrigin Forme',
#   'GhostDragon',
#   680.0,
#   150.0,
#   120.0,
#   100.0,
#   120.0,
#   100.0,
#   90.0],
#  [488.0, 'Cresselia', 'Psychic', 600.0, 120.0, 70.0, 120.0, 75.0, 130.0, 85.0],
#  [489.0, 'Phione', 'Water', 480.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0],
#  [490.0, 'Manaphy', 'Water', 600.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0],
#  [491.0, 'Darkrai', 'Dark', 600.0, 70.0, 90.0, 90.0, 135.0, 90.0, 125.0],
#  [492.0,
#   'ShayminLand Forme',
#   'Grass',
#   600.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0],
#  [492.0,
#   'ShayminSky Forme',
#   'GrassFlying',
#   600.0,
#   100.0,
#   103.0,
#   75.0,
#   120.0,
#   75.0,
#   127.0],
#  [493.0, 'Arceus', 'Normal', 720.0, 120.0, 120.0, 120.0, 120.0, 120.0, 120.0],
#  [494.0,
#   'Victini',
#   'PsychicFire',
#   600.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0],
#  [495.0, 'Snivy', 'Grass', 308.0, 45.0, 45.0, 55.0, 45.0, 55.0, 63.0],
#  [496.0, 'Servine', 'Grass', 413.0, 60.0, 60.0, 75.0, 60.0, 75.0, 83.0],
#  [497.0, 'Serperior', 'Grass', 528.0, 75.0, 75.0, 95.0, 75.0, 95.0, 113.0],
#  [498.0, 'Tepig', 'Fire', 308.0, 65.0, 63.0, 45.0, 45.0, 45.0, 45.0],
#  [499.0, 'Pignite', 'FireFighting', 418.0, 90.0, 93.0, 55.0, 70.0, 55.0, 55.0],
#  [500.0,
#   'Emboar',
#   'FireFighting',
#   528.0,
#   110.0,
#   123.0,
#   65.0,
#   100.0,
#   65.0,
#   65.0],
#  [501.0, 'Oshawott', 'Water', 308.0, 55.0, 55.0, 45.0, 63.0, 45.0, 45.0],
#  [502.0, 'Dewott', 'Water', 413.0, 75.0, 75.0, 60.0, 83.0, 60.0, 60.0],
#  [503.0, 'Samurott', 'Water', 528.0, 95.0, 100.0, 85.0, 108.0, 70.0, 70.0],
#  [504.0, 'Patrat', 'Normal', 255.0, 45.0, 55.0, 39.0, 35.0, 39.0, 42.0],
#  [505.0, 'Watchog', 'Normal', 420.0, 60.0, 85.0, 69.0, 60.0, 69.0, 77.0],
#  [506.0, 'Lillipup', 'Normal', 275.0, 45.0, 60.0, 45.0, 25.0, 45.0, 55.0],
#  [507.0, 'Herdier', 'Normal', 370.0, 65.0, 80.0, 65.0, 35.0, 65.0, 60.0],
#  [508.0, 'Stoutland', 'Normal', 500.0, 85.0, 110.0, 90.0, 45.0, 90.0, 80.0],
#  [509.0, 'Purrloin', 'Dark', 281.0, 41.0, 50.0, 37.0, 50.0, 37.0, 66.0],
#  [510.0, 'Liepard', 'Dark', 446.0, 64.0, 88.0, 50.0, 88.0, 50.0, 106.0],
#  [511.0, 'Pansage', 'Grass', 316.0, 50.0, 53.0, 48.0, 53.0, 48.0, 64.0],
#  [512.0, 'Simisage', 'Grass', 498.0, 75.0, 98.0, 63.0, 98.0, 63.0, 101.0],
#  [513.0, 'Pansear', 'Fire', 316.0, 50.0, 53.0, 48.0, 53.0, 48.0, 64.0],
#  [514.0, 'Simisear', 'Fire', 498.0, 75.0, 98.0, 63.0, 98.0, 63.0, 101.0],
# ...
#   'FirePsychic',
#   540.0,
#   105.0,
#   30.0,
#   105.0,
#   140.0,
#   105.0,
#   55.0],
#  [556.0, 'Maractus', 'Grass', 461.0, 75.0, 86.0, 67.0, 106.0, 67.0, 60.0],
#  [557.0, 'Dwebble', 'BugRock', 325.0, 50.0, 65.0, 85.0, 35.0, 35.0, 55.0],
#  [558.0, 'Crustle', 'BugRock', 475.0, 70.0, 95.0, 125.0, 65.0, 75.0, 45.0],
#  [559.0, 'Scraggy', 'DarkFighting', 348.0, 50.0, 75.0, 70.0, 35.0, 70.0, 48.0],
#  [560.0,
#   'Scrafty',
#   'DarkFighting',
#   488.0,
#   65.0,
#   90.0,
#   115.0,
#   45.0,
#   115.0,
#   58.0],
#  [561.0,
#   'Sigilyph',
#   'PsychicFlying',
#   490.0,
#   72.0,
#   58.0,
#   80.0,
#   103.0,
#   80.0,
#   97.0],
#  [562.0, 'Yamask', 'Ghost', 303.0, 38.0, 30.0, 85.0, 55.0, 65.0, 30.0],
#  [563.0, 'Cofagrigus', 'Ghost', 483.0, 58.0, 50.0, 145.0, 95.0, 105.0, 30.0],
#  [564.0, 'Tirtouga', 'WaterRock', 355.0, 54.0, 78.0, 103.0, 53.0, 45.0, 22.0],
#  [565.0,
#   'Carracosta',
#   'WaterRock',
#   495.0,
#   74.0,
#   108.0,
#   133.0,
#   83.0,
#   65.0,
#   32.0],
#  [566.0, 'Archen', 'RockFlying', 401.0, 55.0, 112.0, 45.0, 74.0, 45.0, 70.0],
#  [567.0,
#   'Archeops',
#   'RockFlying',
#   567.0,
#   75.0,
#   140.0,
#   65.0,
#   112.0,
#   65.0,
#   110.0],
#  [568.0, 'Trubbish', 'Poison', 329.0, 50.0, 50.0, 62.0, 40.0, 62.0, 65.0],
#  [569.0, 'Garbodor', 'Poison', 474.0, 80.0, 95.0, 82.0, 60.0, 82.0, 75.0],
#  [570.0, 'Zorua', 'Dark', 330.0, 40.0, 65.0, 40.0, 80.0, 40.0, 65.0],
#  [571.0, 'Zoroark', 'Dark', 510.0, 60.0, 105.0, 60.0, 120.0, 60.0, 105.0],
#  [572.0, 'Minccino', 'Normal', 300.0, 55.0, 50.0, 40.0, 40.0, 40.0, 75.0],
#  [573.0, 'Cinccino', 'Normal', 470.0, 75.0, 95.0, 60.0, 65.0, 60.0, 115.0],
#  [574.0, 'Gothita', 'Psychic', 290.0, 45.0, 30.0, 50.0, 55.0, 65.0, 45.0],
#  [575.0, 'Gothorita', 'Psychic', 390.0, 60.0, 45.0, 70.0, 75.0, 85.0, 55.0],
#  [576.0, 'Gothitelle', 'Psychic', 490.0, 70.0, 55.0, 95.0, 95.0, 110.0, 65.0],
#  [577.0, 'Solosis', 'Psychic', 290.0, 45.0, 30.0, 40.0, 105.0, 50.0, 20.0],
#  [578.0, 'Duosion', 'Psychic', 370.0, 65.0, 40.0, 50.0, 125.0, 60.0, 30.0],
#  [579.0, 'Reuniclus', 'Psychic', 490.0, 110.0, 65.0, 75.0, 125.0, 85.0, 30.0],
#  [580.0, 'Ducklett', 'WaterFlying', 305.0, 62.0, 44.0, 50.0, 44.0, 50.0, 55.0],
#  [581.0, 'Swanna', 'WaterFlying', 473.0, 75.0, 87.0, 63.0, 87.0, 63.0, 98.0],
#  [582.0, 'Vanillite', 'Ice', 305.0, 36.0, 50.0, 50.0, 65.0, 60.0, 44.0],
#  [583.0, 'Vanillish', 'Ice', 395.0, 51.0, 65.0, 65.0, 80.0, 75.0, 59.0],
#  [584.0, 'Vanilluxe', 'Ice', 535.0, 71.0, 95.0, 85.0, 110.0, 95.0, 79.0],
#  [585.0, 'Deerling', 'NormalGrass', 335.0, 60.0, 60.0, 50.0, 40.0, 50.0, 75.0],
#  [586.0,
#   'Sawsbuck',
#   'NormalGrass',
#   475.0,
#   80.0,
#   100.0,
#   70.0,
#   60.0,
#   70.0,
#   95.0],
#  [587.0,
#   'Emolga',
#   'ElectricFlying',
#   428.0,
#   55.0,
#   75.0,
#   60.0,
#   75.0,
#   60.0,
#   103.0],
#  [588.0, 'Karrablast', 'Bug', 315.0, 50.0, 75.0, 45.0, 40.0, 45.0, 60.0],
#  [589.0,
#   'Escavalier',
#   'BugSteel',
#   495.0,
#   70.0,
#   135.0,
#   105.0,
#   60.0,
#   105.0,
#   20.0],
#  [590.0, 'Foongus', 'GrassPoison', 294.0, 69.0, 55.0, 45.0, 55.0, 55.0, 15.0],
#  [591.0,
#   'Amoonguss',
#   'GrassPoison',
#   464.0,
#   114.0,
#   85.0,
#   70.0,
#   85.0,
#   80.0,
#   30.0],
#  [592.0, 'Frillish', 'WaterGhost', 335.0, 55.0, 40.0, 50.0, 65.0, 85.0, 40.0],
#  [593.0,
#   'Jellicent',
#   'WaterGhost',
#   480.0,
#   100.0,
#   60.0,
#   70.0,
#   85.0,
#   105.0,
#   60.0],
#  [594.0, 'Alomomola', 'Water', 470.0, 165.0, 75.0, 80.0, 40.0, 45.0, 65.0],
#  [595.0, 'Joltik', 'BugElectric', 319.0, 50.0, 47.0, 50.0, 57.0, 50.0, 65.0],
#  [596.0,
#   'Galvantula',
#   'BugElectric',
#   472.0,
#   70.0,
#   77.0,
#   60.0,
#   97.0,
#   60.0,
#   108.0],
#  [597.0, 'Ferroseed', 'GrassSteel', 305.0, 44.0, 50.0, 91.0, 24.0, 86.0, 10.0],
#  [598.0,
#   'Ferrothorn',
#   'GrassSteel',
#   489.0,
#   74.0,
#   94.0,
#   131.0,
#   54.0,
#   116.0,
#   20.0],
#  [599.0, 'Klink', 'Steel', 300.0, 40.0, 55.0, 70.0, 45.0, 60.0, 30.0],
#  [600.0, 'Klang', 'Steel', 440.0, 60.0, 80.0, 95.0, 70.0, 85.0, 50.0],
#  [601.0, 'Klinklang', 'Steel', 520.0, 60.0, 100.0, 115.0, 70.0, 85.0, 90.0],
#  [602.0, 'Tynamo', 'Electric', 275.0, 35.0, 55.0, 40.0, 45.0, 40.0, 60.0],
#  [603.0, 'Eelektrik', 'Electric', 405.0, 65.0, 85.0, 70.0, 75.0, 70.0, 40.0],
#  [604.0,
#   'Eelektross',
#   'Electric',
#   515.0,
#   85.0,
#   115.0,
#   80.0,
#   105.0,
#   80.0,
#   50.0],
#  [605.0, 'Elgyem', 'Psychic', 335.0, 55.0, 55.0, 55.0, 85.0, 55.0, 30.0],
#  [606.0, 'Beheeyem', 'Psychic', 485.0, 75.0, 75.0, 75.0, 125.0, 95.0, 40.0],
#  [607.0, 'Litwick', 'GhostFire', 275.0, 50.0, 30.0, 55.0, 65.0, 55.0, 20.0],
#  [608.0, 'Lampent', 'GhostFire', 370.0, 60.0, 40.0, 60.0, 95.0, 60.0, 55.0],
#  [609.0,
#   'Chandelure',
#   'GhostFire',
#   520.0,
#   60.0,
#   55.0,
#   90.0,
#   145.0,
#   90.0,
#   80.0],
#  [610.0, 'Axew', 'Dragon', 320.0, 46.0, 87.0, 60.0, 30.0, 40.0, 57.0],
#  [611.0, 'Fraxure', 'Dragon', 410.0, 66.0, 117.0, 70.0, 40.0, 50.0, 67.0],
#  [612.0, 'Haxorus', 'Dragon', 540.0, 76.0, 147.0, 90.0, 60.0, 70.0, 97.0],
#  [613.0, 'Cubchoo', 'Ice', 305.0, 55.0, 70.0, 40.0, 60.0, 40.0, 40.0],
#  [614.0, 'Beartic', 'Ice', 485.0, 95.0, 110.0, 80.0, 70.0, 80.0, 50.0],
#  [615.0, 'Cryogonal', 'Ice', 485.0, 70.0, 50.0, 30.0, 95.0, 135.0, 105.0],
#  [616.0, 'Shelmet', 'Bug', 305.0, 50.0, 40.0, 85.0, 40.0, 65.0, 25.0],
#  [617.0, 'Accelgor', 'Bug', 495.0, 80.0, 70.0, 40.0, 100.0, 60.0, 145.0],
#  [618.0,
#   'Stunfisk',
#   'GroundElectric',
#   471.0,
#   109.0,
#   66.0,
#   84.0,
#   81.0,
#   99.0,
#   32.0],
#  [619.0, 'Mienfoo', 'Fighting', 350.0, 45.0, 85.0, 50.0, 55.0, 50.0, 65.0],
#  [620.0, 'Mienshao', 'Fighting', 510.0, 65.0, 125.0, 60.0, 95.0, 60.0, 105.0],
#  [621.0, 'Druddigon', 'Dragon', 485.0, 77.0, 120.0, 90.0, 60.0, 90.0, 48.0],
#  [622.0, 'Golett', 'GroundGhost', 303.0, 59.0, 74.0, 50.0, 35.0, 50.0, 35.0],
#  [623.0, 'Golurk', 'GroundGhost', 483.0, 89.0, 124.0, 80.0, 55.0, 80.0, 55.0],
#  [624.0, 'Pawniard', 'DarkSteel', 340.0, 45.0, 85.0, 70.0, 40.0, 40.0, 60.0],
#  [625.0, 'Bisharp', 'DarkSteel', 490.0, 65.0, 125.0, 100.0, 60.0, 70.0, 70.0],
#  [626.0, 'Bouffalant', 'Normal', 490.0, 95.0, 110.0, 95.0, 40.0, 95.0, 55.0],
#  [627.0, 'Rufflet', 'NormalFlying', 350.0, 70.0, 83.0, 50.0, 37.0, 50.0, 60.0],
#  [628.0,
#   'Braviary',
#   'NormalFlying',
#   510.0,
#   100.0,
#   123.0,
#   75.0,
#   57.0,
#   75.0,
#   80.0],
#  [629.0, 'Vullaby', 'DarkFlying', 370.0, 70.0, 55.0, 75.0, 45.0, 65.0, 60.0],
#  [630.0,
#   'Mandibuzz',
#   'DarkFlying',
#   510.0,
#   110.0,
#   65.0,
#   105.0,
#   55.0,
#   95.0,
#   80.0],
#  [631.0, 'Heatmor', 'Fire', 484.0, 85.0, 97.0, 66.0, 105.0, 66.0, 65.0],
#  [632.0, 'Durant', 'BugSteel', 484.0, 58.0, 109.0, 112.0, 48.0, 48.0, 109.0],
#  [633.0, 'Deino', 'DarkDragon', 300.0, 52.0, 65.0, 50.0, 45.0, 50.0, 38.0],
#  [634.0, 'Zweilous', 'DarkDragon', 420.0, 72.0, 85.0, 70.0, 65.0, 70.0, 58.0],
#  [635.0,
#   'Hydreigon',
#   'DarkDragon',
#   600.0,
#   92.0,
#   105.0,
#   90.0,
#   125.0,
#   90.0,
#   98.0],
#  [636.0, 'Larvesta', 'BugFire', 360.0, 55.0, 85.0, 55.0, 50.0, 55.0, 60.0],
#  [637.0, 'Volcarona', 'BugFire', 550.0, 85.0, 60.0, 65.0, 135.0, 105.0, 100.0],
#  [638.0,
#   'Cobalion',
#   'SteelFighting',
#   580.0,
#   91.0,
#   90.0,
#   129.0,
#   90.0,
#   72.0,
#   108.0],
#  [639.0,
#   'Terrakion',
#   'RockFighting',
#   580.0,
#   91.0,
#   129.0,
#   90.0,
#   72.0,
#   90.0,
#   108.0],
#  [640.0,
#   'Virizion',
#   'GrassFighting',
#   580.0,
#   91.0,
#   90.0,
#   72.0,
#   90.0,
#   129.0,
#   108.0],
#  [641.0,
#   'TornadusIncarnate Forme',
#   'Flying',
#   580.0,
#   79.0,
#   115.0,
#   70.0,
#   125.0,
#   80.0,
#   111.0],
#  [641.0,
#   'TornadusTherian Forme',
#   'Flying',
#   580.0,
#   79.0,
#   100.0,
#   80.0,
#   110.0,
#   90.0,
#   121.0],
#  [642.0,
#   'ThundurusIncarnate Forme',
#   'ElectricFlying',
#   580.0,
#   79.0,
#   115.0,
#   70.0,
#   125.0,
#   80.0,
#   111.0],
#  [642.0,
#   'ThundurusTherian Forme',
#   'ElectricFlying',
#   580.0,
#   79.0,
#   105.0,
#   70.0,
#   145.0,
#   80.0,
#   101.0],
#  [643.0,
#   'Reshiram',
#   'DragonFire',
#   680.0,
#   100.0,
#   120.0,
#   100.0,
#   150.0,
#   120.0,
#   90.0],
#  [644.0,
#   'Zekrom',
#   'DragonElectric',
#   680.0,
#   100.0,
#   150.0,
#   120.0,
#   120.0,
#   100.0,
#   90.0],
#  [645.0,
#   'LandorusIncarnate Forme',
#   'GroundFlying',
#   600.0,
#   89.0,
#   125.0,
#   90.0,
#   115.0,
#   80.0,
#   101.0],
#  [645.0,
#   'LandorusTherian Forme',
#   'GroundFlying',
#   600.0,
#   89.0,
#   145.0,
#   90.0,
#   105.0,
#   80.0,
#   91.0],
#  [646.0, 'Kyurem', 'DragonIce', 660.0, 125.0, 130.0, 90.0, 130.0, 90.0, 95.0],
#  [646.0,
#   'KyuremBlack Kyurem',
#   'DragonIce',
#   700.0,
#   125.0,
#   170.0,
#   100.0,
#   120.0,
#   90.0,
#   95.0],
#  [646.0,
#   'KyuremWhite Kyurem',
#   'DragonIce',
#   700.0,
#   125.0,
#   120.0,
#   90.0,
#   170.0,
#   100.0,
#   95.0],
#  [647.0,
#   'KeldeoOrdinary Forme',
#   'WaterFighting',
#   580.0,
#   91.0,
#   72.0,
#   90.0,
#   129.0,
#   90.0,
#   108.0],
#  [647.0,
#   'KeldeoResolute Forme',
#   'WaterFighting',
#   580.0,
#   91.0,
#   72.0,
#   90.0,
#   129.0,
#   90.0,
#   108.0],
#  [648.0,
#   'MeloettaAria Forme',
#   'NormalPsychic',
#   600.0,
#   100.0,
#   77.0,
#   77.0,
#   128.0,
#   128.0,
#   90.0],
#  [648.0,
#   'MeloettaPirouette Forme',
#   'NormalFighting',
#   600.0,
#   100.0,
#   128.0,
#   90.0,
#   77.0,
#   77.0,
#   128.0],
#  [649.0, 'Genesect', 'BugSteel', 600.0, 71.0, 120.0, 95.0, 120.0, 95.0, 99.0],
#  [650.0, 'Chespin', 'Grass', 313.0, 56.0, 61.0, 65.0, 48.0, 45.0, 38.0],
#  [651.0, 'Quilladin', 'Grass', 405.0, 61.0, 78.0, 95.0, 56.0, 58.0, 57.0],
#  [652.0,
#   'Chesnaught',
#   'GrassFighting',
#   530.0,
#   88.0,
#   107.0,
#   122.0,
#   74.0,
#   75.0,
#   64.0],
#  [653.0, 'Fennekin', 'Fire', 307.0, 40.0, 45.0, 40.0, 62.0, 60.0, 60.0],
#  [654.0, 'Braixen', 'Fire', 409.0, 59.0, 59.0, 58.0, 90.0, 70.0, 73.0],
#  [655.0,
#   'Delphox',
#   'FirePsychic',
#   534.0,
#   75.0,
#   69.0,
#   72.0,
#   114.0,
#   100.0,
#   104.0],
#  [656.0, 'Froakie', 'Water', 314.0, 41.0, 56.0, 40.0, 62.0, 44.0, 71.0],
#  [657.0, 'Frogadier', 'Water', 405.0, 54.0, 63.0, 52.0, 83.0, 56.0, 97.0],
#  [658.0, 'Greninja', 'WaterDark', 530.0, 72.0, 95.0, 67.0, 103.0, 71.0, 122.0],
#  [659.0, 'Bunnelby', 'Normal', 237.0, 38.0, 36.0, 38.0, 32.0, 36.0, 57.0],
#  [660.0,
#   'Diggersby',
#   'NormalGround',
#   423.0,
#   85.0,
#   56.0,
#   77.0,
#   50.0,
#   77.0,
#   78.0],
#  [661.0,
#   'Fletchling',
#   'NormalFlying',
#   278.0,
#   45.0,
#   50.0,
#   43.0,
#   40.0,
#   38.0,
#   62.0],
#  [662.0,
#   'Fletchinder',
#   'FireFlying',
#   382.0,
#   62.0,
#   73.0,
#   55.0,
#   56.0,
#   52.0,
#   84.0],
#  [663.0,
#   'Talonflame',
#   'FireFlying',
#   499.0,
#   78.0,
#   81.0,
#   71.0,
#   74.0,
#   69.0,
#   126.0],
#  [664.0, 'Scatterbug', 'Bug', 200.0, 38.0, 35.0, 40.0, 27.0, 25.0, 35.0],
#  [665.0, 'Spewpa', 'Bug', 213.0, 45.0, 22.0, 60.0, 27.0, 30.0, 29.0],
#  [666.0, 'Vivillon', 'BugFlying', 411.0, 80.0, 52.0, 50.0, 90.0, 50.0, 89.0],
#  [667.0, 'Litleo', 'FireNormal', 369.0, 62.0, 50.0, 58.0, 73.0, 54.0, 72.0],
#  [668.0, 'Pyroar', 'FireNormal', 507.0, 86.0, 68.0, 72.0, 109.0, 66.0, 106.0],
#  [669.0, 'Flabebe', 'Fairy', 303.0, 44.0, 38.0, 39.0, 61.0, 79.0, 42.0],
#  [670.0, 'Floette', 'Fairy', 371.0, 54.0, 45.0, 47.0, 75.0, 98.0, 52.0],
#  [671.0, 'Florges', 'Fairy', 552.0, 78.0, 65.0, 68.0, 112.0, 154.0, 75.0],
#  [672.0, 'Skiddo', 'Grass', 350.0, 66.0, 65.0, 48.0, 62.0, 57.0, 52.0],
#  [673.0, 'Gogoat', 'Grass', 531.0, 123.0, 100.0, 62.0, 97.0, 81.0, 68.0],
#  [674.0, 'Pancham', 'Fighting', 348.0, 67.0, 82.0, 62.0, 46.0, 48.0, 43.0],
#  [675.0,
#   'Pangoro',
#   'FightingDark',
#   495.0,
#   95.0,
#   124.0,
#   78.0,
#   69.0,
#   71.0,
#   58.0],
#  [676.0, 'Furfrou', 'Normal', 472.0, 75.0, 80.0, 60.0, 65.0, 90.0, 102.0],
#  [677.0, 'Espurr', 'Psychic', 355.0, 62.0, 48.0, 54.0, 63.0, 60.0, 68.0],
#  [678.0,
#   'MeowsticMale',
#   'Psychic',
#   466.0,
#   74.0,
#   48.0,
#   76.0,
#   83.0,
#   81.0,
#   104.0],
#  [678.0,
#   'MeowsticFemale',
#   'Psychic',
#   466.0,
#   74.0,
#   48.0,
#   76.0,
#   83.0,
#   81.0,
#   104.0],
#  [679.0, 'Honedge', 'SteelGhost', 325.0, 45.0, 80.0, 100.0, 35.0, 37.0, 28.0],
#  [680.0,
#   'Doublade',
#   'SteelGhost',
#   448.0,
#   59.0,
#   110.0,
#   150.0,
#   45.0,
#   49.0,
#   35.0],
#  [681.0,
#   'AegislashBlade Forme',
#   'SteelGhost',
#   520.0,
#   60.0,
#   150.0,
#   50.0,
#   150.0,
#   50.0,
#   60.0],
#  [681.0,
#   'AegislashShield Forme',
#   'SteelGhost',
#   520.0,
#   60.0,
#   50.0,
#   150.0,
#   50.0,
#   150.0,
#   60.0],
#  [682.0, 'Spritzee', 'Fairy', 341.0, 78.0, 52.0, 60.0, 63.0, 65.0, 23.0],
#  [683.0, 'Aromatisse', 'Fairy', 462.0, 101.0, 72.0, 72.0, 99.0, 89.0, 29.0],
#  [684.0, 'Swirlix', 'Fairy', 341.0, 62.0, 48.0, 66.0, 59.0, 57.0, 49.0],
#  [685.0, 'Slurpuff', 'Fairy', 480.0, 82.0, 80.0, 86.0, 85.0, 75.0, 72.0],
#  [686.0, 'Inkay', 'DarkPsychic', 288.0, 53.0, 54.0, 53.0, 37.0, 46.0, 45.0],
#  [687.0, 'Malamar', 'DarkPsychic', 482.0, 86.0, 92.0, 88.0, 68.0, 75.0, 73.0],
#  [688.0, 'Binacle', 'RockWater', 306.0, 42.0, 52.0, 67.0, 39.0, 56.0, 50.0],
#  [689.0,
#   'Barbaracle',
#   'RockWater',
#   500.0,
#   72.0,
#   105.0,
#   115.0,
#   54.0,
#   86.0,
#   68.0],
#  [690.0, 'Skrelp', 'PoisonWater', 320.0, 50.0, 60.0, 60.0, 60.0, 60.0, 30.0],
#  [691.0,
#   'Dragalge',
#   'PoisonDragon',
#   494.0,
#   65.0,
#   75.0,
#   90.0,
#   97.0,
#   123.0,
#   44.0],
#  [692.0, 'Clauncher', 'Water', 330.0, 50.0, 53.0, 62.0, 58.0, 63.0, 44.0],
#  [693.0, 'Clawitzer', 'Water', 500.0, 71.0, 73.0, 88.0, 120.0, 89.0, 59.0],
#  [694.0,
#   'Helioptile',
#   'ElectricNormal',
#   289.0,
#   44.0,
#   38.0,
#   33.0,
#   61.0,
#   43.0,
#   70.0],
#  [695.0,
#   'Heliolisk',
#   'ElectricNormal',
#   481.0,
#   62.0,
#   55.0,
#   52.0,
#   109.0,
#   94.0,
#   109.0],
#  [696.0, 'Tyrunt', 'RockDragon', 362.0, 58.0, 89.0, 77.0, 45.0, 45.0, 48.0],
#  [697.0,
#   'Tyrantrum',
#   'RockDragon',
#   521.0,
#   82.0,
#   121.0,
#   119.0,
#   69.0,
#   59.0,
#   71.0],
#  [698.0, 'Amaura', 'RockIce', 362.0, 77.0, 59.0, 50.0, 67.0, 63.0, 46.0],
#  [699.0, 'Aurorus', 'RockIce', 521.0, 123.0, 77.0, 72.0, 99.0, 92.0, 58.0],
#  [700.0, 'Sylveon', 'Fairy', 525.0, 95.0, 65.0, 65.0, 110.0, 130.0, 60.0],
#  [701.0,
#   'Hawlucha',
#   'FightingFlying',
#   500.0,
#   78.0,
#   92.0,
#   75.0,
#   74.0,
#   63.0,
#   118.0],
#  [702.0,
#   'Dedenne',
#   'ElectricFairy',
#   431.0,
#   67.0,
#   58.0,
#   57.0,
#   81.0,
#   67.0,
#   101.0],
#  [703.0, 'Carbink', 'RockFairy', 500.0, 50.0, 50.0, 150.0, 50.0, 150.0, 50.0],
#  [704.0, 'Goomy', 'Dragon', 300.0, 45.0, 50.0, 35.0, 55.0, 75.0, 40.0],
#  [705.0, 'Sliggoo', 'Dragon', 452.0, 68.0, 75.0, 53.0, 83.0, 113.0, 60.0],
#  [706.0, 'Goodra', 'Dragon', 600.0, 90.0, 100.0, 70.0, 110.0, 150.0, 80.0],
#  [707.0, 'Klefki', 'SteelFairy', 470.0, 57.0, 80.0, 91.0, 80.0, 87.0, 75.0],
#  [708.0, 'Phantump', 'GhostGrass', 309.0, 43.0, 70.0, 48.0, 50.0, 60.0, 38.0],
#  [709.0,
#   'Trevenant',
#   'GhostGrass',
#   474.0,
#   85.0,
#   110.0,
#   76.0,
#   65.0,
#   82.0,
#   56.0],
#  [710.0,
#   'PumpkabooAverage Size',
#   'GhostGrass',
#   335.0,
#   49.0,
#   66.0,
#   70.0,
#   44.0,
#   55.0,
#   51.0],
#  [710.0,
#   'PumpkabooSmall Size',
#   'GhostGrass',
#   335.0,
#   44.0,
#   66.0,
#   70.0,
#   44.0,
#   55.0,
#   56.0],
#  [710.0,
#   'PumpkabooLarge Size',
#   'GhostGrass',
#   335.0,
#   54.0,
#   66.0,
#   70.0,
#   44.0,
#   55.0,
#   46.0],
#  [710.0,
#   'PumpkabooSuper Size',
#   'GhostGrass',
#   335.0,
#   59.0,
#   66.0,
#   70.0,
#   44.0,
#   55.0,
#   41.0],
#  [711.0,
#   'GourgeistAverage Size',
#   'GhostGrass',
#   494.0,
#   65.0,
#   90.0,
#   122.0,
#   58.0,
#   75.0,
#   84.0],
#  [711.0,
#   'GourgeistSmall Size',
#   'GhostGrass',
#   494.0,
#   55.0,
#   85.0,
#   122.0,
#   58.0,
#   75.0,
#   99.0],
#  [711.0,
#   'GourgeistLarge Size',
#   'GhostGrass',
#   494.0,
#   75.0,
#   95.0,
#   122.0,
#   58.0,
#   75.0,
#   69.0],
#  [711.0,
#   'GourgeistSuper Size',
#   'GhostGrass',
#   494.0,
#   85.0,
#   100.0,
#   122.0,
#   58.0,
#   75.0,
#   54.0],
#  [712.0, 'Bergmite', 'Ice', 304.0, 55.0, 69.0, 85.0, 32.0, 35.0, 28.0],
#  [713.0, 'Avalugg', 'Ice', 514.0, 95.0, 117.0, 184.0, 44.0, 46.0, 28.0],
#  [714.0, 'Noibat', 'FlyingDragon', 245.0, 40.0, 30.0, 35.0, 45.0, 40.0, 55.0],
#  [715.0,
#   'Noivern',
#   'FlyingDragon',
#   535.0,
#   85.0,
#   70.0,
#   80.0,
#   97.0,
#   80.0,
#   123.0],
#  [716.0, 'Xerneas', 'Fairy', 680.0, 126.0, 131.0, 95.0, 131.0, 98.0, 99.0],
#  [717.0,
#   'Yveltal',
#   'DarkFlying',
#   680.0,
#   126.0,
#   131.0,
#   95.0,
#   131.0,
#   98.0,
#   99.0],
#  [718.0,
#   'Zygarde Forme',
#   'DragonGround',
#   600.0,
#   108.0,
#   100.0,
#   121.0,
#   81.0,
#   95.0,
#   95.0],
#  [719.0,
#   'Diancie',
#   'RockFairy',
#   600.0,
#   50.0,
#   100.0,
#   150.0,
#   100.0,
#   150.0,
#   50.0],
#  [719.0,
#   'DiancieMega Diancie',
#   'RockFairy',
#   700.0,
#   50.0,
#   160.0,
#   110.0,
#   160.0,
#   110.0,
#   110.0],
#  [720.0,
#   'HoopaHoopa Confined',
#   'PsychicGhost',
#   600.0,
#   80.0,
#   110.0,
#   60.0,
#   150.0,
#   130.0,
#   70.0],
#  [720.0,
#   'HoopaHoopa Unbound',
#   'PsychicDark',
#   680.0,
#   80.0,
#   160.0,
#   60.0,
#   170.0,
#   130.0,
#   80.0],
#  [721.0,
#   'Volcanion',
#   'FireWater',
#   600.0,
#   80.0,
#   110.0,
#   120.0,
#   130.0,
#   90.0,
#   70.0]]

# %%
for row in floated_data:
    for element in row:
        if element == '':
            element = element.replace('',-1)
# print(floated_data)

final_data = list([split_data[0]]) + floated_data       #final answer of cleaned data

final_data[:3]
header = final_data[0]         #show the first row of column names

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
def new_pokedex(parsed_pokedex):
    
    header = parsed_pokedex[0]                      #selects row of column titles
    
    list_of_tup = []
    for row in parsed_pokedex[1:]:                  #iterate through rows of body data
        list_of_tup.append(list(zip(header,row)))   #gives list of each pokemon with individual (tuples of title with data)    
        
    list_of_dict = []
    for row in list_of_tup:
        list_of_dict.append(dict(row))              #turns tuples of title with data into {title:data}
    
    full_pokedex = {}
    for row in list_of_dict:
        pdex = int(row['PokedexNumber'])            #calls out pokemon_id using PokedexNumber's values
        full_pokedex[pdex] = row                    #assigns pokemon_id as key to it's associated features and values 
 
    print(full_pokedex[100])      #test function                
    return full_pokedex
        
new_pokedex(final_data)
# Out:
# {'PokedexNumber': 100.0, 'Name': 'Voltorb', 'Type': 'Electric', 'Total': 330.0, 'HP': 40.0, 'Attack': 30.0, 'Defense': 50.0, 'SpecialAttack': 55.0, 'SpecialDefense': 55.0, 'Speed\n': 100.0}
# {1: {'PokedexNumber': 1.0,
#   'Name': 'Bulbasaur',
#   'Type': 'GrassPoison',
#   'Total': 318.0,
#   'HP': 45.0,
#   'Attack': 49.0,
#   'Defense': 49.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 45.0},
#  2: {'PokedexNumber': 2.0,
#   'Name': 'Ivysaur',
#   'Type': 'GrassPoison',
#   'Total': 405.0,
#   'HP': 60.0,
#   'Attack': 62.0,
#   'Defense': 63.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 60.0},
#  3: {'PokedexNumber': 3.0,
#   'Name': 'VenusaurMega Venusaur',
#   'Type': 'GrassPoison',
#   'Total': 625.0,
#   'HP': 80.0,
#   'Attack': 100.0,
#   'Defense': 123.0,
#   'SpecialAttack': 122.0,
#   'SpecialDefense': 120.0,
#   'Speed\n': 80.0},
#  4: {'PokedexNumber': 4.0,
#   'Name': 'Charmander',
#   'Type': 'Fire',
#   'Total': 309.0,
#   'HP': 39.0,
#   'Attack': 52.0,
#   'Defense': 43.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 65.0},
#  5: {'PokedexNumber': 5.0,
#   'Name': 'Charmeleon',
#   'Type': 'Fire',
#   'Total': 405.0,
#   'HP': 58.0,
#   'Attack': 64.0,
#   'Defense': 58.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 80.0},
#  6: {'PokedexNumber': 6.0,
#   'Name': 'CharizardMega Charizard Y',
#   'Type': 'FireFlying',
#   'Total': 634.0,
#   'HP': 78.0,
#   'Attack': 104.0,
#   'Defense': 78.0,
#   'SpecialAttack': 159.0,
#   'SpecialDefense': 115.0,
#   'Speed\n': 100.0},
#  7: {'PokedexNumber': 7.0,
#   'Name': 'Squirtle',
#   'Type': 'Water',
#   'Total': 314.0,
#   'HP': 44.0,
#   'Attack': 48.0,
#   'Defense': 65.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 64.0,
#   'Speed\n': 43.0},
#  8: {'PokedexNumber': 8.0,
#   'Name': 'Wartortle',
#   'Type': 'Water',
#   'Total': 405.0,
#   'HP': 59.0,
#   'Attack': 63.0,
#   'Defense': 80.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 58.0},
#  9: {'PokedexNumber': 9.0,
#   'Name': 'BlastoiseMega Blastoise',
#   'Type': 'Water',
#   'Total': 630.0,
#   'HP': 79.0,
#   'Attack': 103.0,
#   'Defense': 120.0,
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 115.0,
#   'Speed\n': 78.0},
#  10: {'PokedexNumber': 10.0,
#   'Name': 'Caterpie',
#   'Type': 'Bug',
#   'Total': 195.0,
#   'HP': 45.0,
#   'Attack': 30.0,
#   'Defense': 35.0,
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 20.0,
#   'Speed\n': 45.0},
#  11: {'PokedexNumber': 11.0,
#   'Name': 'Metapod',
#   'Type': 'Bug',
#   'Total': 205.0,
#   'HP': 50.0,
#   'Attack': 20.0,
#   'Defense': 55.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed\n': 30.0},
#  12: {'PokedexNumber': 12.0,
#   'Name': 'Butterfree',
#   'Type': 'BugFlying',
#   'Total': 395.0,
#   'HP': 60.0,
#   'Attack': 45.0,
#   'Defense': 50.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 70.0},
#  13: {'PokedexNumber': 13.0,
#   'Name': 'Weedle',
#   'Type': 'BugPoison',
#   'Total': 195.0,
#   'HP': 40.0,
#   'Attack': 35.0,
#   'Defense': 30.0,
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 20.0,
#   'Speed\n': 50.0},
#  14: {'PokedexNumber': 14.0,
#   'Name': 'Kakuna',
#   'Type': 'BugPoison',
#   'Total': 205.0,
#   'HP': 45.0,
#   'Attack': 25.0,
#   'Defense': 50.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed\n': 35.0},
#  15: {'PokedexNumber': 15.0,
#   'Name': 'BeedrillMega Beedrill',
#   'Type': 'BugPoison',
#   'Total': 495.0,
#   'HP': 65.0,
#   'Attack': 150.0,
#   'Defense': 40.0,
#   'SpecialAttack': 15.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 145.0},
#  16: {'PokedexNumber': 16.0,
#   'Name': 'Pidgey',
#   'Type': 'NormalFlying',
#   'Total': 251.0,
#   'HP': 40.0,
#   'Attack': 45.0,
#   'Defense': 40.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed\n': 56.0},
#  17: {'PokedexNumber': 17.0,
#   'Name': 'Pidgeotto',
#   'Type': 'NormalFlying',
#   'Total': 349.0,
#   'HP': 63.0,
#   'Attack': 60.0,
#   'Defense': 55.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 71.0},
#  18: {'PokedexNumber': 18.0,
#   'Name': 'PidgeotMega Pidgeot',
#   'Type': 'NormalFlying',
#   'Total': 579.0,
#   'HP': 83.0,
#   'Attack': 80.0,
#   'Defense': 80.0,
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 121.0},
#  19: {'PokedexNumber': 19.0,
#   'Name': 'Rattata',
#   'Type': 'Normal',
#   'Total': 253.0,
#   'HP': 30.0,
#   'Attack': 56.0,
#   'Defense': 35.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 35.0,
#   'Speed\n': 72.0},
#  20: {'PokedexNumber': 20.0,
#   'Name': 'Raticate',
#   'Type': 'Normal',
#   'Total': 413.0,
#   'HP': 55.0,
#   'Attack': 81.0,
#   'Defense': 60.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 97.0},
#  21: {'PokedexNumber': 21.0,
#   'Name': 'Spearow',
#   'Type': 'NormalFlying',
#   'Total': 262.0,
#   'HP': 40.0,
#   'Attack': 60.0,
#   'Defense': 30.0,
#   'SpecialAttack': 31.0,
#   'SpecialDefense': 31.0,
#   'Speed\n': 70.0},
#  22: {'PokedexNumber': 22.0,
#   'Name': 'Fearow',
#   'Type': 'NormalFlying',
#   'Total': 442.0,
#   'HP': 65.0,
#   'Attack': 90.0,
#   'Defense': 65.0,
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 61.0,
#   'Speed\n': 100.0},
#  23: {'PokedexNumber': 23.0,
#   'Name': 'Ekans',
#   'Type': 'Poison',
#   'Total': 288.0,
#   'HP': 35.0,
#   'Attack': 60.0,
#   'Defense': 44.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 54.0,
#   'Speed\n': 55.0},
#  24: {'PokedexNumber': 24.0,
#   'Name': 'Arbok',
#   'Type': 'Poison',
#   'Total': 438.0,
#   'HP': 60.0,
#   'Attack': 85.0,
#   'Defense': 69.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 79.0,
#   'Speed\n': 80.0},
#  25: {'PokedexNumber': 25.0,
#   'Name': 'Pikachu',
#   'Type': 'Electric',
#   'Total': 320.0,
#   'HP': 35.0,
#   'Attack': 55.0,
#   'Defense': 40.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 90.0},
#  26: {'PokedexNumber': 26.0,
#   'Name': 'Raichu',
#   'Type': 'Electric',
#   'Total': 485.0,
#   'HP': 60.0,
#   'Attack': 90.0,
#   'Defense': 55.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 110.0},
#  27: {'PokedexNumber': 27.0,
#   'Name': 'Sandshrew',
#   'Type': 'Ground',
#   'Total': 300.0,
#   'HP': 50.0,
#   'Attack': 75.0,
#   'Defense': 85.0,
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 30.0,
#   'Speed\n': 40.0},
#  28: {'PokedexNumber': 28.0,
#   'Name': 'Sandslash',
#   'Type': 'Ground',
#   'Total': 450.0,
#   'HP': 75.0,
#   'Attack': 100.0,
#   'Defense': 110.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 65.0},
#  29: {'PokedexNumber': 29.0,
#   'Name': 'NidoranF',
#   'Type': 'Poison',
#   'Total': 275.0,
#   'HP': 55.0,
#   'Attack': 47.0,
#   'Defense': 52.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 41.0},
#  30: {'PokedexNumber': 30.0,
#   'Name': 'Nidorina',
#   'Type': 'Poison',
#   'Total': 365.0,
#   'HP': 70.0,
#   'Attack': 62.0,
#   'Defense': 67.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 56.0},
#  31: {'PokedexNumber': 31.0,
#   'Name': 'Nidoqueen',
#   'Type': 'PoisonGround',
#   'Total': 505.0,
#   'HP': 90.0,
#   'Attack': 92.0,
#   'Defense': 87.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 76.0},
#  32: {'PokedexNumber': 32.0,
#   'Name': 'NidoranM',
#   'Type': 'Poison',
#   'Total': 273.0,
#   'HP': 46.0,
#   'Attack': 57.0,
#   'Defense': 40.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 50.0},
#  33: {'PokedexNumber': 33.0,
#   'Name': 'Nidorino',
#   'Type': 'Poison',
#   'Total': 365.0,
#   'HP': 61.0,
#   'Attack': 72.0,
#   'Defense': 57.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 65.0},
#  34: {'PokedexNumber': 34.0,
#   'Name': 'Nidoking',
#   'Type': 'PoisonGround',
#   'Total': 505.0,
#   'HP': 81.0,
#   'Attack': 102.0,
#   'Defense': 77.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 85.0},
#  35: {'PokedexNumber': 35.0,
#   'Name': 'Clefairy',
#   'Type': 'Fairy',
#   'Total': 323.0,
#   'HP': 70.0,
#   'Attack': 45.0,
#   'Defense': 48.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 35.0},
#  36: {'PokedexNumber': 36.0,
#   'Name': 'Clefable',
#   'Type': 'Fairy',
#   'Total': 483.0,
#   'HP': 95.0,
#   'Attack': 70.0,
#   'Defense': 73.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 90.0,
#   'Speed\n': 60.0},
#  37: {'PokedexNumber': 37.0,
#   'Name': 'Vulpix',
#   'Type': 'Fire',
#   'Total': 299.0,
#   'HP': 38.0,
#   'Attack': 41.0,
#   'Defense': 40.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 65.0},
#  38: {'PokedexNumber': 38.0,
#   'Name': 'Ninetales',
#   'Type': 'Fire',
#   'Total': 505.0,
#   'HP': 73.0,
#   'Attack': 76.0,
#   'Defense': 75.0,
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 100.0},
#  39: {'PokedexNumber': 39.0,
#   'Name': 'Jigglypuff',
#   'Type': 'NormalFairy',
#   'Total': 270.0,
#   'HP': 115.0,
#   'Attack': 45.0,
#   'Defense': 20.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 25.0,
#   'Speed\n': 20.0},
#  40: {'PokedexNumber': 40.0,
#   'Name': 'Wigglytuff',
#   'Type': 'NormalFairy',
#   'Total': 435.0,
#   'HP': 140.0,
#   'Attack': 70.0,
#   'Defense': 45.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 45.0},
#  41: {'PokedexNumber': 41.0,
#   'Name': 'Zubat',
#   'Type': 'PoisonFlying',
#   'Total': 245.0,
#   'HP': 40.0,
#   'Attack': 45.0,
#   'Defense': 35.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 55.0},
#  42: {'PokedexNumber': 42.0,
#   'Name': 'Golbat',
#   'Type': 'PoisonFlying',
#   'Total': 455.0,
#   'HP': 75.0,
#   'Attack': 80.0,
#   'Defense': 70.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 90.0},
#  43: {'PokedexNumber': 43.0,
#   'Name': 'Oddish',
#   'Type': 'GrassPoison',
#   'Total': 320.0,
#   'HP': 45.0,
#   'Attack': 50.0,
#   'Defense': 55.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 30.0},
#  44: {'PokedexNumber': 44.0,
#   'Name': 'Gloom',
#   'Type': 'GrassPoison',
#   'Total': 395.0,
#   'HP': 60.0,
#   'Attack': 65.0,
#   'Defense': 70.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 40.0},
#  45: {'PokedexNumber': 45.0,
#   'Name': 'Vileplume',
#   'Type': 'GrassPoison',
#   'Total': 490.0,
#   'HP': 75.0,
#   'Attack': 80.0,
#   'Defense': 85.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 90.0,
#   'Speed\n': 50.0},
#  46: {'PokedexNumber': 46.0,
#   'Name': 'Paras',
#   'Type': 'BugGrass',
#   'Total': 285.0,
#   'HP': 35.0,
#   'Attack': 70.0,
#   'Defense': 55.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 25.0},
#  47: {'PokedexNumber': 47.0,
#   'Name': 'Parasect',
#   'Type': 'BugGrass',
#   'Total': 405.0,
#   'HP': 60.0,
#   'Attack': 95.0,
#   'Defense': 80.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 30.0},
#  48: {'PokedexNumber': 48.0,
#   'Name': 'Venonat',
#   'Type': 'BugPoison',
#   'Total': 305.0,
#   'HP': 60.0,
#   'Attack': 55.0,
#   'Defense': 50.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 45.0},
#  49: {'PokedexNumber': 49.0,
#   'Name': 'Venomoth',
#   'Type': 'BugPoison',
#   'Total': 450.0,
#   'HP': 70.0,
#   'Attack': 65.0,
#   'Defense': 60.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 90.0},
#  50: {'PokedexNumber': 50.0,
#   'Name': 'Diglett',
#   'Type': 'Ground',
#   'Total': 265.0,
#   'HP': 10.0,
#   'Attack': 55.0,
#   'Defense': 25.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 95.0},
#  51: {'PokedexNumber': 51.0,
#   'Name': 'Dugtrio',
#   'Type': 'Ground',
#   'Total': 405.0,
#   'HP': 35.0,
#   'Attack': 80.0,
#   'Defense': 50.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 120.0},
#  52: {'PokedexNumber': 52.0,
#   'Name': 'Meowth',
#   'Type': 'Normal',
#   'Total': 290.0,
#   'HP': 40.0,
#   'Attack': 45.0,
#   'Defense': 35.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 90.0},
#  53: {'PokedexNumber': 53.0,
#   'Name': 'Persian',
#   'Type': 'Normal',
#   'Total': 440.0,
#   'HP': 65.0,
#   'Attack': 70.0,
#   'Defense': 60.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 115.0},
#  54: {'PokedexNumber': 54.0,
#   'Name': 'Psyduck',
#   'Type': 'Water',
#   'Total': 320.0,
#   'HP': 50.0,
#   'Attack': 52.0,
#   'Defense': 48.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 55.0},
#  55: {'PokedexNumber': 55.0,
#   'Name': 'Golduck',
#   'Type': 'Water',
#   'Total': 500.0,
#   'HP': 80.0,
#   'Attack': 82.0,
#   'Defense': 78.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 85.0},
#  56: {'PokedexNumber': 56.0,
#   'Name': 'Mankey',
#   'Type': 'Fighting',
#   'Total': 305.0,
#   'HP': 40.0,
#   'Attack': 80.0,
#   'Defense': 35.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 70.0},
#  57: {'PokedexNumber': 57.0,
#   'Name': 'Primeape',
#   'Type': 'Fighting',
#   'Total': 455.0,
#   'HP': 65.0,
#   'Attack': 105.0,
#   'Defense': 60.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 95.0},
#  58: {'PokedexNumber': 58.0,
#   'Name': 'Growlithe',
#   'Type': 'Fire',
#   'Total': 350.0,
#   'HP': 55.0,
#   'Attack': 70.0,
#   'Defense': 45.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 60.0},
#  59: {'PokedexNumber': 59.0,
#   'Name': 'Arcanine',
#   'Type': 'Fire',
#   'Total': 555.0,
#   'HP': 90.0,
#   'Attack': 110.0,
#   'Defense': 80.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 95.0},
#  60: {'PokedexNumber': 60.0,
#   'Name': 'Poliwag',
#   'Type': 'Water',
#   'Total': 300.0,
#   'HP': 40.0,
#   'Attack': 50.0,
#   'Defense': 40.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 90.0},
#  61: {'PokedexNumber': 61.0,
#   'Name': 'Poliwhirl',
#   'Type': 'Water',
#   'Total': 385.0,
#   'HP': 65.0,
#   'Attack': 65.0,
#   'Defense': 65.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 90.0},
#  62: {'PokedexNumber': 62.0,
#   'Name': 'Poliwrath',
#   'Type': 'WaterFighting',
#   'Total': 510.0,
#   'HP': 90.0,
#   'Attack': 95.0,
#   'Defense': 95.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 90.0,
#   'Speed\n': 70.0},
#  63: {'PokedexNumber': 63.0,
#   'Name': 'Abra',
#   'Type': 'Psychic',
#   'Total': 310.0,
#   'HP': 25.0,
#   'Attack': 20.0,
#   'Defense': 15.0,
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 90.0},
#  64: {'PokedexNumber': 64.0,
#   'Name': 'Kadabra',
#   'Type': 'Psychic',
#   'Total': 400.0,
#   'HP': 40.0,
#   'Attack': 35.0,
#   'Defense': 30.0,
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 105.0},
#  65: {'PokedexNumber': 65.0,
#   'Name': 'AlakazamMega Alakazam',
#   'Type': 'Psychic',
#   'Total': 590.0,
#   'HP': 55.0,
#   'Attack': 50.0,
#   'Defense': 65.0,
#   'SpecialAttack': 175.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 150.0},
#  66: {'PokedexNumber': 66.0,
#   'Name': 'Machop',
#   'Type': 'Fighting',
#   'Total': 305.0,
#   'HP': 70.0,
#   'Attack': 80.0,
#   'Defense': 50.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed\n': 35.0},
#  67: {'PokedexNumber': 67.0,
#   'Name': 'Machoke',
#   'Type': 'Fighting',
#   'Total': 405.0,
#   'HP': 80.0,
#   'Attack': 100.0,
#   'Defense': 70.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 45.0},
#  68: {'PokedexNumber': 68.0,
#   'Name': 'Machamp',
#   'Type': 'Fighting',
#   'Total': 505.0,
#   'HP': 90.0,
#   'Attack': 130.0,
#   'Defense': 80.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 55.0},
#  69: {'PokedexNumber': 69.0,
#   'Name': 'Bellsprout',
#   'Type': 'GrassPoison',
#   'Total': 300.0,
#   'HP': 50.0,
#   'Attack': 75.0,
#   'Defense': 35.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 30.0,
#   'Speed\n': 40.0},
#  70: {'PokedexNumber': 70.0,
#   'Name': 'Weepinbell',
#   'Type': 'GrassPoison',
#   'Total': 390.0,
#   'HP': 65.0,
#   'Attack': 90.0,
#   'Defense': 50.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 55.0},
#  71: {'PokedexNumber': 71.0,
#   'Name': 'Victreebel',
#   'Type': 'GrassPoison',
#   'Total': 490.0,
#   'HP': 80.0,
#   'Attack': 105.0,
#   'Defense': 65.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 70.0},
#  72: {'PokedexNumber': 72.0,
#   'Name': 'Tentacool',
#   'Type': 'WaterPoison',
#   'Total': 335.0,
#   'HP': 40.0,
#   'Attack': 40.0,
#   'Defense': 35.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 70.0},
#  73: {'PokedexNumber': 73.0,
#   'Name': 'Tentacruel',
#   'Type': 'WaterPoison',
#   'Total': 515.0,
#   'HP': 80.0,
#   'Attack': 70.0,
#   'Defense': 65.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 120.0,
#   'Speed\n': 100.0},
#  74: {'PokedexNumber': 74.0,
#   'Name': 'Geodude',
#   'Type': 'RockGround',
#   'Total': 300.0,
#   'HP': 40.0,
#   'Attack': 80.0,
#   'Defense': 100.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed\n': 20.0},
#  75: {'PokedexNumber': 75.0,
#   'Name': 'Graveler',
#   'Type': 'RockGround',
#   'Total': 390.0,
#   'HP': 55.0,
#   'Attack': 95.0,
#   'Defense': 115.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 35.0},
#  76: {'PokedexNumber': 76.0,
#   'Name': 'Golem',
#   'Type': 'RockGround',
#   'Total': 495.0,
#   'HP': 80.0,
#   'Attack': 120.0,
#   'Defense': 130.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 45.0},
#  77: {'PokedexNumber': 77.0,
#   'Name': 'Ponyta',
#   'Type': 'Fire',
#   'Total': 410.0,
#   'HP': 50.0,
#   'Attack': 85.0,
#   'Defense': 55.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 90.0},
#  78: {'PokedexNumber': 78.0,
#   'Name': 'Rapidash',
#   'Type': 'Fire',
#   'Total': 500.0,
#   'HP': 65.0,
#   'Attack': 100.0,
#   'Defense': 70.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 105.0},
#  79: {'PokedexNumber': 79.0,
#   'Name': 'Slowpoke',
#   'Type': 'WaterPsychic',
#   'Total': 315.0,
#   'HP': 90.0,
#   'Attack': 65.0,
#   'Defense': 65.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 15.0},
#  80: {'PokedexNumber': 80.0,
#   'Name': 'SlowbroMega Slowbro',
#   'Type': 'WaterPsychic',
#   'Total': 590.0,
#   'HP': 95.0,
#   'Attack': 75.0,
#   'Defense': 180.0,
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 30.0},
#  81: {'PokedexNumber': 81.0,
#   'Name': 'Magnemite',
#   'Type': 'ElectricSteel',
#   'Total': 325.0,
#   'HP': 25.0,
#   'Attack': 35.0,
#   'Defense': 70.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 45.0},
#  82: {'PokedexNumber': 82.0,
#   'Name': 'Magneton',
#   'Type': 'ElectricSteel',
#   'Total': 465.0,
#   'HP': 50.0,
#   'Attack': 60.0,
#   'Defense': 95.0,
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 70.0},
#  83: {'PokedexNumber': 83.0,
#   'Name': "Farfetch'd",
#   'Type': 'NormalFlying',
#   'Total': 352.0,
#   'HP': 52.0,
#   'Attack': 65.0,
#   'Defense': 55.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 62.0,
#   'Speed\n': 60.0},
#  84: {'PokedexNumber': 84.0,
#   'Name': 'Doduo',
#   'Type': 'NormalFlying',
#   'Total': 310.0,
#   'HP': 35.0,
#   'Attack': 85.0,
#   'Defense': 45.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed\n': 75.0},
#  85: {'PokedexNumber': 85.0,
#   'Name': 'Dodrio',
#   'Type': 'NormalFlying',
#   'Total': 460.0,
#   'HP': 60.0,
#   'Attack': 110.0,
#   'Defense': 70.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 100.0},
#  86: {'PokedexNumber': 86.0,
#   'Name': 'Seel',
#   'Type': 'Water',
#   'Total': 325.0,
#   'HP': 65.0,
#   'Attack': 45.0,
#   'Defense': 55.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 45.0},
#  87: {'PokedexNumber': 87.0,
#   'Name': 'Dewgong',
#   'Type': 'WaterIce',
#   'Total': 475.0,
#   'HP': 90.0,
#   'Attack': 70.0,
#   'Defense': 80.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 70.0},
#  88: {'PokedexNumber': 88.0,
#   'Name': 'Grimer',
#   'Type': 'Poison',
#   'Total': 325.0,
#   'HP': 80.0,
#   'Attack': 80.0,
#   'Defense': 50.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 25.0},
#  89: {'PokedexNumber': 89.0,
#   'Name': 'Muk',
#   'Type': 'Poison',
#   'Total': 500.0,
#   'HP': 105.0,
#   'Attack': 105.0,
#   'Defense': 75.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 50.0},
#  90: {'PokedexNumber': 90.0,
#   'Name': 'Shellder',
#   'Type': 'Water',
#   'Total': 305.0,
#   'HP': 30.0,
#   'Attack': 65.0,
#   'Defense': 100.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 25.0,
#   'Speed\n': 40.0},
#  91: {'PokedexNumber': 91.0,
#   'Name': 'Cloyster',
#   'Type': 'WaterIce',
#   'Total': 525.0,
#   'HP': 50.0,
#   'Attack': 95.0,
#   'Defense': 180.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 70.0},
#  92: {'PokedexNumber': 92.0,
#   'Name': 'Gastly',
#   'Type': 'GhostPoison',
#   'Total': 310.0,
#   'HP': 30.0,
#   'Attack': 35.0,
#   'Defense': 30.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 35.0,
#   'Speed\n': 80.0},
#  93: {'PokedexNumber': 93.0,
#   'Name': 'Haunter',
#   'Type': 'GhostPoison',
#   'Total': 405.0,
#   'HP': 45.0,
#   'Attack': 50.0,
#   'Defense': 45.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 95.0},
#  94: {'PokedexNumber': 94.0,
#   'Name': 'GengarMega Gengar',
#   'Type': 'GhostPoison',
#   'Total': 600.0,
#   'HP': 60.0,
#   'Attack': 65.0,
#   'Defense': 80.0,
#   'SpecialAttack': 170.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 130.0},
#  95: {'PokedexNumber': 95.0,
#   'Name': 'Onix',
#   'Type': 'RockGround',
#   'Total': 385.0,
#   'HP': 35.0,
#   'Attack': 45.0,
#   'Defense': 160.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 70.0},
#  96: {'PokedexNumber': 96.0,
#   'Name': 'Drowzee',
#   'Type': 'Psychic',
#   'Total': 328.0,
#   'HP': 60.0,
#   'Attack': 48.0,
#   'Defense': 45.0,
#   'SpecialAttack': 43.0,
#   'SpecialDefense': 90.0,
#   'Speed\n': 42.0},
#  97: {'PokedexNumber': 97.0,
#   'Name': 'Hypno',
#   'Type': 'Psychic',
#   'Total': 483.0,
#   'HP': 85.0,
#   'Attack': 73.0,
#   'Defense': 70.0,
#   'SpecialAttack': 73.0,
#   'SpecialDefense': 115.0,
#   'Speed\n': 67.0},
#  98: {'PokedexNumber': 98.0,
#   'Name': 'Krabby',
#   'Type': 'Water',
#   'Total': 325.0,
#   'HP': 30.0,
#   'Attack': 105.0,
#   'Defense': 90.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed\n': 50.0},
#  99: {'PokedexNumber': 99.0,
#   'Name': 'Kingler',
#   'Type': 'Water',
#   'Total': 475.0,
#   'HP': 55.0,
#   'Attack': 130.0,
#   'Defense': 115.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 75.0},
#  100: {'PokedexNumber': 100.0,
#   'Name': 'Voltorb',
#   'Type': 'Electric',
#   'Total': 330.0,
#   'HP': 40.0,
#   'Attack': 30.0,
#   'Defense': 50.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 100.0},
#  101: {'PokedexNumber': 101.0,
#   'Name': 'Electrode',
#   'Type': 'Electric',
#   'Total': 480.0,
#   'HP': 60.0,
#   'Attack': 50.0,
#   'Defense': 70.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 140.0},
#  102: {'PokedexNumber': 102.0,
#   'Name': 'Exeggcute',
#   'Type': 'GrassPsychic',
#   'Total': 325.0,
#   'HP': 60.0,
#   'Attack': 40.0,
#   'Defense': 80.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 40.0},
#  103: {'PokedexNumber': 103.0,
#   'Name': 'Exeggutor',
#   'Type': 'GrassPsychic',
#   'Total': 520.0,
#   'HP': 95.0,
#   'Attack': 95.0,
#   'Defense': 85.0,
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 55.0},
#  104: {'PokedexNumber': 104.0,
#   'Name': 'Cubone',
#   'Type': 'Ground',
#   'Total': 320.0,
#   'HP': 50.0,
#   'Attack': 50.0,
#   'Defense': 95.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 35.0},
#  105: {'PokedexNumber': 105.0,
#   'Name': 'Marowak',
#   'Type': 'Ground',
#   'Total': 425.0,
#   'HP': 60.0,
#   'Attack': 80.0,
#   'Defense': 110.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 45.0},
#  106: {'PokedexNumber': 106.0,
#   'Name': 'Hitmonlee',
#   'Type': 'Fighting',
#   'Total': 455.0,
#   'HP': 50.0,
#   'Attack': 120.0,
#   'Defense': 53.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 110.0,
#   'Speed\n': 87.0},
#  107: {'PokedexNumber': 107.0,
#   'Name': 'Hitmonchan',
#   'Type': 'Fighting',
#   'Total': 455.0,
#   'HP': 50.0,
#   'Attack': 105.0,
#   'Defense': 79.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 110.0,
#   'Speed\n': 76.0},
#  108: {'PokedexNumber': 108.0,
#   'Name': 'Lickitung',
#   'Type': 'Normal',
#   'Total': 385.0,
#   'HP': 90.0,
#   'Attack': 55.0,
#   'Defense': 75.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 30.0},
#  109: {'PokedexNumber': 109.0,
#   'Name': 'Koffing',
#   'Type': 'Poison',
#   'Total': 340.0,
#   'HP': 40.0,
#   'Attack': 65.0,
#   'Defense': 95.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 35.0},
#  110: {'PokedexNumber': 110.0,
#   'Name': 'Weezing',
#   'Type': 'Poison',
#   'Total': 490.0,
#   'HP': 65.0,
#   'Attack': 90.0,
#   'Defense': 120.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 60.0},
#  111: {'PokedexNumber': 111.0,
#   'Name': 'Rhyhorn',
#   'Type': 'GroundRock',
#   'Total': 345.0,
#   'HP': 80.0,
#   'Attack': 85.0,
#   'Defense': 95.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed\n': 25.0},
#  112: {'PokedexNumber': 112.0,
#   'Name': 'Rhydon',
#   'Type': 'GroundRock',
#   'Total': 485.0,
#   'HP': 105.0,
#   'Attack': 130.0,
#   'Defense': 120.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 40.0},
#  113: {'PokedexNumber': 113.0,
#   'Name': 'Chansey',
#   'Type': 'Normal',
#   'Total': 450.0,
#   'HP': 250.0,
#   'Attack': 5.0,
#   'Defense': 5.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 105.0,
#   'Speed\n': 50.0},
#  114: {'PokedexNumber': 114.0,
#   'Name': 'Tangela',
#   'Type': 'Grass',
#   'Total': 435.0,
#   'HP': 65.0,
#   'Attack': 55.0,
#   'Defense': 115.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 60.0},
#  115: {'PokedexNumber': 115.0,
#   'Name': 'KangaskhanMega Kangaskhan',
#   'Type': 'Normal',
#   'Total': 590.0,
#   'HP': 105.0,
#   'Attack': 125.0,
#   'Defense': 100.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 100.0},
#  116: {'PokedexNumber': 116.0,
#   'Name': 'Horsea',
#   'Type': 'Water',
#   'Total': 295.0,
#   'HP': 30.0,
#   'Attack': 40.0,
#   'Defense': 70.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 25.0,
#   'Speed\n': 60.0},
#  117: {'PokedexNumber': 117.0,
#   'Name': 'Seadra',
#   'Type': 'Water',
#   'Total': 440.0,
#   'HP': 55.0,
#   'Attack': 65.0,
#   'Defense': 95.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 85.0},
#  118: {'PokedexNumber': 118.0,
#   'Name': 'Goldeen',
#   'Type': 'Water',
#   'Total': 320.0,
#   'HP': 45.0,
#   'Attack': 67.0,
#   'Defense': 60.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 63.0},
#  119: {'PokedexNumber': 119.0,
#   'Name': 'Seaking',
#   'Type': 'Water',
#   'Total': 450.0,
#   'HP': 80.0,
#   'Attack': 92.0,
#   'Defense': 65.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 68.0},
#  120: {'PokedexNumber': 120.0,
#   'Name': 'Staryu',
#   'Type': 'Water',
#   'Total': 340.0,
#   'HP': 30.0,
#   'Attack': 45.0,
#   'Defense': 55.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 85.0},
#  121: {'PokedexNumber': 121.0,
#   'Name': 'Starmie',
#   'Type': 'WaterPsychic',
#   'Total': 520.0,
#   'HP': 60.0,
#   'Attack': 75.0,
#   'Defense': 85.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 115.0},
#  122: {'PokedexNumber': 122.0,
#   'Name': 'Mr. Mime',
#   'Type': 'PsychicFairy',
#   'Total': 460.0,
#   'HP': 40.0,
#   'Attack': 45.0,
#   'Defense': 65.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 120.0,
#   'Speed\n': 90.0},
#  123: {'PokedexNumber': 123.0,
#   'Name': 'Scyther',
#   'Type': 'BugFlying',
#   'Total': 500.0,
#   'HP': 70.0,
#   'Attack': 110.0,
#   'Defense': 80.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 105.0},
#  124: {'PokedexNumber': 124.0,
#   'Name': 'Jynx',
#   'Type': 'IcePsychic',
#   'Total': 455.0,
#   'HP': 65.0,
#   'Attack': 50.0,
#   'Defense': 35.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 95.0},
#  125: {'PokedexNumber': 125.0,
#   'Name': 'Electabuzz',
#   'Type': 'Electric',
#   'Total': 490.0,
#   'HP': 65.0,
#   'Attack': 83.0,
#   'Defense': 57.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 105.0},
#  126: {'PokedexNumber': 126.0,
#   'Name': 'Magmar',
#   'Type': 'Fire',
#   'Total': 495.0,
#   'HP': 65.0,
#   'Attack': 95.0,
#   'Defense': 57.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 93.0},
#  127: {'PokedexNumber': 127.0,
#   'Name': 'PinsirMega Pinsir',
#   'Type': 'BugFlying',
#   'Total': 600.0,
#   'HP': 65.0,
#   'Attack': 155.0,
#   'Defense': 120.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 90.0,
#   'Speed\n': 105.0},
#  128: {'PokedexNumber': 128.0,
#   'Name': 'Tauros',
#   'Type': 'Normal',
#   'Total': 490.0,
#   'HP': 75.0,
#   'Attack': 100.0,
#   'Defense': 95.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 110.0},
#  129: {'PokedexNumber': 129.0,
#   'Name': 'Magikarp',
#   'Type': 'Water',
#   'Total': 200.0,
#   'HP': 20.0,
#   'Attack': 10.0,
#   'Defense': 55.0,
#   'SpecialAttack': 15.0,
#   'SpecialDefense': 20.0,
#   'Speed\n': 80.0},
#  130: {'PokedexNumber': 130.0,
#   'Name': 'GyaradosMega Gyarados',
#   'Type': 'WaterDark',
#   'Total': 640.0,
#   'HP': 95.0,
#   'Attack': 155.0,
#   'Defense': 109.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 130.0,
#   'Speed\n': 81.0},
#  131: {'PokedexNumber': 131.0,
#   'Name': 'Lapras',
#   'Type': 'WaterIce',
#   'Total': 535.0,
#   'HP': 130.0,
#   'Attack': 85.0,
#   'Defense': 80.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 60.0},
#  132: {'PokedexNumber': 132.0,
#   'Name': 'Ditto',
#   'Type': 'Normal',
#   'Total': 288.0,
#   'HP': 48.0,
#   'Attack': 48.0,
#   'Defense': 48.0,
#   'SpecialAttack': 48.0,
#   'SpecialDefense': 48.0,
#   'Speed\n': 48.0},
#  133: {'PokedexNumber': 133.0,
#   'Name': 'Eevee',
#   'Type': 'Normal',
#   'Total': 325.0,
#   'HP': 55.0,
#   'Attack': 55.0,
#   'Defense': 50.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 55.0},
#  134: {'PokedexNumber': 134.0,
#   'Name': 'Vaporeon',
#   'Type': 'Water',
#   'Total': 525.0,
#   'HP': 130.0,
#   'Attack': 65.0,
#   'Defense': 60.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 65.0},
#  135: {'PokedexNumber': 135.0,
#   'Name': 'Jolteon',
#   'Type': 'Electric',
#   'Total': 525.0,
#   'HP': 65.0,
#   'Attack': 65.0,
#   'Defense': 60.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 130.0},
#  136: {'PokedexNumber': 136.0,
#   'Name': 'Flareon',
#   'Type': 'Fire',
#   'Total': 525.0,
#   'HP': 65.0,
#   'Attack': 130.0,
#   'Defense': 60.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 110.0,
#   'Speed\n': 65.0},
#  137: {'PokedexNumber': 137.0,
#   'Name': 'Porygon',
#   'Type': 'Normal',
#   'Total': 395.0,
#   'HP': 65.0,
#   'Attack': 60.0,
#   'Defense': 70.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 40.0},
#  138: {'PokedexNumber': 138.0,
#   'Name': 'Omanyte',
#   'Type': 'RockWater',
#   'Total': 355.0,
#   'HP': 35.0,
#   'Attack': 40.0,
#   'Defense': 100.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 35.0},
#  139: {'PokedexNumber': 139.0,
#   'Name': 'Omastar',
#   'Type': 'RockWater',
#   'Total': 495.0,
#   'HP': 70.0,
#   'Attack': 60.0,
#   'Defense': 125.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 55.0},
#  140: {'PokedexNumber': 140.0,
#   'Name': 'Kabuto',
#   'Type': 'RockWater',
#   'Total': 355.0,
#   'HP': 30.0,
#   'Attack': 80.0,
#   'Defense': 90.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 55.0},
#  141: {'PokedexNumber': 141.0,
#   'Name': 'Kabutops',
#   'Type': 'RockWater',
#   'Total': 495.0,
#   'HP': 60.0,
#   'Attack': 115.0,
#   'Defense': 105.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 80.0},
#  142: {'PokedexNumber': 142.0,
#   'Name': 'AerodactylMega Aerodactyl',
#   'Type': 'RockFlying',
#   'Total': 615.0,
#   'HP': 80.0,
#   'Attack': 135.0,
#   'Defense': 85.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 150.0},
#  143: {'PokedexNumber': 143.0,
#   'Name': 'Snorlax',
#   'Type': 'Normal',
#   'Total': 540.0,
#   'HP': 160.0,
#   'Attack': 110.0,
#   'Defense': 65.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 110.0,
#   'Speed\n': 30.0},
#  144: {'PokedexNumber': 144.0,
#   'Name': 'Articuno',
#   'Type': 'IceFlying',
#   'Total': 580.0,
#   'HP': 90.0,
#   'Attack': 85.0,
#   'Defense': 100.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 125.0,
#   'Speed\n': 85.0},
#  145: {'PokedexNumber': 145.0,
#   'Name': 'Zapdos',
#   'Type': 'ElectricFlying',
#   'Total': 580.0,
#   'HP': 90.0,
#   'Attack': 90.0,
#   'Defense': 85.0,
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 90.0,
#   'Speed\n': 100.0},
#  146: {'PokedexNumber': 146.0,
#   'Name': 'Moltres',
#   'Type': 'FireFlying',
#   'Total': 580.0,
#   'HP': 90.0,
#   'Attack': 100.0,
#   'Defense': 90.0,
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 90.0},
#  147: {'PokedexNumber': 147.0,
#   'Name': 'Dratini',
#   'Type': 'Dragon',
#   'Total': 300.0,
#   'HP': 41.0,
#   'Attack': 64.0,
#   'Defense': 45.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 50.0},
#  148: {'PokedexNumber': 148.0,
#   'Name': 'Dragonair',
#   'Type': 'Dragon',
#   'Total': 420.0,
#   'HP': 61.0,
#   'Attack': 84.0,
#   'Defense': 65.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 70.0},
#  149: {'PokedexNumber': 149.0,
#   'Name': 'Dragonite',
#   'Type': 'DragonFlying',
#   'Total': 600.0,
#   'HP': 91.0,
#   'Attack': 134.0,
#   'Defense': 95.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 80.0},
#  150: {'PokedexNumber': 150.0,
#   'Name': 'MewtwoMega Mewtwo Y',
#   'Type': 'Psychic',
#   'Total': 780.0,
#   'HP': 106.0,
#   'Attack': 150.0,
#   'Defense': 70.0,
#   'SpecialAttack': 194.0,
#   'SpecialDefense': 120.0,
#   'Speed\n': 140.0},
#  151: {'PokedexNumber': 151.0,
#   'Name': 'Mew',
#   'Type': 'Psychic',
#   'Total': 600.0,
#   'HP': 100.0,
#   'Attack': 100.0,
#   'Defense': 100.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 100.0},
#  152: {'PokedexNumber': 152.0,
#   'Name': 'Chikorita',
#   'Type': 'Grass',
#   'Total': 318.0,
#   'HP': 45.0,
#   'Attack': 49.0,
#   'Defense': 65.0,
#   'SpecialAttack': 49.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 45.0},
#  153: {'PokedexNumber': 153.0,
#   'Name': 'Bayleef',
#   'Type': 'Grass',
#   'Total': 405.0,
#   'HP': 60.0,
#   'Attack': 62.0,
#   'Defense': 80.0,
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 60.0},
#  154: {'PokedexNumber': 154.0,
#   'Name': 'Meganium',
#   'Type': 'Grass',
#   'Total': 525.0,
#   'HP': 80.0,
#   'Attack': 82.0,
#   'Defense': 100.0,
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 80.0},
#  155: {'PokedexNumber': 155.0,
#   'Name': 'Cyndaquil',
#   'Type': 'Fire',
#   'Total': 309.0,
#   'HP': 39.0,
#   'Attack': 52.0,
#   'Defense': 43.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 65.0},
#  156: {'PokedexNumber': 156.0,
#   'Name': 'Quilava',
#   'Type': 'Fire',
#   'Total': 405.0,
#   'HP': 58.0,
#   'Attack': 64.0,
#   'Defense': 58.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 80.0},
#  157: {'PokedexNumber': 157.0,
#   'Name': 'Typhlosion',
#   'Type': 'Fire',
#   'Total': 534.0,
#   'HP': 78.0,
#   'Attack': 84.0,
#   'Defense': 78.0,
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 100.0},
#  158: {'PokedexNumber': 158.0,
#   'Name': 'Totodile',
#   'Type': 'Water',
#   'Total': 314.0,
#   'HP': 50.0,
#   'Attack': 65.0,
#   'Defense': 64.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 48.0,
#   'Speed\n': 43.0},
#  159: {'PokedexNumber': 159.0,
#   'Name': 'Croconaw',
#   'Type': 'Water',
#   'Total': 405.0,
#   'HP': 65.0,
#   'Attack': 80.0,
#   'Defense': 80.0,
#   'SpecialAttack': 59.0,
#   'SpecialDefense': 63.0,
#   'Speed\n': 58.0},
#  160: {'PokedexNumber': 160.0,
#   'Name': 'Feraligatr',
#   'Type': 'Water',
#   'Total': 530.0,
#   'HP': 85.0,
#   'Attack': 105.0,
#   'Defense': 100.0,
#   'SpecialAttack': 79.0,
#   'SpecialDefense': 83.0,
#   'Speed\n': 78.0},
#  161: {'PokedexNumber': 161.0,
#   'Name': 'Sentret',
#   'Type': 'Normal',
#   'Total': 215.0,
#   'HP': 35.0,
#   'Attack': 46.0,
#   'Defense': 34.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 20.0},
#  162: {'PokedexNumber': 162.0,
#   'Name': 'Furret',
#   'Type': 'Normal',
#   'Total': 415.0,
#   'HP': 85.0,
#   'Attack': 76.0,
#   'Defense': 64.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 90.0},
#  163: {'PokedexNumber': 163.0,
#   'Name': 'Hoothoot',
#   'Type': 'NormalFlying',
#   'Total': 262.0,
#   'HP': 60.0,
#   'Attack': 30.0,
#   'Defense': 30.0,
#   'SpecialAttack': 36.0,
#   'SpecialDefense': 56.0,
#   'Speed\n': 50.0},
#  164: {'PokedexNumber': 164.0,
#   'Name': 'Noctowl',
#   'Type': 'NormalFlying',
#   'Total': 442.0,
#   'HP': 100.0,
#   'Attack': 50.0,
#   'Defense': 50.0,
#   'SpecialAttack': 76.0,
#   'SpecialDefense': 96.0,
#   'Speed\n': 70.0},
#  165: {'PokedexNumber': 165.0,
#   'Name': 'Ledyba',
#   'Type': 'BugFlying',
#   'Total': 265.0,
#   'HP': 40.0,
#   'Attack': 20.0,
#   'Defense': 30.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 55.0},
#  166: {'PokedexNumber': 166.0,
#   'Name': 'Ledian',
#   'Type': 'BugFlying',
#   'Total': 390.0,
#   'HP': 55.0,
#   'Attack': 35.0,
#   'Defense': 50.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 110.0,
#   'Speed\n': 85.0},
#  167: {'PokedexNumber': 167.0,
#   'Name': 'Spinarak',
#   'Type': 'BugPoison',
#   'Total': 250.0,
#   'HP': 40.0,
#   'Attack': 60.0,
#   'Defense': 40.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 30.0},
#  168: {'PokedexNumber': 168.0,
#   'Name': 'Ariados',
#   'Type': 'BugPoison',
#   'Total': 390.0,
#   'HP': 70.0,
#   'Attack': 90.0,
#   'Defense': 70.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 40.0},
#  169: {'PokedexNumber': 169.0,
#   'Name': 'Crobat',
#   'Type': 'PoisonFlying',
#   'Total': 535.0,
#   'HP': 85.0,
#   'Attack': 90.0,
#   'Defense': 80.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 130.0},
#  170: {'PokedexNumber': 170.0,
#   'Name': 'Chinchou',
#   'Type': 'WaterElectric',
#   'Total': 330.0,
#   'HP': 75.0,
#   'Attack': 38.0,
#   'Defense': 38.0,
#   'SpecialAttack': 56.0,
#   'SpecialDefense': 56.0,
#   'Speed\n': 67.0},
#  171: {'PokedexNumber': 171.0,
#   'Name': 'Lanturn',
#   'Type': 'WaterElectric',
#   'Total': 460.0,
#   'HP': 125.0,
#   'Attack': 58.0,
#   'Defense': 58.0,
#   'SpecialAttack': 76.0,
#   'SpecialDefense': 76.0,
#   'Speed\n': 67.0},
#  172: {'PokedexNumber': 172.0,
#   'Name': 'Pichu',
#   'Type': 'Electric',
#   'Total': 205.0,
#   'HP': 20.0,
#   'Attack': 40.0,
#   'Defense': 15.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed\n': 60.0},
#  173: {'PokedexNumber': 173.0,
#   'Name': 'Cleffa',
#   'Type': 'Fairy',
#   'Total': 218.0,
#   'HP': 50.0,
#   'Attack': 25.0,
#   'Defense': 28.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 15.0},
#  174: {'PokedexNumber': 174.0,
#   'Name': 'Igglybuff',
#   'Type': 'NormalFairy',
#   'Total': 210.0,
#   'HP': 90.0,
#   'Attack': 30.0,
#   'Defense': 15.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 20.0,
#   'Speed\n': 15.0},
#  175: {'PokedexNumber': 175.0,
#   'Name': 'Togepi',
#   'Type': 'Fairy',
#   'Total': 245.0,
#   'HP': 35.0,
#   'Attack': 20.0,
#   'Defense': 65.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 20.0},
#  176: {'PokedexNumber': 176.0,
#   'Name': 'Togetic',
#   'Type': 'FairyFlying',
#   'Total': 405.0,
#   'HP': 55.0,
#   'Attack': 40.0,
#   'Defense': 85.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 105.0,
#   'Speed\n': 40.0},
#  177: {'PokedexNumber': 177.0,
#   'Name': 'Natu',
#   'Type': 'PsychicFlying',
#   'Total': 320.0,
#   'HP': 40.0,
#   'Attack': 50.0,
#   'Defense': 45.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 70.0},
#  178: {'PokedexNumber': 178.0,
#   'Name': 'Xatu',
#   'Type': 'PsychicFlying',
#   'Total': 470.0,
#   'HP': 65.0,
#   'Attack': 75.0,
#   'Defense': 70.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 95.0},
#  179: {'PokedexNumber': 179.0,
#   'Name': 'Mareep',
#   'Type': 'Electric',
#   'Total': 280.0,
#   'HP': 55.0,
#   'Attack': 40.0,
#   'Defense': 40.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 35.0},
#  180: {'PokedexNumber': 180.0,
#   'Name': 'Flaaffy',
#   'Type': 'Electric',
#   'Total': 365.0,
#   'HP': 70.0,
#   'Attack': 55.0,
#   'Defense': 55.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 45.0},
#  181: {'PokedexNumber': 181.0,
#   'Name': 'AmpharosMega Ampharos',
#   'Type': 'ElectricDragon',
#   'Total': 610.0,
#   'HP': 90.0,
#   'Attack': 95.0,
#   'Defense': 105.0,
#   'SpecialAttack': 165.0,
#   'SpecialDefense': 110.0,
#   'Speed\n': 45.0},
#  182: {'PokedexNumber': 182.0,
#   'Name': 'Bellossom',
#   'Type': 'Grass',
#   'Total': 490.0,
#   'HP': 75.0,
#   'Attack': 80.0,
#   'Defense': 95.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 50.0},
#  183: {'PokedexNumber': 183.0,
#   'Name': 'Marill',
#   'Type': 'WaterFairy',
#   'Total': 250.0,
#   'HP': 70.0,
#   'Attack': 20.0,
#   'Defense': 50.0,
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 40.0},
#  184: {'PokedexNumber': 184.0,
#   'Name': 'Azumarill',
#   'Type': 'WaterFairy',
#   'Total': 420.0,
#   'HP': 100.0,
#   'Attack': 50.0,
#   'Defense': 80.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 50.0},
#  185: {'PokedexNumber': 185.0,
#   'Name': 'Sudowoodo',
#   'Type': 'Rock',
#   'Total': 410.0,
#   'HP': 70.0,
#   'Attack': 100.0,
#   'Defense': 115.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 30.0},
#  186: {'PokedexNumber': 186.0,
#   'Name': 'Politoed',
#   'Type': 'Water',
#   'Total': 500.0,
#   'HP': 90.0,
#   'Attack': 75.0,
#   'Defense': 75.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 70.0},
#  187: {'PokedexNumber': 187.0,
#   'Name': 'Hoppip',
#   'Type': 'GrassFlying',
#   'Total': 250.0,
#   'HP': 35.0,
#   'Attack': 35.0,
#   'Defense': 40.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 50.0},
#  188: {'PokedexNumber': 188.0,
#   'Name': 'Skiploom',
#   'Type': 'GrassFlying',
#   'Total': 340.0,
#   'HP': 55.0,
#   'Attack': 45.0,
#   'Defense': 50.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 80.0},
#  189: {'PokedexNumber': 189.0,
#   'Name': 'Jumpluff',
#   'Type': 'GrassFlying',
#   'Total': 460.0,
#   'HP': 75.0,
#   'Attack': 55.0,
#   'Defense': 70.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 110.0},
#  190: {'PokedexNumber': 190.0,
#   'Name': 'Aipom',
#   'Type': 'Normal',
#   'Total': 360.0,
#   'HP': 55.0,
#   'Attack': 70.0,
#   'Defense': 55.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 85.0},
#  191: {'PokedexNumber': 191.0,
#   'Name': 'Sunkern',
#   'Type': 'Grass',
#   'Total': 180.0,
#   'HP': 30.0,
#   'Attack': 30.0,
#   'Defense': 30.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed\n': 30.0},
#  192: {'PokedexNumber': 192.0,
#   'Name': 'Sunflora',
#   'Type': 'Grass',
#   'Total': 425.0,
#   'HP': 75.0,
#   'Attack': 75.0,
#   'Defense': 55.0,
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 30.0},
#  193: {'PokedexNumber': 193.0,
#   'Name': 'Yanma',
#   'Type': 'BugFlying',
#   'Total': 390.0,
#   'HP': 65.0,
#   'Attack': 65.0,
#   'Defense': 45.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 95.0},
#  194: {'PokedexNumber': 194.0,
#   'Name': 'Wooper',
#   'Type': 'WaterGround',
#   'Total': 210.0,
#   'HP': 55.0,
#   'Attack': 45.0,
#   'Defense': 45.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed\n': 15.0},
#  195: {'PokedexNumber': 195.0,
#   'Name': 'Quagsire',
#   'Type': 'WaterGround',
#   'Total': 430.0,
#   'HP': 95.0,
#   'Attack': 85.0,
#   'Defense': 85.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 35.0},
#  196: {'PokedexNumber': 196.0,
#   'Name': 'Espeon',
#   'Type': 'Psychic',
#   'Total': 525.0,
#   'HP': 65.0,
#   'Attack': 65.0,
#   'Defense': 60.0,
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 110.0},
#  197: {'PokedexNumber': 197.0,
#   'Name': 'Umbreon',
#   'Type': 'Dark',
#   'Total': 525.0,
#   'HP': 95.0,
#   'Attack': 65.0,
#   'Defense': 110.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 130.0,
#   'Speed\n': 65.0},
#  198: {'PokedexNumber': 198.0,
#   'Name': 'Murkrow',
#   'Type': 'DarkFlying',
#   'Total': 405.0,
#   'HP': 60.0,
#   'Attack': 85.0,
#   'Defense': 42.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 42.0,
#   'Speed\n': 91.0},
#  199: {'PokedexNumber': 199.0,
#   'Name': 'Slowking',
#   'Type': 'WaterPsychic',
#   'Total': 490.0,
#   'HP': 95.0,
#   'Attack': 75.0,
#   'Defense': 80.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 110.0,
#   'Speed\n': 30.0},
#  200: {'PokedexNumber': 200.0,
#   'Name': 'Misdreavus',
#   'Type': 'Ghost',
#   'Total': 435.0,
#   'HP': 60.0,
#   'Attack': 60.0,
#   'Defense': 60.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 85.0},
#  201: {'PokedexNumber': 201.0,
#   'Name': 'Unown',
#   'Type': 'Psychic',
#   'Total': 336.0,
#   'HP': 48.0,
#   'Attack': 72.0,
#   'Defense': 48.0,
#   'SpecialAttack': 72.0,
#   'SpecialDefense': 48.0,
#   'Speed\n': 48.0},
#  202: {'PokedexNumber': 202.0,
#   'Name': 'Wobbuffet',
#   'Type': 'Psychic',
#   'Total': 405.0,
#   'HP': 190.0,
#   'Attack': 33.0,
#   'Defense': 58.0,
#   'SpecialAttack': 33.0,
#   'SpecialDefense': 58.0,
#   'Speed\n': 33.0},
#  203: {'PokedexNumber': 203.0,
#   'Name': 'Girafarig',
#   'Type': 'NormalPsychic',
#   'Total': 455.0,
#   'HP': 70.0,
#   'Attack': 80.0,
#   'Defense': 65.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 85.0},
#  204: {'PokedexNumber': 204.0,
#   'Name': 'Pineco',
#   'Type': 'Bug',
#   'Total': 290.0,
#   'HP': 50.0,
#   'Attack': 65.0,
#   'Defense': 90.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed\n': 15.0},
#  205: {'PokedexNumber': 205.0,
#   'Name': 'Forretress',
#   'Type': 'BugSteel',
#   'Total': 465.0,
#   'HP': 75.0,
#   'Attack': 90.0,
#   'Defense': 140.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 40.0},
#  206: {'PokedexNumber': 206.0,
#   'Name': 'Dunsparce',
#   'Type': 'Normal',
#   'Total': 415.0,
#   'HP': 100.0,
#   'Attack': 70.0,
#   'Defense': 70.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 45.0},
#  207: {'PokedexNumber': 207.0,
#   'Name': 'Gligar',
#   'Type': 'GroundFlying',
#   'Total': 430.0,
#   'HP': 65.0,
#   'Attack': 75.0,
#   'Defense': 105.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 85.0},
#  208: {'PokedexNumber': 208.0,
#   'Name': 'SteelixMega Steelix',
#   'Type': 'SteelGround',
#   'Total': 610.0,
#   'HP': 75.0,
#   'Attack': 125.0,
#   'Defense': 230.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 30.0},
#  209: {'PokedexNumber': 209.0,
#   'Name': 'Snubbull',
#   'Type': 'Fairy',
#   'Total': 300.0,
#   'HP': 60.0,
#   'Attack': 80.0,
#   'Defense': 50.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 30.0},
#  210: {'PokedexNumber': 210.0,
#   'Name': 'Granbull',
#   'Type': 'Fairy',
#   'Total': 450.0,
#   'HP': 90.0,
#   'Attack': 120.0,
#   'Defense': 75.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 45.0},
#  211: {'PokedexNumber': 211.0,
#   'Name': 'Qwilfish',
#   'Type': 'WaterPoison',
#   'Total': 430.0,
#   'HP': 65.0,
#   'Attack': 95.0,
#   'Defense': 75.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 85.0},
#  212: {'PokedexNumber': 212.0,
#   'Name': 'ScizorMega Scizor',
#   'Type': 'BugSteel',
#   'Total': 600.0,
#   'HP': 70.0,
#   'Attack': 150.0,
#   'Defense': 140.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 75.0},
#  213: {'PokedexNumber': 213.0,
#   'Name': 'Shuckle',
#   'Type': 'BugRock',
#   'Total': 505.0,
#   'HP': 20.0,
#   'Attack': 10.0,
#   'Defense': 230.0,
#   'SpecialAttack': 10.0,
#   'SpecialDefense': 230.0,
#   'Speed\n': 5.0},
#  214: {'PokedexNumber': 214.0,
#   'Name': 'HeracrossMega Heracross',
#   'Type': 'BugFighting',
#   'Total': 600.0,
#   'HP': 80.0,
#   'Attack': 185.0,
#   'Defense': 115.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 105.0,
#   'Speed\n': 75.0},
#  215: {'PokedexNumber': 215.0,
#   'Name': 'Sneasel',
#   'Type': 'DarkIce',
#   'Total': 430.0,
#   'HP': 55.0,
#   'Attack': 95.0,
#   'Defense': 55.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 115.0},
#  216: {'PokedexNumber': 216.0,
#   'Name': 'Teddiursa',
#   'Type': 'Normal',
#   'Total': 330.0,
#   'HP': 60.0,
#   'Attack': 80.0,
#   'Defense': 50.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 40.0},
#  217: {'PokedexNumber': 217.0,
#   'Name': 'Ursaring',
#   'Type': 'Normal',
#   'Total': 500.0,
#   'HP': 90.0,
#   'Attack': 130.0,
#   'Defense': 75.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 55.0},
#  218: {'PokedexNumber': 218.0,
#   'Name': 'Slugma',
#   'Type': 'Fire',
#   'Total': 250.0,
#   'HP': 40.0,
#   'Attack': 40.0,
#   'Defense': 40.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 20.0},
#  219: {'PokedexNumber': 219.0,
#   'Name': 'Magcargo',
#   'Type': 'FireRock',
#   'Total': 410.0,
#   'HP': 50.0,
#   'Attack': 50.0,
#   'Defense': 120.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 30.0},
#  220: {'PokedexNumber': 220.0,
#   'Name': 'Swinub',
#   'Type': 'IceGround',
#   'Total': 250.0,
#   'HP': 50.0,
#   'Attack': 50.0,
#   'Defense': 40.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed\n': 50.0},
#  221: {'PokedexNumber': 221.0,
#   'Name': 'Piloswine',
#   'Type': 'IceGround',
#   'Total': 450.0,
#   'HP': 100.0,
#   'Attack': 100.0,
#   'Defense': 80.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 50.0},
#  222: {'PokedexNumber': 222.0,
#   'Name': 'Corsola',
#   'Type': 'WaterRock',
#   'Total': 380.0,
#   'HP': 55.0,
#   'Attack': 55.0,
#   'Defense': 85.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 85.0,
#   'Speed\n': 35.0},
#  223: {'PokedexNumber': 223.0,
# ...
#   'Type': 'NormalFighting',
#   'Total': 600.0,
#   'HP': 100.0,
#   'Attack': 128.0,
#   'Defense': 90.0,
#   'SpecialAttack': 77.0,
#   'SpecialDefense': 77.0,
#   'Speed\n': 128.0},
#  649: {'PokedexNumber': 649.0,
#   'Name': 'Genesect',
#   'Type': 'BugSteel',
#   'Total': 600.0,
#   'HP': 71.0,
#   'Attack': 120.0,
#   'Defense': 95.0,
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 99.0},
#  650: {'PokedexNumber': 650.0,
#   'Name': 'Chespin',
#   'Type': 'Grass',
#   'Total': 313.0,
#   'HP': 56.0,
#   'Attack': 61.0,
#   'Defense': 65.0,
#   'SpecialAttack': 48.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 38.0},
#  651: {'PokedexNumber': 651.0,
#   'Name': 'Quilladin',
#   'Type': 'Grass',
#   'Total': 405.0,
#   'HP': 61.0,
#   'Attack': 78.0,
#   'Defense': 95.0,
#   'SpecialAttack': 56.0,
#   'SpecialDefense': 58.0,
#   'Speed\n': 57.0},
#  652: {'PokedexNumber': 652.0,
#   'Name': 'Chesnaught',
#   'Type': 'GrassFighting',
#   'Total': 530.0,
#   'HP': 88.0,
#   'Attack': 107.0,
#   'Defense': 122.0,
#   'SpecialAttack': 74.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 64.0},
#  653: {'PokedexNumber': 653.0,
#   'Name': 'Fennekin',
#   'Type': 'Fire',
#   'Total': 307.0,
#   'HP': 40.0,
#   'Attack': 45.0,
#   'Defense': 40.0,
#   'SpecialAttack': 62.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 60.0},
#  654: {'PokedexNumber': 654.0,
#   'Name': 'Braixen',
#   'Type': 'Fire',
#   'Total': 409.0,
#   'HP': 59.0,
#   'Attack': 59.0,
#   'Defense': 58.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 70.0,
#   'Speed\n': 73.0},
#  655: {'PokedexNumber': 655.0,
#   'Name': 'Delphox',
#   'Type': 'FirePsychic',
#   'Total': 534.0,
#   'HP': 75.0,
#   'Attack': 69.0,
#   'Defense': 72.0,
#   'SpecialAttack': 114.0,
#   'SpecialDefense': 100.0,
#   'Speed\n': 104.0},
#  656: {'PokedexNumber': 656.0,
#   'Name': 'Froakie',
#   'Type': 'Water',
#   'Total': 314.0,
#   'HP': 41.0,
#   'Attack': 56.0,
#   'Defense': 40.0,
#   'SpecialAttack': 62.0,
#   'SpecialDefense': 44.0,
#   'Speed\n': 71.0},
#  657: {'PokedexNumber': 657.0,
#   'Name': 'Frogadier',
#   'Type': 'Water',
#   'Total': 405.0,
#   'HP': 54.0,
#   'Attack': 63.0,
#   'Defense': 52.0,
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 56.0,
#   'Speed\n': 97.0},
#  658: {'PokedexNumber': 658.0,
#   'Name': 'Greninja',
#   'Type': 'WaterDark',
#   'Total': 530.0,
#   'HP': 72.0,
#   'Attack': 95.0,
#   'Defense': 67.0,
#   'SpecialAttack': 103.0,
#   'SpecialDefense': 71.0,
#   'Speed\n': 122.0},
#  659: {'PokedexNumber': 659.0,
#   'Name': 'Bunnelby',
#   'Type': 'Normal',
#   'Total': 237.0,
#   'HP': 38.0,
#   'Attack': 36.0,
#   'Defense': 38.0,
#   'SpecialAttack': 32.0,
#   'SpecialDefense': 36.0,
#   'Speed\n': 57.0},
#  660: {'PokedexNumber': 660.0,
#   'Name': 'Diggersby',
#   'Type': 'NormalGround',
#   'Total': 423.0,
#   'HP': 85.0,
#   'Attack': 56.0,
#   'Defense': 77.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 77.0,
#   'Speed\n': 78.0},
#  661: {'PokedexNumber': 661.0,
#   'Name': 'Fletchling',
#   'Type': 'NormalFlying',
#   'Total': 278.0,
#   'HP': 45.0,
#   'Attack': 50.0,
#   'Defense': 43.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 38.0,
#   'Speed\n': 62.0},
#  662: {'PokedexNumber': 662.0,
#   'Name': 'Fletchinder',
#   'Type': 'FireFlying',
#   'Total': 382.0,
#   'HP': 62.0,
#   'Attack': 73.0,
#   'Defense': 55.0,
#   'SpecialAttack': 56.0,
#   'SpecialDefense': 52.0,
#   'Speed\n': 84.0},
#  663: {'PokedexNumber': 663.0,
#   'Name': 'Talonflame',
#   'Type': 'FireFlying',
#   'Total': 499.0,
#   'HP': 78.0,
#   'Attack': 81.0,
#   'Defense': 71.0,
#   'SpecialAttack': 74.0,
#   'SpecialDefense': 69.0,
#   'Speed\n': 126.0},
#  664: {'PokedexNumber': 664.0,
#   'Name': 'Scatterbug',
#   'Type': 'Bug',
#   'Total': 200.0,
#   'HP': 38.0,
#   'Attack': 35.0,
#   'Defense': 40.0,
#   'SpecialAttack': 27.0,
#   'SpecialDefense': 25.0,
#   'Speed\n': 35.0},
#  665: {'PokedexNumber': 665.0,
#   'Name': 'Spewpa',
#   'Type': 'Bug',
#   'Total': 213.0,
#   'HP': 45.0,
#   'Attack': 22.0,
#   'Defense': 60.0,
#   'SpecialAttack': 27.0,
#   'SpecialDefense': 30.0,
#   'Speed\n': 29.0},
#  666: {'PokedexNumber': 666.0,
#   'Name': 'Vivillon',
#   'Type': 'BugFlying',
#   'Total': 411.0,
#   'HP': 80.0,
#   'Attack': 52.0,
#   'Defense': 50.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 50.0,
#   'Speed\n': 89.0},
#  667: {'PokedexNumber': 667.0,
#   'Name': 'Litleo',
#   'Type': 'FireNormal',
#   'Total': 369.0,
#   'HP': 62.0,
#   'Attack': 50.0,
#   'Defense': 58.0,
#   'SpecialAttack': 73.0,
#   'SpecialDefense': 54.0,
#   'Speed\n': 72.0},
#  668: {'PokedexNumber': 668.0,
#   'Name': 'Pyroar',
#   'Type': 'FireNormal',
#   'Total': 507.0,
#   'HP': 86.0,
#   'Attack': 68.0,
#   'Defense': 72.0,
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 66.0,
#   'Speed\n': 106.0},
#  669: {'PokedexNumber': 669.0,
#   'Name': 'Flabebe',
#   'Type': 'Fairy',
#   'Total': 303.0,
#   'HP': 44.0,
#   'Attack': 38.0,
#   'Defense': 39.0,
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 79.0,
#   'Speed\n': 42.0},
#  670: {'PokedexNumber': 670.0,
#   'Name': 'Floette',
#   'Type': 'Fairy',
#   'Total': 371.0,
#   'HP': 54.0,
#   'Attack': 45.0,
#   'Defense': 47.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 98.0,
#   'Speed\n': 52.0},
#  671: {'PokedexNumber': 671.0,
#   'Name': 'Florges',
#   'Type': 'Fairy',
#   'Total': 552.0,
#   'HP': 78.0,
#   'Attack': 65.0,
#   'Defense': 68.0,
#   'SpecialAttack': 112.0,
#   'SpecialDefense': 154.0,
#   'Speed\n': 75.0},
#  672: {'PokedexNumber': 672.0,
#   'Name': 'Skiddo',
#   'Type': 'Grass',
#   'Total': 350.0,
#   'HP': 66.0,
#   'Attack': 65.0,
#   'Defense': 48.0,
#   'SpecialAttack': 62.0,
#   'SpecialDefense': 57.0,
#   'Speed\n': 52.0},
#  673: {'PokedexNumber': 673.0,
#   'Name': 'Gogoat',
#   'Type': 'Grass',
#   'Total': 531.0,
#   'HP': 123.0,
#   'Attack': 100.0,
#   'Defense': 62.0,
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 81.0,
#   'Speed\n': 68.0},
#  674: {'PokedexNumber': 674.0,
#   'Name': 'Pancham',
#   'Type': 'Fighting',
#   'Total': 348.0,
#   'HP': 67.0,
#   'Attack': 82.0,
#   'Defense': 62.0,
#   'SpecialAttack': 46.0,
#   'SpecialDefense': 48.0,
#   'Speed\n': 43.0},
#  675: {'PokedexNumber': 675.0,
#   'Name': 'Pangoro',
#   'Type': 'FightingDark',
#   'Total': 495.0,
#   'HP': 95.0,
#   'Attack': 124.0,
#   'Defense': 78.0,
#   'SpecialAttack': 69.0,
#   'SpecialDefense': 71.0,
#   'Speed\n': 58.0},
#  676: {'PokedexNumber': 676.0,
#   'Name': 'Furfrou',
#   'Type': 'Normal',
#   'Total': 472.0,
#   'HP': 75.0,
#   'Attack': 80.0,
#   'Defense': 60.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 90.0,
#   'Speed\n': 102.0},
#  677: {'PokedexNumber': 677.0,
#   'Name': 'Espurr',
#   'Type': 'Psychic',
#   'Total': 355.0,
#   'HP': 62.0,
#   'Attack': 48.0,
#   'Defense': 54.0,
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 68.0},
#  678: {'PokedexNumber': 678.0,
#   'Name': 'MeowsticFemale',
#   'Type': 'Psychic',
#   'Total': 466.0,
#   'HP': 74.0,
#   'Attack': 48.0,
#   'Defense': 76.0,
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 81.0,
#   'Speed\n': 104.0},
#  679: {'PokedexNumber': 679.0,
#   'Name': 'Honedge',
#   'Type': 'SteelGhost',
#   'Total': 325.0,
#   'HP': 45.0,
#   'Attack': 80.0,
#   'Defense': 100.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 37.0,
#   'Speed\n': 28.0},
#  680: {'PokedexNumber': 680.0,
#   'Name': 'Doublade',
#   'Type': 'SteelGhost',
#   'Total': 448.0,
#   'HP': 59.0,
#   'Attack': 110.0,
#   'Defense': 150.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 49.0,
#   'Speed\n': 35.0},
#  681: {'PokedexNumber': 681.0,
#   'Name': 'AegislashShield Forme',
#   'Type': 'SteelGhost',
#   'Total': 520.0,
#   'HP': 60.0,
#   'Attack': 50.0,
#   'Defense': 150.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 150.0,
#   'Speed\n': 60.0},
#  682: {'PokedexNumber': 682.0,
#   'Name': 'Spritzee',
#   'Type': 'Fairy',
#   'Total': 341.0,
#   'HP': 78.0,
#   'Attack': 52.0,
#   'Defense': 60.0,
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 65.0,
#   'Speed\n': 23.0},
#  683: {'PokedexNumber': 683.0,
#   'Name': 'Aromatisse',
#   'Type': 'Fairy',
#   'Total': 462.0,
#   'HP': 101.0,
#   'Attack': 72.0,
#   'Defense': 72.0,
#   'SpecialAttack': 99.0,
#   'SpecialDefense': 89.0,
#   'Speed\n': 29.0},
#  684: {'PokedexNumber': 684.0,
#   'Name': 'Swirlix',
#   'Type': 'Fairy',
#   'Total': 341.0,
#   'HP': 62.0,
#   'Attack': 48.0,
#   'Defense': 66.0,
#   'SpecialAttack': 59.0,
#   'SpecialDefense': 57.0,
#   'Speed\n': 49.0},
#  685: {'PokedexNumber': 685.0,
#   'Name': 'Slurpuff',
#   'Type': 'Fairy',
#   'Total': 480.0,
#   'HP': 82.0,
#   'Attack': 80.0,
#   'Defense': 86.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 72.0},
#  686: {'PokedexNumber': 686.0,
#   'Name': 'Inkay',
#   'Type': 'DarkPsychic',
#   'Total': 288.0,
#   'HP': 53.0,
#   'Attack': 54.0,
#   'Defense': 53.0,
#   'SpecialAttack': 37.0,
#   'SpecialDefense': 46.0,
#   'Speed\n': 45.0},
#  687: {'PokedexNumber': 687.0,
#   'Name': 'Malamar',
#   'Type': 'DarkPsychic',
#   'Total': 482.0,
#   'HP': 86.0,
#   'Attack': 92.0,
#   'Defense': 88.0,
#   'SpecialAttack': 68.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 73.0},
#  688: {'PokedexNumber': 688.0,
#   'Name': 'Binacle',
#   'Type': 'RockWater',
#   'Total': 306.0,
#   'HP': 42.0,
#   'Attack': 52.0,
#   'Defense': 67.0,
#   'SpecialAttack': 39.0,
#   'SpecialDefense': 56.0,
#   'Speed\n': 50.0},
#  689: {'PokedexNumber': 689.0,
#   'Name': 'Barbaracle',
#   'Type': 'RockWater',
#   'Total': 500.0,
#   'HP': 72.0,
#   'Attack': 105.0,
#   'Defense': 115.0,
#   'SpecialAttack': 54.0,
#   'SpecialDefense': 86.0,
#   'Speed\n': 68.0},
#  690: {'PokedexNumber': 690.0,
#   'Name': 'Skrelp',
#   'Type': 'PoisonWater',
#   'Total': 320.0,
#   'HP': 50.0,
#   'Attack': 60.0,
#   'Defense': 60.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 30.0},
#  691: {'PokedexNumber': 691.0,
#   'Name': 'Dragalge',
#   'Type': 'PoisonDragon',
#   'Total': 494.0,
#   'HP': 65.0,
#   'Attack': 75.0,
#   'Defense': 90.0,
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 123.0,
#   'Speed\n': 44.0},
#  692: {'PokedexNumber': 692.0,
#   'Name': 'Clauncher',
#   'Type': 'Water',
#   'Total': 330.0,
#   'HP': 50.0,
#   'Attack': 53.0,
#   'Defense': 62.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 63.0,
#   'Speed\n': 44.0},
#  693: {'PokedexNumber': 693.0,
#   'Name': 'Clawitzer',
#   'Type': 'Water',
#   'Total': 500.0,
#   'HP': 71.0,
#   'Attack': 73.0,
#   'Defense': 88.0,
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 89.0,
#   'Speed\n': 59.0},
#  694: {'PokedexNumber': 694.0,
#   'Name': 'Helioptile',
#   'Type': 'ElectricNormal',
#   'Total': 289.0,
#   'HP': 44.0,
#   'Attack': 38.0,
#   'Defense': 33.0,
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 43.0,
#   'Speed\n': 70.0},
#  695: {'PokedexNumber': 695.0,
#   'Name': 'Heliolisk',
#   'Type': 'ElectricNormal',
#   'Total': 481.0,
#   'HP': 62.0,
#   'Attack': 55.0,
#   'Defense': 52.0,
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 94.0,
#   'Speed\n': 109.0},
#  696: {'PokedexNumber': 696.0,
#   'Name': 'Tyrunt',
#   'Type': 'RockDragon',
#   'Total': 362.0,
#   'HP': 58.0,
#   'Attack': 89.0,
#   'Defense': 77.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed\n': 48.0},
#  697: {'PokedexNumber': 697.0,
#   'Name': 'Tyrantrum',
#   'Type': 'RockDragon',
#   'Total': 521.0,
#   'HP': 82.0,
#   'Attack': 121.0,
#   'Defense': 119.0,
#   'SpecialAttack': 69.0,
#   'SpecialDefense': 59.0,
#   'Speed\n': 71.0},
#  698: {'PokedexNumber': 698.0,
#   'Name': 'Amaura',
#   'Type': 'RockIce',
#   'Total': 362.0,
#   'HP': 77.0,
#   'Attack': 59.0,
#   'Defense': 50.0,
#   'SpecialAttack': 67.0,
#   'SpecialDefense': 63.0,
#   'Speed\n': 46.0},
#  699: {'PokedexNumber': 699.0,
#   'Name': 'Aurorus',
#   'Type': 'RockIce',
#   'Total': 521.0,
#   'HP': 123.0,
#   'Attack': 77.0,
#   'Defense': 72.0,
#   'SpecialAttack': 99.0,
#   'SpecialDefense': 92.0,
#   'Speed\n': 58.0},
#  700: {'PokedexNumber': 700.0,
#   'Name': 'Sylveon',
#   'Type': 'Fairy',
#   'Total': 525.0,
#   'HP': 95.0,
#   'Attack': 65.0,
#   'Defense': 65.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 130.0,
#   'Speed\n': 60.0},
#  701: {'PokedexNumber': 701.0,
#   'Name': 'Hawlucha',
#   'Type': 'FightingFlying',
#   'Total': 500.0,
#   'HP': 78.0,
#   'Attack': 92.0,
#   'Defense': 75.0,
#   'SpecialAttack': 74.0,
#   'SpecialDefense': 63.0,
#   'Speed\n': 118.0},
#  702: {'PokedexNumber': 702.0,
#   'Name': 'Dedenne',
#   'Type': 'ElectricFairy',
#   'Total': 431.0,
#   'HP': 67.0,
#   'Attack': 58.0,
#   'Defense': 57.0,
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 67.0,
#   'Speed\n': 101.0},
#  703: {'PokedexNumber': 703.0,
#   'Name': 'Carbink',
#   'Type': 'RockFairy',
#   'Total': 500.0,
#   'HP': 50.0,
#   'Attack': 50.0,
#   'Defense': 150.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 150.0,
#   'Speed\n': 50.0},
#  704: {'PokedexNumber': 704.0,
#   'Name': 'Goomy',
#   'Type': 'Dragon',
#   'Total': 300.0,
#   'HP': 45.0,
#   'Attack': 50.0,
#   'Defense': 35.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 40.0},
#  705: {'PokedexNumber': 705.0,
#   'Name': 'Sliggoo',
#   'Type': 'Dragon',
#   'Total': 452.0,
#   'HP': 68.0,
#   'Attack': 75.0,
#   'Defense': 53.0,
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 113.0,
#   'Speed\n': 60.0},
#  706: {'PokedexNumber': 706.0,
#   'Name': 'Goodra',
#   'Type': 'Dragon',
#   'Total': 600.0,
#   'HP': 90.0,
#   'Attack': 100.0,
#   'Defense': 70.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 150.0,
#   'Speed\n': 80.0},
#  707: {'PokedexNumber': 707.0,
#   'Name': 'Klefki',
#   'Type': 'SteelFairy',
#   'Total': 470.0,
#   'HP': 57.0,
#   'Attack': 80.0,
#   'Defense': 91.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 87.0,
#   'Speed\n': 75.0},
#  708: {'PokedexNumber': 708.0,
#   'Name': 'Phantump',
#   'Type': 'GhostGrass',
#   'Total': 309.0,
#   'HP': 43.0,
#   'Attack': 70.0,
#   'Defense': 48.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 60.0,
#   'Speed\n': 38.0},
#  709: {'PokedexNumber': 709.0,
#   'Name': 'Trevenant',
#   'Type': 'GhostGrass',
#   'Total': 474.0,
#   'HP': 85.0,
#   'Attack': 110.0,
#   'Defense': 76.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 82.0,
#   'Speed\n': 56.0},
#  710: {'PokedexNumber': 710.0,
#   'Name': 'PumpkabooSuper Size',
#   'Type': 'GhostGrass',
#   'Total': 335.0,
#   'HP': 59.0,
#   'Attack': 66.0,
#   'Defense': 70.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 55.0,
#   'Speed\n': 41.0},
#  711: {'PokedexNumber': 711.0,
#   'Name': 'GourgeistSuper Size',
#   'Type': 'GhostGrass',
#   'Total': 494.0,
#   'HP': 85.0,
#   'Attack': 100.0,
#   'Defense': 122.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 75.0,
#   'Speed\n': 54.0},
#  712: {'PokedexNumber': 712.0,
#   'Name': 'Bergmite',
#   'Type': 'Ice',
#   'Total': 304.0,
#   'HP': 55.0,
#   'Attack': 69.0,
#   'Defense': 85.0,
#   'SpecialAttack': 32.0,
#   'SpecialDefense': 35.0,
#   'Speed\n': 28.0},
#  713: {'PokedexNumber': 713.0,
#   'Name': 'Avalugg',
#   'Type': 'Ice',
#   'Total': 514.0,
#   'HP': 95.0,
#   'Attack': 117.0,
#   'Defense': 184.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 46.0,
#   'Speed\n': 28.0},
#  714: {'PokedexNumber': 714.0,
#   'Name': 'Noibat',
#   'Type': 'FlyingDragon',
#   'Total': 245.0,
#   'HP': 40.0,
#   'Attack': 30.0,
#   'Defense': 35.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 40.0,
#   'Speed\n': 55.0},
#  715: {'PokedexNumber': 715.0,
#   'Name': 'Noivern',
#   'Type': 'FlyingDragon',
#   'Total': 535.0,
#   'HP': 85.0,
#   'Attack': 70.0,
#   'Defense': 80.0,
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 80.0,
#   'Speed\n': 123.0},
#  716: {'PokedexNumber': 716.0,
#   'Name': 'Xerneas',
#   'Type': 'Fairy',
#   'Total': 680.0,
#   'HP': 126.0,
#   'Attack': 131.0,
#   'Defense': 95.0,
#   'SpecialAttack': 131.0,
#   'SpecialDefense': 98.0,
#   'Speed\n': 99.0},
#  717: {'PokedexNumber': 717.0,
#   'Name': 'Yveltal',
#   'Type': 'DarkFlying',
#   'Total': 680.0,
#   'HP': 126.0,
#   'Attack': 131.0,
#   'Defense': 95.0,
#   'SpecialAttack': 131.0,
#   'SpecialDefense': 98.0,
#   'Speed\n': 99.0},
#  718: {'PokedexNumber': 718.0,
#   'Name': 'Zygarde Forme',
#   'Type': 'DragonGround',
#   'Total': 600.0,
#   'HP': 108.0,
#   'Attack': 100.0,
#   'Defense': 121.0,
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 95.0,
#   'Speed\n': 95.0},
#  719: {'PokedexNumber': 719.0,
#   'Name': 'DiancieMega Diancie',
#   'Type': 'RockFairy',
#   'Total': 700.0,
#   'HP': 50.0,
#   'Attack': 160.0,
#   'Defense': 110.0,
#   'SpecialAttack': 160.0,
#   'SpecialDefense': 110.0,
#   'Speed\n': 110.0},
#  720: {'PokedexNumber': 720.0,
#   'Name': 'HoopaHoopa Unbound',
#   'Type': 'PsychicDark',
#   'Total': 680.0,
#   'HP': 80.0,
#   'Attack': 160.0,
#   'Defense': 60.0,
#   'SpecialAttack': 170.0,
#   'SpecialDefense': 130.0,
#   'Speed\n': 80.0},
#  721: {'PokedexNumber': 721.0,
#   'Name': 'Volcanion',
#   'Type': 'FireWater',
#   'Total': 600.0,
#   'HP': 80.0,
#   'Attack': 110.0,
#   'Defense': 120.0,
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 90.0,
#   'Speed\n': 70.0}}

# %%
#Baby steps/mini experiment for Q9 above!
""""
header = final_data[0]
test = final_data[1:4]

list_1 = []
for row in test:
    list_1.append(list(zip(header,row)))

print(list_1)

x = []
for row in list_1:
    x.append(dict(row))
print(x)


f_dict = {}
for row in x:
#     print(row)
    pdex = int(row['PokedexNumber'])
    f_dict[pdex] = row
 
f_dict
""""
# Out:
#   File "<ipython-input-88-a631b25a42dc>", line 25
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
final_data[:3]
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed\n'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]]

# %% [markdown]
# ## 9. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.
